# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader
import torch
import warnings
from transformers import AutoModel, AutoTokenizer
import torch
import joblib
import base64
from huggingface_hub import login, HfApi
from gensim.models import Word2Vec
warnings.filterwarnings('ignore')

# %%
# Define device for torch
use_cuda = True
print("CUDA is available:", torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# CUDA is available: True

# %%
from datasets import load_dataset

dataset = load_dataset("davanstrien/WELFake")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'text', 'label'],
#         num_rows: 72134
#     })
# })

# %%
from collections import Counter

data = dataset["train"].to_pandas()

print("\nData shape:", data.shape)
print("\nSample of training data:")
display(data.head(3))
# Out:
# Data shape: (72134, 3)
#
# Sample of training data:
#                                                title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1                                               None
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1

# %% [markdown]
# ### Remove Empty Text Sections

# %%
cleaned_data = data.dropna(subset=['text', 'title'])
# rmve all columns where body text is just whitespace
cleaned_data = cleaned_data[cleaned_data['text'].str.strip().str.len() > 0]

# Print before and after to verify
print(f"Original data shape: {data.shape}")
print(f"After removing NaNs and whitespace-only rows: {cleaned_data.shape}")
cleaned_data = cleaned_data.reset_index(drop=True)
# Out:
# Original data shape: (72134, 3)
# After removing NaNs and whitespace-only rows: (70793, 3)

# %% [markdown]
# ### Generate Embeddings

# %%
def array_to_string(arr):
    return base64.b64encode(arr.tobytes()).decode('utf-8')

# %%
def sparse_to_string(sparse_mat):
    csr = sparse_mat.tocsr()
    data = base64.b64encode(csr.data.tobytes()).decode('utf-8')
    indices = base64.b64encode(csr.indices.tobytes()).decode('utf-8')
    indptr = base64.b64encode(csr.indptr.tobytes()).decode('utf-8')
    shape = f"{csr.shape[0]},{csr.shape[1]}"
    return f"{data}|{indices}|{indptr}|{shape}"

# %% [markdown]
# ##### Roberta

# %%
tokenizer = AutoTokenizer.from_pretrained("roberta-base")
model = AutoModel.from_pretrained("roberta-base")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

print(device)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# cuda

# %%
def get_roberta_embedding(text, max_length=512):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=max_length)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().cpu().numpy()

# %%
batch_size = 32
roberta_embeddings = []
for i in range(0, len(cleaned_data), batch_size):
    batch_texts = cleaned_data['text'][i:i+batch_size].tolist()
    batch_embeds = [get_roberta_embedding(text) for text in batch_texts]
    roberta_embeddings.extend(batch_embeds)
    print(f"Processed RoBERTa batch {i//batch_size + 1}/{len(cleaned_data)//batch_size + 1}")

roberta_embeddings = np.array(roberta_embeddings)
cleaned_data['roberta_embedding'] = [array_to_string(arr) for arr in roberta_embeddings]
print("RoBERTa embeddings shape:", roberta_embeddings.shape)
# Out:
# Processed RoBERTa batch 1/2213
# Processed RoBERTa batch 2/2213
# Processed RoBERTa batch 3/2213
# Processed RoBERTa batch 4/2213
# Processed RoBERTa batch 5/2213
# Processed RoBERTa batch 6/2213
# Processed RoBERTa batch 7/2213
# Processed RoBERTa batch 8/2213
# Processed RoBERTa batch 9/2213
# Processed RoBERTa batch 10/2213
# Processed RoBERTa batch 11/2213
# Processed RoBERTa batch 12/2213
# Processed RoBERTa batch 13/2213
# Processed RoBERTa batch 14/2213
# Processed RoBERTa batch 15/2213
# Processed RoBERTa batch 16/2213
# Processed RoBERTa batch 17/2213
# Processed RoBERTa batch 18/2213
# Processed RoBERTa batch 19/2213
# Processed RoBERTa batch 20/2213
# Processed RoBERTa batch 21/2213
# Processed RoBERTa batch 22/2213
# Processed RoBERTa batch 23/2213
# Processed RoBERTa batch 24/2213
# Processed RoBERTa batch 25/2213
# Processed RoBERTa batch 26/2213
# Processed RoBERTa batch 27/2213
# Processed RoBERTa batch 28/2213
# Processed RoBERTa batch 29/2213
# Processed RoBERTa batch 30/2213
# Processed RoBERTa batch 31/2213
# Processed RoBERTa batch 32/2213
# Processed RoBERTa batch 33/2213
# Processed RoBERTa batch 34/2213
# Processed RoBERTa batch 35/2213
# Processed RoBERTa batch 36/2213
# Processed RoBERTa batch 37/2213
# Processed RoBERTa batch 38/2213
# Processed RoBERTa batch 39/2213
# Processed RoBERTa batch 40/2213
# Processed RoBERTa batch 41/2213
# Processed RoBERTa batch 42/2213
# Processed RoBERTa batch 43/2213
# Processed RoBERTa batch 44/2213
# Processed RoBERTa batch 45/2213
# Processed RoBERTa batch 46/2213
# Processed RoBERTa batch 47/2213
# Processed RoBERTa batch 48/2213
# Processed RoBERTa batch 49/2213
# Processed RoBERTa batch 50/2213
# Processed RoBERTa batch 51/2213
# Processed RoBERTa batch 52/2213
# Processed RoBERTa batch 53/2213
# Processed RoBERTa batch 54/2213
# Processed RoBERTa batch 55/2213
# Processed RoBERTa batch 56/2213
# Processed RoBERTa batch 57/2213
# Processed RoBERTa batch 58/2213
# Processed RoBERTa batch 59/2213
# Processed RoBERTa batch 60/2213
# Processed RoBERTa batch 61/2213
# Processed RoBERTa batch 62/2213
# Processed RoBERTa batch 63/2213
# Processed RoBERTa batch 64/2213
# Processed RoBERTa batch 65/2213
# Processed RoBERTa batch 66/2213
# Processed RoBERTa batch 67/2213
# Processed RoBERTa batch 68/2213
# Processed RoBERTa batch 69/2213
# Processed RoBERTa batch 70/2213
# Processed RoBERTa batch 71/2213
# Processed RoBERTa batch 72/2213
# Processed RoBERTa batch 73/2213
# Processed RoBERTa batch 74/2213
# Processed RoBERTa batch 75/2213
# Processed RoBERTa batch 76/2213
# Processed RoBERTa batch 77/2213
# Processed RoBERTa batch 78/2213
# Processed RoBERTa batch 79/2213
# Processed RoBERTa batch 80/2213
# Processed RoBERTa batch 81/2213
# Processed RoBERTa batch 82/2213
# Processed RoBERTa batch 83/2213
# Processed RoBERTa batch 84/2213
# Processed RoBERTa batch 85/2213
# Processed RoBERTa batch 86/2213
# Processed RoBERTa batch 87/2213
# Processed RoBERTa batch 88/2213
# Processed RoBERTa batch 89/2213
# Processed RoBERTa batch 90/2213
# Processed RoBERTa batch 91/2213
# Processed RoBERTa batch 92/2213
# Processed RoBERTa batch 93/2213
# Processed RoBERTa batch 94/2213
# Processed RoBERTa batch 95/2213
# Processed RoBERTa batch 96/2213
# Processed RoBERTa batch 97/2213
# Processed RoBERTa batch 98/2213
# Processed RoBERTa batch 99/2213
# Processed RoBERTa batch 100/2213
# Processed RoBERTa batch 101/2213
# Processed RoBERTa batch 102/2213
# Processed RoBERTa batch 103/2213
# Processed RoBERTa batch 104/2213
# Processed RoBERTa batch 105/2213
# Processed RoBERTa batch 106/2213
# Processed RoBERTa batch 107/2213
# Processed RoBERTa batch 108/2213
# Processed RoBERTa batch 109/2213
# Processed RoBERTa batch 110/2213
# Processed RoBERTa batch 111/2213
# Processed RoBERTa batch 112/2213
# Processed RoBERTa batch 113/2213
# Processed RoBERTa batch 114/2213
# Processed RoBERTa batch 115/2213
# Processed RoBERTa batch 116/2213
# Processed RoBERTa batch 117/2213
# Processed RoBERTa batch 118/2213
# Processed RoBERTa batch 119/2213
# Processed RoBERTa batch 120/2213
# Processed RoBERTa batch 121/2213
# Processed RoBERTa batch 122/2213
# Processed RoBERTa batch 123/2213
# Processed RoBERTa batch 124/2213
# Processed RoBERTa batch 125/2213
# Processed RoBERTa batch 126/2213
# Processed RoBERTa batch 127/2213
# Processed RoBERTa batch 128/2213
# Processed RoBERTa batch 129/2213
# Processed RoBERTa batch 130/2213
# Processed RoBERTa batch 131/2213
# Processed RoBERTa batch 132/2213
# Processed RoBERTa batch 133/2213
# Processed RoBERTa batch 134/2213
# Processed RoBERTa batch 135/2213
# Processed RoBERTa batch 136/2213
# Processed RoBERTa batch 137/2213
# Processed RoBERTa batch 138/2213
# Processed RoBERTa batch 139/2213
# Processed RoBERTa batch 140/2213
# Processed RoBERTa batch 141/2213
# Processed RoBERTa batch 142/2213
# Processed RoBERTa batch 143/2213
# Processed RoBERTa batch 144/2213
# Processed RoBERTa batch 145/2213
# Processed RoBERTa batch 146/2213
# Processed RoBERTa batch 147/2213
# Processed RoBERTa batch 148/2213
# Processed RoBERTa batch 149/2213
# Processed RoBERTa batch 150/2213
# Processed RoBERTa batch 151/2213
# Processed RoBERTa batch 152/2213
# Processed RoBERTa batch 153/2213
# Processed RoBERTa batch 154/2213
# Processed RoBERTa batch 155/2213
# Processed RoBERTa batch 156/2213
# Processed RoBERTa batch 157/2213
# Processed RoBERTa batch 158/2213
# Processed RoBERTa batch 159/2213
# Processed RoBERTa batch 160/2213
# Processed RoBERTa batch 161/2213
# Processed RoBERTa batch 162/2213
# Processed RoBERTa batch 163/2213
# Processed RoBERTa batch 164/2213
# Processed RoBERTa batch 165/2213
# Processed RoBERTa batch 166/2213
# Processed RoBERTa batch 167/2213
# Processed RoBERTa batch 168/2213
# Processed RoBERTa batch 169/2213
# Processed RoBERTa batch 170/2213
# Processed RoBERTa batch 171/2213
# Processed RoBERTa batch 172/2213
# Processed RoBERTa batch 173/2213
# Processed RoBERTa batch 174/2213
# Processed RoBERTa batch 175/2213
# Processed RoBERTa batch 176/2213
# Processed RoBERTa batch 177/2213
# Processed RoBERTa batch 178/2213
# Processed RoBERTa batch 179/2213
# Processed RoBERTa batch 180/2213
# Processed RoBERTa batch 181/2213
# Processed RoBERTa batch 182/2213
# Processed RoBERTa batch 183/2213
# Processed RoBERTa batch 184/2213
# Processed RoBERTa batch 185/2213
# Processed RoBERTa batch 186/2213
# Processed RoBERTa batch 187/2213
# Processed RoBERTa batch 188/2213
# Processed RoBERTa batch 189/2213
# Processed RoBERTa batch 190/2213
# Processed RoBERTa batch 191/2213
# Processed RoBERTa batch 192/2213
# Processed RoBERTa batch 193/2213
# Processed RoBERTa batch 194/2213
# Processed RoBERTa batch 195/2213
# Processed RoBERTa batch 196/2213
# Processed RoBERTa batch 197/2213
# Processed RoBERTa batch 198/2213
# Processed RoBERTa batch 199/2213
# Processed RoBERTa batch 200/2213
# Processed RoBERTa batch 201/2213
# Processed RoBERTa batch 202/2213
# Processed RoBERTa batch 203/2213
# Processed RoBERTa batch 204/2213
# Processed RoBERTa batch 205/2213
# Processed RoBERTa batch 206/2213
# Processed RoBERTa batch 207/2213
# Processed RoBERTa batch 208/2213
# Processed RoBERTa batch 209/2213
# Processed RoBERTa batch 210/2213
# Processed RoBERTa batch 211/2213
# Processed RoBERTa batch 212/2213
# Processed RoBERTa batch 213/2213
# Processed RoBERTa batch 214/2213
# Processed RoBERTa batch 215/2213
# Processed RoBERTa batch 216/2213
# Processed RoBERTa batch 217/2213
# Processed RoBERTa batch 218/2213
# Processed RoBERTa batch 219/2213
# Processed RoBERTa batch 220/2213
# Processed RoBERTa batch 221/2213
# Processed RoBERTa batch 222/2213
# Processed RoBERTa batch 223/2213
# Processed RoBERTa batch 224/2213
# Processed RoBERTa batch 225/2213
# Processed RoBERTa batch 226/2213
# Processed RoBERTa batch 227/2213
# Processed RoBERTa batch 228/2213
# Processed RoBERTa batch 229/2213
# Processed RoBERTa batch 230/2213
# Processed RoBERTa batch 231/2213
# Processed RoBERTa batch 232/2213
# Processed RoBERTa batch 233/2213
# Processed RoBERTa batch 234/2213
# Processed RoBERTa batch 235/2213
# Processed RoBERTa batch 236/2213
# Processed RoBERTa batch 237/2213
# Processed RoBERTa batch 238/2213
# Processed RoBERTa batch 239/2213
# Processed RoBERTa batch 240/2213
# Processed RoBERTa batch 241/2213
# Processed RoBERTa batch 242/2213
# Processed RoBERTa batch 243/2213
# Processed RoBERTa batch 244/2213
# Processed RoBERTa batch 245/2213
# Processed RoBERTa batch 246/2213
# Processed RoBERTa batch 247/2213
# Processed RoBERTa batch 248/2213
# Processed RoBERTa batch 249/2213
# Processed RoBERTa batch 250/2213
# Processed RoBERTa batch 251/2213
# Processed RoBERTa batch 252/2213
# Processed RoBERTa batch 253/2213
# Processed RoBERTa batch 254/2213
# Processed RoBERTa batch 255/2213
# Processed RoBERTa batch 256/2213
# Processed RoBERTa batch 257/2213
# Processed RoBERTa batch 258/2213
# Processed RoBERTa batch 259/2213
# Processed RoBERTa batch 260/2213
# Processed RoBERTa batch 261/2213
# Processed RoBERTa batch 262/2213
# Processed RoBERTa batch 263/2213
# Processed RoBERTa batch 264/2213
# Processed RoBERTa batch 265/2213
# Processed RoBERTa batch 266/2213
# Processed RoBERTa batch 267/2213
# Processed RoBERTa batch 268/2213
# Processed RoBERTa batch 269/2213
# Processed RoBERTa batch 270/2213
# Processed RoBERTa batch 271/2213
# Processed RoBERTa batch 272/2213
# Processed RoBERTa batch 273/2213
# Processed RoBERTa batch 274/2213
# Processed RoBERTa batch 275/2213
# Processed RoBERTa batch 276/2213
# Processed RoBERTa batch 277/2213
# Processed RoBERTa batch 278/2213
# Processed RoBERTa batch 279/2213
# Processed RoBERTa batch 280/2213
# Processed RoBERTa batch 281/2213
# Processed RoBERTa batch 282/2213
# Processed RoBERTa batch 283/2213
# Processed RoBERTa batch 284/2213
# Processed RoBERTa batch 285/2213
# Processed RoBERTa batch 286/2213
# Processed RoBERTa batch 287/2213
# Processed RoBERTa batch 288/2213
# Processed RoBERTa batch 289/2213
# Processed RoBERTa batch 290/2213
# Processed RoBERTa batch 291/2213
# Processed RoBERTa batch 292/2213
# Processed RoBERTa batch 293/2213
# Processed RoBERTa batch 294/2213
# Processed RoBERTa batch 295/2213
# Processed RoBERTa batch 296/2213
# Processed RoBERTa batch 297/2213
# Processed RoBERTa batch 298/2213
# Processed RoBERTa batch 299/2213
# Processed RoBERTa batch 300/2213
# Processed RoBERTa batch 301/2213
# Processed RoBERTa batch 302/2213
# Processed RoBERTa batch 303/2213
# Processed RoBERTa batch 304/2213
# Processed RoBERTa batch 305/2213
# Processed RoBERTa batch 306/2213
# Processed RoBERTa batch 307/2213
# Processed RoBERTa batch 308/2213
# Processed RoBERTa batch 309/2213
# Processed RoBERTa batch 310/2213
# Processed RoBERTa batch 311/2213
# Processed RoBERTa batch 312/2213
# Processed RoBERTa batch 313/2213
# Processed RoBERTa batch 314/2213
# Processed RoBERTa batch 315/2213
# Processed RoBERTa batch 316/2213
# Processed RoBERTa batch 317/2213
# Processed RoBERTa batch 318/2213
# Processed RoBERTa batch 319/2213
# Processed RoBERTa batch 320/2213
# Processed RoBERTa batch 321/2213
# Processed RoBERTa batch 322/2213
# Processed RoBERTa batch 323/2213
# Processed RoBERTa batch 324/2213
# Processed RoBERTa batch 325/2213
# Processed RoBERTa batch 326/2213
# Processed RoBERTa batch 327/2213
# Processed RoBERTa batch 328/2213
# Processed RoBERTa batch 329/2213
# Processed RoBERTa batch 330/2213
# Processed RoBERTa batch 331/2213
# Processed RoBERTa batch 332/2213
# Processed RoBERTa batch 333/2213
# Processed RoBERTa batch 334/2213
# Processed RoBERTa batch 335/2213
# Processed RoBERTa batch 336/2213
# Processed RoBERTa batch 337/2213
# Processed RoBERTa batch 338/2213
# Processed RoBERTa batch 339/2213
# Processed RoBERTa batch 340/2213
# Processed RoBERTa batch 341/2213
# Processed RoBERTa batch 342/2213
# Processed RoBERTa batch 343/2213
# Processed RoBERTa batch 344/2213
# Processed RoBERTa batch 345/2213
# Processed RoBERTa batch 346/2213
# Processed RoBERTa batch 347/2213
# Processed RoBERTa batch 348/2213
# Processed RoBERTa batch 349/2213
# Processed RoBERTa batch 350/2213
# Processed RoBERTa batch 351/2213
# Processed RoBERTa batch 352/2213
# Processed RoBERTa batch 353/2213
# Processed RoBERTa batch 354/2213
# Processed RoBERTa batch 355/2213
# Processed RoBERTa batch 356/2213
# Processed RoBERTa batch 357/2213
# Processed RoBERTa batch 358/2213
# Processed RoBERTa batch 359/2213
# Processed RoBERTa batch 360/2213
# Processed RoBERTa batch 361/2213
# Processed RoBERTa batch 362/2213
# Processed RoBERTa batch 363/2213
# Processed RoBERTa batch 364/2213
# Processed RoBERTa batch 365/2213
# Processed RoBERTa batch 366/2213
# Processed RoBERTa batch 367/2213
# Processed RoBERTa batch 368/2213
# Processed RoBERTa batch 369/2213
# Processed RoBERTa batch 370/2213
# Processed RoBERTa batch 371/2213
# Processed RoBERTa batch 372/2213
# Processed RoBERTa batch 373/2213
# Processed RoBERTa batch 374/2213
# Processed RoBERTa batch 375/2213
# Processed RoBERTa batch 376/2213
# Processed RoBERTa batch 377/2213
# Processed RoBERTa batch 378/2213
# Processed RoBERTa batch 379/2213
# Processed RoBERTa batch 380/2213
# Processed RoBERTa batch 381/2213
# Processed RoBERTa batch 382/2213
# Processed RoBERTa batch 383/2213
# Processed RoBERTa batch 384/2213
# Processed RoBERTa batch 385/2213
# Processed RoBERTa batch 386/2213
# Processed RoBERTa batch 387/2213
# Processed RoBERTa batch 388/2213
# Processed RoBERTa batch 389/2213
# Processed RoBERTa batch 390/2213
# Processed RoBERTa batch 391/2213
# Processed RoBERTa batch 392/2213
# Processed RoBERTa batch 393/2213
# Processed RoBERTa batch 394/2213
# Processed RoBERTa batch 395/2213
# Processed RoBERTa batch 396/2213
# Processed RoBERTa batch 397/2213
# Processed RoBERTa batch 398/2213
# Processed RoBERTa batch 399/2213
# Processed RoBERTa batch 400/2213
# Processed RoBERTa batch 401/2213
# Processed RoBERTa batch 402/2213
# Processed RoBERTa batch 403/2213
# Processed RoBERTa batch 404/2213
# Processed RoBERTa batch 405/2213
# Processed RoBERTa batch 406/2213
# Processed RoBERTa batch 407/2213
# Processed RoBERTa batch 408/2213
# Processed RoBERTa batch 409/2213
# Processed RoBERTa batch 410/2213
# Processed RoBERTa batch 411/2213
# Processed RoBERTa batch 412/2213
# Processed RoBERTa batch 413/2213
# Processed RoBERTa batch 414/2213
# Processed RoBERTa batch 415/2213
# Processed RoBERTa batch 416/2213
# Processed RoBERTa batch 417/2213
# Processed RoBERTa batch 418/2213
# Processed RoBERTa batch 419/2213
# Processed RoBERTa batch 420/2213
# Processed RoBERTa batch 421/2213
# Processed RoBERTa batch 422/2213
# Processed RoBERTa batch 423/2213
# Processed RoBERTa batch 424/2213
# Processed RoBERTa batch 425/2213
# Processed RoBERTa batch 426/2213
# Processed RoBERTa batch 427/2213
# Processed RoBERTa batch 428/2213
# Processed RoBERTa batch 429/2213
# Processed RoBERTa batch 430/2213
# Processed RoBERTa batch 431/2213
# Processed RoBERTa batch 432/2213
# Processed RoBERTa batch 433/2213
# Processed RoBERTa batch 434/2213
# Processed RoBERTa batch 435/2213
# Processed RoBERTa batch 436/2213
# Processed RoBERTa batch 437/2213
# Processed RoBERTa batch 438/2213
# Processed RoBERTa batch 439/2213
# Processed RoBERTa batch 440/2213
# Processed RoBERTa batch 441/2213
# Processed RoBERTa batch 442/2213
# Processed RoBERTa batch 443/2213
# Processed RoBERTa batch 444/2213
# Processed RoBERTa batch 445/2213
# Processed RoBERTa batch 446/2213
# Processed RoBERTa batch 447/2213
# Processed RoBERTa batch 448/2213
# Processed RoBERTa batch 449/2213
# Processed RoBERTa batch 450/2213
# Processed RoBERTa batch 451/2213
# Processed RoBERTa batch 452/2213
# Processed RoBERTa batch 453/2213
# Processed RoBERTa batch 454/2213
# Processed RoBERTa batch 455/2213
# Processed RoBERTa batch 456/2213
# Processed RoBERTa batch 457/2213
# Processed RoBERTa batch 458/2213
# Processed RoBERTa batch 459/2213
# Processed RoBERTa batch 460/2213
# Processed RoBERTa batch 461/2213
# Processed RoBERTa batch 462/2213
# Processed RoBERTa batch 463/2213
# Processed RoBERTa batch 464/2213
# Processed RoBERTa batch 465/2213
# Processed RoBERTa batch 466/2213
# Processed RoBERTa batch 467/2213
# Processed RoBERTa batch 468/2213
# Processed RoBERTa batch 469/2213
# Processed RoBERTa batch 470/2213
# Processed RoBERTa batch 471/2213
# Processed RoBERTa batch 472/2213
# Processed RoBERTa batch 473/2213
# Processed RoBERTa batch 474/2213
# Processed RoBERTa batch 475/2213
# Processed RoBERTa batch 476/2213
# Processed RoBERTa batch 477/2213
# Processed RoBERTa batch 478/2213
# Processed RoBERTa batch 479/2213
# Processed RoBERTa batch 480/2213
# Processed RoBERTa batch 481/2213
# Processed RoBERTa batch 482/2213
# Processed RoBERTa batch 483/2213
# Processed RoBERTa batch 484/2213
# Processed RoBERTa batch 485/2213
# Processed RoBERTa batch 486/2213
# Processed RoBERTa batch 487/2213
# Processed RoBERTa batch 488/2213
# Processed RoBERTa batch 489/2213
# Processed RoBERTa batch 490/2213
# Processed RoBERTa batch 491/2213
# Processed RoBERTa batch 492/2213
# Processed RoBERTa batch 493/2213
# Processed RoBERTa batch 494/2213
# Processed RoBERTa batch 495/2213
# Processed RoBERTa batch 496/2213
# Processed RoBERTa batch 497/2213
# Processed RoBERTa batch 498/2213
# Processed RoBERTa batch 499/2213
# Processed RoBERTa batch 500/2213
# Processed RoBERTa batch 501/2213
# Processed RoBERTa batch 502/2213
# Processed RoBERTa batch 503/2213
# Processed RoBERTa batch 504/2213
# Processed RoBERTa batch 505/2213
# Processed RoBERTa batch 506/2213
# Processed RoBERTa batch 507/2213
# Processed RoBERTa batch 508/2213
# Processed RoBERTa batch 509/2213
# Processed RoBERTa batch 510/2213
# Processed RoBERTa batch 511/2213
# Processed RoBERTa batch 512/2213
# Processed RoBERTa batch 513/2213
# Processed RoBERTa batch 514/2213
# Processed RoBERTa batch 515/2213
# Processed RoBERTa batch 516/2213
# Processed RoBERTa batch 517/2213
# Processed RoBERTa batch 518/2213
# Processed RoBERTa batch 519/2213
# Processed RoBERTa batch 520/2213
# Processed RoBERTa batch 521/2213
# Processed RoBERTa batch 522/2213
# Processed RoBERTa batch 523/2213
# Processed RoBERTa batch 524/2213
# Processed RoBERTa batch 525/2213
# Processed RoBERTa batch 526/2213
# Processed RoBERTa batch 527/2213
# Processed RoBERTa batch 528/2213
# Processed RoBERTa batch 529/2213
# Processed RoBERTa batch 530/2213
# Processed RoBERTa batch 531/2213
# Processed RoBERTa batch 532/2213
# Processed RoBERTa batch 533/2213
# Processed RoBERTa batch 534/2213
# Processed RoBERTa batch 535/2213
# Processed RoBERTa batch 536/2213
# Processed RoBERTa batch 537/2213
# Processed RoBERTa batch 538/2213
# Processed RoBERTa batch 539/2213
# Processed RoBERTa batch 540/2213
# Processed RoBERTa batch 541/2213
# Processed RoBERTa batch 542/2213
# Processed RoBERTa batch 543/2213
# Processed RoBERTa batch 544/2213
# Processed RoBERTa batch 545/2213
# Processed RoBERTa batch 546/2213
# Processed RoBERTa batch 547/2213
# Processed RoBERTa batch 548/2213
# Processed RoBERTa batch 549/2213
# Processed RoBERTa batch 550/2213
# Processed RoBERTa batch 551/2213
# Processed RoBERTa batch 552/2213
# Processed RoBERTa batch 553/2213
# Processed RoBERTa batch 554/2213
# Processed RoBERTa batch 555/2213
# Processed RoBERTa batch 556/2213
# Processed RoBERTa batch 557/2213
# Processed RoBERTa batch 558/2213
# Processed RoBERTa batch 559/2213
# Processed RoBERTa batch 560/2213
# Processed RoBERTa batch 561/2213
# Processed RoBERTa batch 562/2213
# Processed RoBERTa batch 563/2213
# Processed RoBERTa batch 564/2213
# Processed RoBERTa batch 565/2213
# Processed RoBERTa batch 566/2213
# Processed RoBERTa batch 567/2213
# Processed RoBERTa batch 568/2213
# Processed RoBERTa batch 569/2213
# Processed RoBERTa batch 570/2213
# Processed RoBERTa batch 571/2213
# Processed RoBERTa batch 572/2213
# Processed RoBERTa batch 573/2213
# Processed RoBERTa batch 574/2213
# Processed RoBERTa batch 575/2213
# Processed RoBERTa batch 576/2213
# Processed RoBERTa batch 577/2213
# Processed RoBERTa batch 578/2213
# Processed RoBERTa batch 579/2213
# Processed RoBERTa batch 580/2213
# Processed RoBERTa batch 581/2213
# Processed RoBERTa batch 582/2213
# Processed RoBERTa batch 583/2213
# Processed RoBERTa batch 584/2213
# Processed RoBERTa batch 585/2213
# Processed RoBERTa batch 586/2213
# Processed RoBERTa batch 587/2213
# Processed RoBERTa batch 588/2213
# Processed RoBERTa batch 589/2213
# Processed RoBERTa batch 590/2213
# Processed RoBERTa batch 591/2213
# Processed RoBERTa batch 592/2213
# Processed RoBERTa batch 593/2213
# Processed RoBERTa batch 594/2213
# Processed RoBERTa batch 595/2213
# Processed RoBERTa batch 596/2213
# Processed RoBERTa batch 597/2213
# Processed RoBERTa batch 598/2213
# Processed RoBERTa batch 599/2213
# Processed RoBERTa batch 600/2213
# Processed RoBERTa batch 601/2213
# Processed RoBERTa batch 602/2213
# Processed RoBERTa batch 603/2213
# Processed RoBERTa batch 604/2213
# Processed RoBERTa batch 605/2213
# Processed RoBERTa batch 606/2213
# Processed RoBERTa batch 607/2213
# Processed RoBERTa batch 608/2213
# Processed RoBERTa batch 609/2213
# Processed RoBERTa batch 610/2213
# Processed RoBERTa batch 611/2213
# Processed RoBERTa batch 612/2213
# Processed RoBERTa batch 613/2213
# Processed RoBERTa batch 614/2213
# Processed RoBERTa batch 615/2213
# Processed RoBERTa batch 616/2213
# Processed RoBERTa batch 617/2213
# Processed RoBERTa batch 618/2213
# Processed RoBERTa batch 619/2213
# Processed RoBERTa batch 620/2213
# Processed RoBERTa batch 621/2213
# Processed RoBERTa batch 622/2213
# Processed RoBERTa batch 623/2213
# Processed RoBERTa batch 624/2213
# Processed RoBERTa batch 625/2213
# Processed RoBERTa batch 626/2213
# Processed RoBERTa batch 627/2213
# Processed RoBERTa batch 628/2213
# Processed RoBERTa batch 629/2213
# Processed RoBERTa batch 630/2213
# Processed RoBERTa batch 631/2213
# Processed RoBERTa batch 632/2213
# Processed RoBERTa batch 633/2213
# Processed RoBERTa batch 634/2213
# Processed RoBERTa batch 635/2213
# Processed RoBERTa batch 636/2213
# Processed RoBERTa batch 637/2213
# Processed RoBERTa batch 638/2213
# Processed RoBERTa batch 639/2213
# Processed RoBERTa batch 640/2213
# Processed RoBERTa batch 641/2213
# Processed RoBERTa batch 642/2213
# Processed RoBERTa batch 643/2213
# Processed RoBERTa batch 644/2213
# Processed RoBERTa batch 645/2213
# Processed RoBERTa batch 646/2213
# Processed RoBERTa batch 647/2213
# Processed RoBERTa batch 648/2213
# Processed RoBERTa batch 649/2213
# Processed RoBERTa batch 650/2213
# Processed RoBERTa batch 651/2213
# Processed RoBERTa batch 652/2213
# Processed RoBERTa batch 653/2213
# Processed RoBERTa batch 654/2213
# Processed RoBERTa batch 655/2213
# Processed RoBERTa batch 656/2213
# Processed RoBERTa batch 657/2213
# Processed RoBERTa batch 658/2213
# Processed RoBERTa batch 659/2213
# Processed RoBERTa batch 660/2213
# Processed RoBERTa batch 661/2213
# Processed RoBERTa batch 662/2213
# Processed RoBERTa batch 663/2213
# Processed RoBERTa batch 664/2213
# Processed RoBERTa batch 665/2213
# Processed RoBERTa batch 666/2213
# Processed RoBERTa batch 667/2213
# Processed RoBERTa batch 668/2213
# Processed RoBERTa batch 669/2213
# Processed RoBERTa batch 670/2213
# Processed RoBERTa batch 671/2213
# Processed RoBERTa batch 672/2213
# Processed RoBERTa batch 673/2213
# Processed RoBERTa batch 674/2213
# Processed RoBERTa batch 675/2213
# Processed RoBERTa batch 676/2213
# Processed RoBERTa batch 677/2213
# Processed RoBERTa batch 678/2213
# Processed RoBERTa batch 679/2213
# Processed RoBERTa batch 680/2213
# Processed RoBERTa batch 681/2213
# Processed RoBERTa batch 682/2213
# Processed RoBERTa batch 683/2213
# Processed RoBERTa batch 684/2213
# Processed RoBERTa batch 685/2213
# Processed RoBERTa batch 686/2213
# Processed RoBERTa batch 687/2213
# Processed RoBERTa batch 688/2213
# Processed RoBERTa batch 689/2213
# Processed RoBERTa batch 690/2213
# Processed RoBERTa batch 691/2213
# Processed RoBERTa batch 692/2213
# Processed RoBERTa batch 693/2213
# Processed RoBERTa batch 694/2213
# Processed RoBERTa batch 695/2213
# Processed RoBERTa batch 696/2213
# Processed RoBERTa batch 697/2213
# Processed RoBERTa batch 698/2213
# Processed RoBERTa batch 699/2213
# Processed RoBERTa batch 700/2213
# Processed RoBERTa batch 701/2213
# Processed RoBERTa batch 702/2213
# Processed RoBERTa batch 703/2213
# Processed RoBERTa batch 704/2213
# Processed RoBERTa batch 705/2213
# Processed RoBERTa batch 706/2213
# Processed RoBERTa batch 707/2213
# Processed RoBERTa batch 708/2213
# Processed RoBERTa batch 709/2213
# Processed RoBERTa batch 710/2213
# Processed RoBERTa batch 711/2213
# Processed RoBERTa batch 712/2213
# Processed RoBERTa batch 713/2213
# Processed RoBERTa batch 714/2213
# Processed RoBERTa batch 715/2213
# Processed RoBERTa batch 716/2213
# Processed RoBERTa batch 717/2213
# Processed RoBERTa batch 718/2213
# Processed RoBERTa batch 719/2213
# Processed RoBERTa batch 720/2213
# Processed RoBERTa batch 721/2213
# Processed RoBERTa batch 722/2213
# Processed RoBERTa batch 723/2213
# Processed RoBERTa batch 724/2213
# Processed RoBERTa batch 725/2213
# Processed RoBERTa batch 726/2213
# Processed RoBERTa batch 727/2213
# Processed RoBERTa batch 728/2213
# Processed RoBERTa batch 729/2213
# Processed RoBERTa batch 730/2213
# Processed RoBERTa batch 731/2213
# Processed RoBERTa batch 732/2213
# Processed RoBERTa batch 733/2213
# Processed RoBERTa batch 734/2213
# Processed RoBERTa batch 735/2213
# Processed RoBERTa batch 736/2213
# Processed RoBERTa batch 737/2213
# Processed RoBERTa batch 738/2213
# Processed RoBERTa batch 739/2213
# Processed RoBERTa batch 740/2213
# Processed RoBERTa batch 741/2213
# Processed RoBERTa batch 742/2213
# Processed RoBERTa batch 743/2213
# Processed RoBERTa batch 744/2213
# Processed RoBERTa batch 745/2213
# Processed RoBERTa batch 746/2213
# Processed RoBERTa batch 747/2213
# Processed RoBERTa batch 748/2213
# Processed RoBERTa batch 749/2213
# Processed RoBERTa batch 750/2213
# Processed RoBERTa batch 751/2213
# Processed RoBERTa batch 752/2213
# Processed RoBERTa batch 753/2213
# Processed RoBERTa batch 754/2213
# Processed RoBERTa batch 755/2213
# Processed RoBERTa batch 756/2213
# Processed RoBERTa batch 757/2213
# Processed RoBERTa batch 758/2213
# Processed RoBERTa batch 759/2213
# Processed RoBERTa batch 760/2213
# Processed RoBERTa batch 761/2213
# Processed RoBERTa batch 762/2213
# Processed RoBERTa batch 763/2213
# Processed RoBERTa batch 764/2213
# Processed RoBERTa batch 765/2213
# Processed RoBERTa batch 766/2213
# Processed RoBERTa batch 767/2213
# Processed RoBERTa batch 768/2213
# Processed RoBERTa batch 769/2213
# Processed RoBERTa batch 770/2213
# Processed RoBERTa batch 771/2213
# Processed RoBERTa batch 772/2213
# Processed RoBERTa batch 773/2213
# Processed RoBERTa batch 774/2213
# Processed RoBERTa batch 775/2213
# Processed RoBERTa batch 776/2213
# Processed RoBERTa batch 777/2213
# Processed RoBERTa batch 778/2213
# Processed RoBERTa batch 779/2213
# Processed RoBERTa batch 780/2213
# Processed RoBERTa batch 781/2213
# Processed RoBERTa batch 782/2213
# Processed RoBERTa batch 783/2213
# Processed RoBERTa batch 784/2213
# Processed RoBERTa batch 785/2213
# Processed RoBERTa batch 786/2213
# Processed RoBERTa batch 787/2213
# Processed RoBERTa batch 788/2213
# Processed RoBERTa batch 789/2213
# Processed RoBERTa batch 790/2213
# Processed RoBERTa batch 791/2213
# Processed RoBERTa batch 792/2213
# Processed RoBERTa batch 793/2213
# Processed RoBERTa batch 794/2213
# Processed RoBERTa batch 795/2213
# Processed RoBERTa batch 796/2213
# Processed RoBERTa batch 797/2213
# Processed RoBERTa batch 798/2213
# Processed RoBERTa batch 799/2213
# Processed RoBERTa batch 800/2213
# Processed RoBERTa batch 801/2213
# Processed RoBERTa batch 802/2213
# Processed RoBERTa batch 803/2213
# Processed RoBERTa batch 804/2213
# Processed RoBERTa batch 805/2213
# Processed RoBERTa batch 806/2213
# Processed RoBERTa batch 807/2213
# Processed RoBERTa batch 808/2213
# Processed RoBERTa batch 809/2213
# Processed RoBERTa batch 810/2213
# Processed RoBERTa batch 811/2213
# Processed RoBERTa batch 812/2213
# Processed RoBERTa batch 813/2213
# Processed RoBERTa batch 814/2213
# Processed RoBERTa batch 815/2213
# Processed RoBERTa batch 816/2213
# Processed RoBERTa batch 817/2213
# Processed RoBERTa batch 818/2213
# Processed RoBERTa batch 819/2213
# Processed RoBERTa batch 820/2213
# Processed RoBERTa batch 821/2213
# Processed RoBERTa batch 822/2213
# Processed RoBERTa batch 823/2213
# Processed RoBERTa batch 824/2213
# Processed RoBERTa batch 825/2213
# Processed RoBERTa batch 826/2213
# Processed RoBERTa batch 827/2213
# Processed RoBERTa batch 828/2213
# Processed RoBERTa batch 829/2213
# Processed RoBERTa batch 830/2213
# Processed RoBERTa batch 831/2213
# Processed RoBERTa batch 832/2213
# Processed RoBERTa batch 833/2213
# Processed RoBERTa batch 834/2213
# Processed RoBERTa batch 835/2213
# Processed RoBERTa batch 836/2213
# Processed RoBERTa batch 837/2213
# Processed RoBERTa batch 838/2213
# Processed RoBERTa batch 839/2213
# Processed RoBERTa batch 840/2213
# Processed RoBERTa batch 841/2213
# Processed RoBERTa batch 842/2213
# Processed RoBERTa batch 843/2213
# Processed RoBERTa batch 844/2213
# Processed RoBERTa batch 845/2213
# Processed RoBERTa batch 846/2213
# Processed RoBERTa batch 847/2213
# Processed RoBERTa batch 848/2213
# Processed RoBERTa batch 849/2213
# Processed RoBERTa batch 850/2213
# Processed RoBERTa batch 851/2213
# Processed RoBERTa batch 852/2213
# Processed RoBERTa batch 853/2213
# Processed RoBERTa batch 854/2213
# Processed RoBERTa batch 855/2213
# Processed RoBERTa batch 856/2213
# Processed RoBERTa batch 857/2213
# Processed RoBERTa batch 858/2213
# Processed RoBERTa batch 859/2213
# Processed RoBERTa batch 860/2213
# Processed RoBERTa batch 861/2213
# Processed RoBERTa batch 862/2213
# Processed RoBERTa batch 863/2213
# Processed RoBERTa batch 864/2213
# Processed RoBERTa batch 865/2213
# Processed RoBERTa batch 866/2213
# Processed RoBERTa batch 867/2213
# Processed RoBERTa batch 868/2213
# Processed RoBERTa batch 869/2213
# Processed RoBERTa batch 870/2213
# Processed RoBERTa batch 871/2213
# Processed RoBERTa batch 872/2213
# Processed RoBERTa batch 873/2213
# Processed RoBERTa batch 874/2213
# Processed RoBERTa batch 875/2213
# Processed RoBERTa batch 876/2213
# Processed RoBERTa batch 877/2213
# Processed RoBERTa batch 878/2213
# Processed RoBERTa batch 879/2213
# Processed RoBERTa batch 880/2213
# Processed RoBERTa batch 881/2213
# Processed RoBERTa batch 882/2213
# Processed RoBERTa batch 883/2213
# Processed RoBERTa batch 884/2213
# Processed RoBERTa batch 885/2213
# Processed RoBERTa batch 886/2213
# Processed RoBERTa batch 887/2213
# Processed RoBERTa batch 888/2213
# Processed RoBERTa batch 889/2213
# Processed RoBERTa batch 890/2213
# Processed RoBERTa batch 891/2213
# Processed RoBERTa batch 892/2213
# Processed RoBERTa batch 893/2213
# Processed RoBERTa batch 894/2213
# Processed RoBERTa batch 895/2213
# Processed RoBERTa batch 896/2213
# Processed RoBERTa batch 897/2213
# Processed RoBERTa batch 898/2213
# Processed RoBERTa batch 899/2213
# Processed RoBERTa batch 900/2213
# Processed RoBERTa batch 901/2213
# Processed RoBERTa batch 902/2213
# Processed RoBERTa batch 903/2213
# Processed RoBERTa batch 904/2213
# Processed RoBERTa batch 905/2213
# Processed RoBERTa batch 906/2213
# Processed RoBERTa batch 907/2213
# Processed RoBERTa batch 908/2213
# Processed RoBERTa batch 909/2213
# Processed RoBERTa batch 910/2213
# Processed RoBERTa batch 911/2213
# Processed RoBERTa batch 912/2213
# Processed RoBERTa batch 913/2213
# Processed RoBERTa batch 914/2213
# Processed RoBERTa batch 915/2213
# Processed RoBERTa batch 916/2213
# Processed RoBERTa batch 917/2213
# Processed RoBERTa batch 918/2213
# Processed RoBERTa batch 919/2213
# Processed RoBERTa batch 920/2213
# Processed RoBERTa batch 921/2213
# Processed RoBERTa batch 922/2213
# Processed RoBERTa batch 923/2213
# Processed RoBERTa batch 924/2213
# Processed RoBERTa batch 925/2213
# Processed RoBERTa batch 926/2213
# Processed RoBERTa batch 927/2213
# Processed RoBERTa batch 928/2213
# Processed RoBERTa batch 929/2213
# Processed RoBERTa batch 930/2213
# Processed RoBERTa batch 931/2213
# Processed RoBERTa batch 932/2213
# Processed RoBERTa batch 933/2213
# Processed RoBERTa batch 934/2213
# Processed RoBERTa batch 935/2213
# Processed RoBERTa batch 936/2213
# Processed RoBERTa batch 937/2213
# Processed RoBERTa batch 938/2213
# Processed RoBERTa batch 939/2213
# Processed RoBERTa batch 940/2213
# Processed RoBERTa batch 941/2213
# Processed RoBERTa batch 942/2213
# Processed RoBERTa batch 943/2213
# Processed RoBERTa batch 944/2213
# Processed RoBERTa batch 945/2213
# Processed RoBERTa batch 946/2213
# Processed RoBERTa batch 947/2213
# Processed RoBERTa batch 948/2213
# Processed RoBERTa batch 949/2213
# Processed RoBERTa batch 950/2213
# Processed RoBERTa batch 951/2213
# Processed RoBERTa batch 952/2213
# Processed RoBERTa batch 953/2213
# Processed RoBERTa batch 954/2213
# Processed RoBERTa batch 955/2213
# Processed RoBERTa batch 956/2213
# Processed RoBERTa batch 957/2213
# Processed RoBERTa batch 958/2213
# Processed RoBERTa batch 959/2213
# Processed RoBERTa batch 960/2213
# Processed RoBERTa batch 961/2213
# Processed RoBERTa batch 962/2213
# Processed RoBERTa batch 963/2213
# Processed RoBERTa batch 964/2213
# Processed RoBERTa batch 965/2213
# Processed RoBERTa batch 966/2213
# Processed RoBERTa batch 967/2213
# Processed RoBERTa batch 968/2213
# Processed RoBERTa batch 969/2213
# Processed RoBERTa batch 970/2213
# Processed RoBERTa batch 971/2213
# Processed RoBERTa batch 972/2213
# Processed RoBERTa batch 973/2213
# Processed RoBERTa batch 974/2213
# Processed RoBERTa batch 975/2213
# Processed RoBERTa batch 976/2213
# Processed RoBERTa batch 977/2213
# Processed RoBERTa batch 978/2213
# Processed RoBERTa batch 979/2213
# Processed RoBERTa batch 980/2213
# Processed RoBERTa batch 981/2213
# Processed RoBERTa batch 982/2213
# Processed RoBERTa batch 983/2213
# Processed RoBERTa batch 984/2213
# Processed RoBERTa batch 985/2213
# Processed RoBERTa batch 986/2213
# Processed RoBERTa batch 987/2213
# Processed RoBERTa batch 988/2213
# Processed RoBERTa batch 989/2213
# Processed RoBERTa batch 990/2213
# Processed RoBERTa batch 991/2213
# Processed RoBERTa batch 992/2213
# Processed RoBERTa batch 993/2213
# Processed RoBERTa batch 994/2213
# Processed RoBERTa batch 995/2213
# Processed RoBERTa batch 996/2213
# Processed RoBERTa batch 997/2213
# Processed RoBERTa batch 998/2213
# Processed RoBERTa batch 999/2213
# Processed RoBERTa batch 1000/2213
# Processed RoBERTa batch 1001/2213
# Processed RoBERTa batch 1002/2213
# Processed RoBERTa batch 1003/2213
# Processed RoBERTa batch 1004/2213
# Processed RoBERTa batch 1005/2213
# Processed RoBERTa batch 1006/2213
# Processed RoBERTa batch 1007/2213
# Processed RoBERTa batch 1008/2213
# Processed RoBERTa batch 1009/2213
# Processed RoBERTa batch 1010/2213
# Processed RoBERTa batch 1011/2213
# Processed RoBERTa batch 1012/2213
# Processed RoBERTa batch 1013/2213
# Processed RoBERTa batch 1014/2213
# Processed RoBERTa batch 1015/2213
# Processed RoBERTa batch 1016/2213
# Processed RoBERTa batch 1017/2213
# Processed RoBERTa batch 1018/2213
# Processed RoBERTa batch 1019/2213
# Processed RoBERTa batch 1020/2213
# Processed RoBERTa batch 1021/2213
# Processed RoBERTa batch 1022/2213
# Processed RoBERTa batch 1023/2213
# Processed RoBERTa batch 1024/2213
# Processed RoBERTa batch 1025/2213
# Processed RoBERTa batch 1026/2213
# Processed RoBERTa batch 1027/2213
# Processed RoBERTa batch 1028/2213
# Processed RoBERTa batch 1029/2213
# Processed RoBERTa batch 1030/2213
# Processed RoBERTa batch 1031/2213
# Processed RoBERTa batch 1032/2213
# Processed RoBERTa batch 1033/2213
# Processed RoBERTa batch 1034/2213
# Processed RoBERTa batch 1035/2213
# Processed RoBERTa batch 1036/2213
# Processed RoBERTa batch 1037/2213
# Processed RoBERTa batch 1038/2213
# Processed RoBERTa batch 1039/2213
# Processed RoBERTa batch 1040/2213
# Processed RoBERTa batch 1041/2213
# Processed RoBERTa batch 1042/2213
# Processed RoBERTa batch 1043/2213
# Processed RoBERTa batch 1044/2213
# Processed RoBERTa batch 1045/2213
# Processed RoBERTa batch 1046/2213
# Processed RoBERTa batch 1047/2213
# Processed RoBERTa batch 1048/2213
# Processed RoBERTa batch 1049/2213
# Processed RoBERTa batch 1050/2213
# Processed RoBERTa batch 1051/2213
# Processed RoBERTa batch 1052/2213
# Processed RoBERTa batch 1053/2213
# Processed RoBERTa batch 1054/2213
# Processed RoBERTa batch 1055/2213
# Processed RoBERTa batch 1056/2213
# Processed RoBERTa batch 1057/2213
# Processed RoBERTa batch 1058/2213
# Processed RoBERTa batch 1059/2213
# Processed RoBERTa batch 1060/2213
# Processed RoBERTa batch 1061/2213
# Processed RoBERTa batch 1062/2213
# Processed RoBERTa batch 1063/2213
# Processed RoBERTa batch 1064/2213
# Processed RoBERTa batch 1065/2213
# Processed RoBERTa batch 1066/2213
# Processed RoBERTa batch 1067/2213
# Processed RoBERTa batch 1068/2213
# Processed RoBERTa batch 1069/2213
# Processed RoBERTa batch 1070/2213
# Processed RoBERTa batch 1071/2213
# Processed RoBERTa batch 1072/2213
# Processed RoBERTa batch 1073/2213
# Processed RoBERTa batch 1074/2213
# Processed RoBERTa batch 1075/2213
# Processed RoBERTa batch 1076/2213
# Processed RoBERTa batch 1077/2213
# Processed RoBERTa batch 1078/2213
# Processed RoBERTa batch 1079/2213
# Processed RoBERTa batch 1080/2213
# Processed RoBERTa batch 1081/2213
# Processed RoBERTa batch 1082/2213
# Processed RoBERTa batch 1083/2213
# Processed RoBERTa batch 1084/2213
# Processed RoBERTa batch 1085/2213
# Processed RoBERTa batch 1086/2213
# Processed RoBERTa batch 1087/2213
# Processed RoBERTa batch 1088/2213
# Processed RoBERTa batch 1089/2213
# Processed RoBERTa batch 1090/2213
# Processed RoBERTa batch 1091/2213
# Processed RoBERTa batch 1092/2213
# Processed RoBERTa batch 1093/2213
# Processed RoBERTa batch 1094/2213
# Processed RoBERTa batch 1095/2213
# Processed RoBERTa batch 1096/2213
# Processed RoBERTa batch 1097/2213
# Processed RoBERTa batch 1098/2213
# Processed RoBERTa batch 1099/2213
# Processed RoBERTa batch 1100/2213
# Processed RoBERTa batch 1101/2213
# Processed RoBERTa batch 1102/2213
# Processed RoBERTa batch 1103/2213
# Processed RoBERTa batch 1104/2213
# Processed RoBERTa batch 1105/2213
# Processed RoBERTa batch 1106/2213
# Processed RoBERTa batch 1107/2213
# Processed RoBERTa batch 1108/2213
# Processed RoBERTa batch 1109/2213
# Processed RoBERTa batch 1110/2213
# Processed RoBERTa batch 1111/2213
# Processed RoBERTa batch 1112/2213
# Processed RoBERTa batch 1113/2213
# Processed RoBERTa batch 1114/2213
# Processed RoBERTa batch 1115/2213
# Processed RoBERTa batch 1116/2213
# Processed RoBERTa batch 1117/2213
# Processed RoBERTa batch 1118/2213
# Processed RoBERTa batch 1119/2213
# Processed RoBERTa batch 1120/2213
# Processed RoBERTa batch 1121/2213
# Processed RoBERTa batch 1122/2213
# Processed RoBERTa batch 1123/2213
# Processed RoBERTa batch 1124/2213
# Processed RoBERTa batch 1125/2213
# Processed RoBERTa batch 1126/2213
# Processed RoBERTa batch 1127/2213
# Processed RoBERTa batch 1128/2213
# Processed RoBERTa batch 1129/2213
# Processed RoBERTa batch 1130/2213
# Processed RoBERTa batch 1131/2213
# Processed RoBERTa batch 1132/2213
# Processed RoBERTa batch 1133/2213
# Processed RoBERTa batch 1134/2213
# Processed RoBERTa batch 1135/2213
# Processed RoBERTa batch 1136/2213
# Processed RoBERTa batch 1137/2213
# Processed RoBERTa batch 1138/2213
# Processed RoBERTa batch 1139/2213
# Processed RoBERTa batch 1140/2213
# Processed RoBERTa batch 1141/2213
# Processed RoBERTa batch 1142/2213
# Processed RoBERTa batch 1143/2213
# Processed RoBERTa batch 1144/2213
# Processed RoBERTa batch 1145/2213
# Processed RoBERTa batch 1146/2213
# Processed RoBERTa batch 1147/2213
# Processed RoBERTa batch 1148/2213
# Processed RoBERTa batch 1149/2213
# Processed RoBERTa batch 1150/2213
# Processed RoBERTa batch 1151/2213
# Processed RoBERTa batch 1152/2213
# Processed RoBERTa batch 1153/2213
# Processed RoBERTa batch 1154/2213
# Processed RoBERTa batch 1155/2213
# Processed RoBERTa batch 1156/2213
# Processed RoBERTa batch 1157/2213
# Processed RoBERTa batch 1158/2213
# Processed RoBERTa batch 1159/2213
# Processed RoBERTa batch 1160/2213
# Processed RoBERTa batch 1161/2213
# Processed RoBERTa batch 1162/2213
# Processed RoBERTa batch 1163/2213
# Processed RoBERTa batch 1164/2213
# Processed RoBERTa batch 1165/2213
# Processed RoBERTa batch 1166/2213
# Processed RoBERTa batch 1167/2213
# Processed RoBERTa batch 1168/2213
# Processed RoBERTa batch 1169/2213
# Processed RoBERTa batch 1170/2213
# Processed RoBERTa batch 1171/2213
# Processed RoBERTa batch 1172/2213
# Processed RoBERTa batch 1173/2213
# Processed RoBERTa batch 1174/2213
# Processed RoBERTa batch 1175/2213
# Processed RoBERTa batch 1176/2213
# Processed RoBERTa batch 1177/2213
# Processed RoBERTa batch 1178/2213
# Processed RoBERTa batch 1179/2213
# Processed RoBERTa batch 1180/2213
# Processed RoBERTa batch 1181/2213
# Processed RoBERTa batch 1182/2213
# Processed RoBERTa batch 1183/2213
# Processed RoBERTa batch 1184/2213
# Processed RoBERTa batch 1185/2213
# Processed RoBERTa batch 1186/2213
# Processed RoBERTa batch 1187/2213
# Processed RoBERTa batch 1188/2213
# Processed RoBERTa batch 1189/2213
# Processed RoBERTa batch 1190/2213
# Processed RoBERTa batch 1191/2213
# Processed RoBERTa batch 1192/2213
# Processed RoBERTa batch 1193/2213
# Processed RoBERTa batch 1194/2213
# Processed RoBERTa batch 1195/2213
# Processed RoBERTa batch 1196/2213
# Processed RoBERTa batch 1197/2213
# Processed RoBERTa batch 1198/2213
# Processed RoBERTa batch 1199/2213
# Processed RoBERTa batch 1200/2213
# Processed RoBERTa batch 1201/2213
# Processed RoBERTa batch 1202/2213
# Processed RoBERTa batch 1203/2213
# Processed RoBERTa batch 1204/2213
# Processed RoBERTa batch 1205/2213
# Processed RoBERTa batch 1206/2213
# Processed RoBERTa batch 1207/2213
# Processed RoBERTa batch 1208/2213
# Processed RoBERTa batch 1209/2213
# Processed RoBERTa batch 1210/2213
# Processed RoBERTa batch 1211/2213
# Processed RoBERTa batch 1212/2213
# Processed RoBERTa batch 1213/2213
# Processed RoBERTa batch 1214/2213
# Processed RoBERTa batch 1215/2213
# Processed RoBERTa batch 1216/2213
# Processed RoBERTa batch 1217/2213
# Processed RoBERTa batch 1218/2213
# Processed RoBERTa batch 1219/2213
# Processed RoBERTa batch 1220/2213
# Processed RoBERTa batch 1221/2213
# Processed RoBERTa batch 1222/2213
# Processed RoBERTa batch 1223/2213
# Processed RoBERTa batch 1224/2213
# Processed RoBERTa batch 1225/2213
# Processed RoBERTa batch 1226/2213
# Processed RoBERTa batch 1227/2213
# Processed RoBERTa batch 1228/2213
# Processed RoBERTa batch 1229/2213
# Processed RoBERTa batch 1230/2213
# Processed RoBERTa batch 1231/2213
# Processed RoBERTa batch 1232/2213
# Processed RoBERTa batch 1233/2213
# Processed RoBERTa batch 1234/2213
# Processed RoBERTa batch 1235/2213
# Processed RoBERTa batch 1236/2213
# Processed RoBERTa batch 1237/2213
# Processed RoBERTa batch 1238/2213
# Processed RoBERTa batch 1239/2213
# Processed RoBERTa batch 1240/2213
# Processed RoBERTa batch 1241/2213
# Processed RoBERTa batch 1242/2213
# Processed RoBERTa batch 1243/2213
# Processed RoBERTa batch 1244/2213
# Processed RoBERTa batch 1245/2213
# Processed RoBERTa batch 1246/2213
# Processed RoBERTa batch 1247/2213
# Processed RoBERTa batch 1248/2213
# Processed RoBERTa batch 1249/2213
# Processed RoBERTa batch 1250/2213
# Processed RoBERTa batch 1251/2213
# Processed RoBERTa batch 1252/2213
# Processed RoBERTa batch 1253/2213
# Processed RoBERTa batch 1254/2213
# Processed RoBERTa batch 1255/2213
# Processed RoBERTa batch 1256/2213
# Processed RoBERTa batch 1257/2213
# Processed RoBERTa batch 1258/2213
# Processed RoBERTa batch 1259/2213
# Processed RoBERTa batch 1260/2213
# Processed RoBERTa batch 1261/2213
# Processed RoBERTa batch 1262/2213
# Processed RoBERTa batch 1263/2213
# Processed RoBERTa batch 1264/2213
# Processed RoBERTa batch 1265/2213
# Processed RoBERTa batch 1266/2213
# Processed RoBERTa batch 1267/2213
# Processed RoBERTa batch 1268/2213
# Processed RoBERTa batch 1269/2213
# Processed RoBERTa batch 1270/2213
# Processed RoBERTa batch 1271/2213
# Processed RoBERTa batch 1272/2213
# Processed RoBERTa batch 1273/2213
# Processed RoBERTa batch 1274/2213
# Processed RoBERTa batch 1275/2213
# Processed RoBERTa batch 1276/2213
# Processed RoBERTa batch 1277/2213
# Processed RoBERTa batch 1278/2213
# Processed RoBERTa batch 1279/2213
# Processed RoBERTa batch 1280/2213
# Processed RoBERTa batch 1281/2213
# Processed RoBERTa batch 1282/2213
# Processed RoBERTa batch 1283/2213
# Processed RoBERTa batch 1284/2213
# Processed RoBERTa batch 1285/2213
# Processed RoBERTa batch 1286/2213
# Processed RoBERTa batch 1287/2213
# Processed RoBERTa batch 1288/2213
# Processed RoBERTa batch 1289/2213
# Processed RoBERTa batch 1290/2213
# Processed RoBERTa batch 1291/2213
# Processed RoBERTa batch 1292/2213
# Processed RoBERTa batch 1293/2213
# Processed RoBERTa batch 1294/2213
# Processed RoBERTa batch 1295/2213
# Processed RoBERTa batch 1296/2213
# Processed RoBERTa batch 1297/2213
# Processed RoBERTa batch 1298/2213
# Processed RoBERTa batch 1299/2213
# Processed RoBERTa batch 1300/2213
# Processed RoBERTa batch 1301/2213
# Processed RoBERTa batch 1302/2213
# Processed RoBERTa batch 1303/2213
# Processed RoBERTa batch 1304/2213
# Processed RoBERTa batch 1305/2213
# Processed RoBERTa batch 1306/2213
# Processed RoBERTa batch 1307/2213
# Processed RoBERTa batch 1308/2213
# Processed RoBERTa batch 1309/2213
# Processed RoBERTa batch 1310/2213
# Processed RoBERTa batch 1311/2213
# Processed RoBERTa batch 1312/2213
# Processed RoBERTa batch 1313/2213
# Processed RoBERTa batch 1314/2213
# Processed RoBERTa batch 1315/2213
# Processed RoBERTa batch 1316/2213
# Processed RoBERTa batch 1317/2213
# Processed RoBERTa batch 1318/2213
# Processed RoBERTa batch 1319/2213
# Processed RoBERTa batch 1320/2213
# Processed RoBERTa batch 1321/2213
# Processed RoBERTa batch 1322/2213
# Processed RoBERTa batch 1323/2213
# Processed RoBERTa batch 1324/2213
# Processed RoBERTa batch 1325/2213
# Processed RoBERTa batch 1326/2213
# Processed RoBERTa batch 1327/2213
# Processed RoBERTa batch 1328/2213
# Processed RoBERTa batch 1329/2213
# Processed RoBERTa batch 1330/2213
# Processed RoBERTa batch 1331/2213
# Processed RoBERTa batch 1332/2213
# Processed RoBERTa batch 1333/2213
# Processed RoBERTa batch 1334/2213
# Processed RoBERTa batch 1335/2213
# Processed RoBERTa batch 1336/2213
# Processed RoBERTa batch 1337/2213
# Processed RoBERTa batch 1338/2213
# Processed RoBERTa batch 1339/2213
# Processed RoBERTa batch 1340/2213
# Processed RoBERTa batch 1341/2213
# Processed RoBERTa batch 1342/2213
# Processed RoBERTa batch 1343/2213
# Processed RoBERTa batch 1344/2213
# Processed RoBERTa batch 1345/2213
# Processed RoBERTa batch 1346/2213
# Processed RoBERTa batch 1347/2213
# Processed RoBERTa batch 1348/2213
# Processed RoBERTa batch 1349/2213
# Processed RoBERTa batch 1350/2213
# Processed RoBERTa batch 1351/2213
# Processed RoBERTa batch 1352/2213
# Processed RoBERTa batch 1353/2213
# Processed RoBERTa batch 1354/2213
# Processed RoBERTa batch 1355/2213
# Processed RoBERTa batch 1356/2213
# Processed RoBERTa batch 1357/2213
# Processed RoBERTa batch 1358/2213
# Processed RoBERTa batch 1359/2213
# Processed RoBERTa batch 1360/2213
# Processed RoBERTa batch 1361/2213
# Processed RoBERTa batch 1362/2213
# Processed RoBERTa batch 1363/2213
# Processed RoBERTa batch 1364/2213
# Processed RoBERTa batch 1365/2213
# Processed RoBERTa batch 1366/2213
# Processed RoBERTa batch 1367/2213
# Processed RoBERTa batch 1368/2213
# Processed RoBERTa batch 1369/2213
# Processed RoBERTa batch 1370/2213
# Processed RoBERTa batch 1371/2213
# Processed RoBERTa batch 1372/2213
# Processed RoBERTa batch 1373/2213
# Processed RoBERTa batch 1374/2213
# Processed RoBERTa batch 1375/2213
# Processed RoBERTa batch 1376/2213
# Processed RoBERTa batch 1377/2213
# Processed RoBERTa batch 1378/2213
# Processed RoBERTa batch 1379/2213
# Processed RoBERTa batch 1380/2213
# Processed RoBERTa batch 1381/2213
# Processed RoBERTa batch 1382/2213
# Processed RoBERTa batch 1383/2213
# Processed RoBERTa batch 1384/2213
# Processed RoBERTa batch 1385/2213
# Processed RoBERTa batch 1386/2213
# Processed RoBERTa batch 1387/2213
# Processed RoBERTa batch 1388/2213
# Processed RoBERTa batch 1389/2213
# Processed RoBERTa batch 1390/2213
# Processed RoBERTa batch 1391/2213
# Processed RoBERTa batch 1392/2213
# Processed RoBERTa batch 1393/2213
# Processed RoBERTa batch 1394/2213
# Processed RoBERTa batch 1395/2213
# Processed RoBERTa batch 1396/2213
# Processed RoBERTa batch 1397/2213
# Processed RoBERTa batch 1398/2213
# Processed RoBERTa batch 1399/2213
# Processed RoBERTa batch 1400/2213
# Processed RoBERTa batch 1401/2213
# Processed RoBERTa batch 1402/2213
# Processed RoBERTa batch 1403/2213
# Processed RoBERTa batch 1404/2213
# Processed RoBERTa batch 1405/2213
# Processed RoBERTa batch 1406/2213
# Processed RoBERTa batch 1407/2213
# Processed RoBERTa batch 1408/2213
# Processed RoBERTa batch 1409/2213
# Processed RoBERTa batch 1410/2213
# Processed RoBERTa batch 1411/2213
# Processed RoBERTa batch 1412/2213
# Processed RoBERTa batch 1413/2213
# Processed RoBERTa batch 1414/2213
# Processed RoBERTa batch 1415/2213
# Processed RoBERTa batch 1416/2213
# Processed RoBERTa batch 1417/2213
# Processed RoBERTa batch 1418/2213
# Processed RoBERTa batch 1419/2213
# Processed RoBERTa batch 1420/2213
# Processed RoBERTa batch 1421/2213
# Processed RoBERTa batch 1422/2213
# Processed RoBERTa batch 1423/2213
# Processed RoBERTa batch 1424/2213
# Processed RoBERTa batch 1425/2213
# Processed RoBERTa batch 1426/2213
# Processed RoBERTa batch 1427/2213
# Processed RoBERTa batch 1428/2213
# Processed RoBERTa batch 1429/2213
# Processed RoBERTa batch 1430/2213
# Processed RoBERTa batch 1431/2213
# Processed RoBERTa batch 1432/2213
# Processed RoBERTa batch 1433/2213
# Processed RoBERTa batch 1434/2213
# Processed RoBERTa batch 1435/2213
# Processed RoBERTa batch 1436/2213
# Processed RoBERTa batch 1437/2213
# Processed RoBERTa batch 1438/2213
# Processed RoBERTa batch 1439/2213
# Processed RoBERTa batch 1440/2213
# Processed RoBERTa batch 1441/2213
# Processed RoBERTa batch 1442/2213
# Processed RoBERTa batch 1443/2213
# Processed RoBERTa batch 1444/2213
# ...
# Processed RoBERTa batch 1745/2213
# Processed RoBERTa batch 1746/2213
# Processed RoBERTa batch 1747/2213
# Processed RoBERTa batch 1748/2213
# Processed RoBERTa batch 1749/2213
# Processed RoBERTa batch 1750/2213
# Processed RoBERTa batch 1751/2213
# Processed RoBERTa batch 1752/2213
# Processed RoBERTa batch 1753/2213
# Processed RoBERTa batch 1754/2213
# Processed RoBERTa batch 1755/2213
# Processed RoBERTa batch 1756/2213
# Processed RoBERTa batch 1757/2213
# Processed RoBERTa batch 1758/2213
# Processed RoBERTa batch 1759/2213
# Processed RoBERTa batch 1760/2213
# Processed RoBERTa batch 1761/2213
# Processed RoBERTa batch 1762/2213
# Processed RoBERTa batch 1763/2213
# Processed RoBERTa batch 1764/2213
# Processed RoBERTa batch 1765/2213
# Processed RoBERTa batch 1766/2213
# Processed RoBERTa batch 1767/2213
# Processed RoBERTa batch 1768/2213
# Processed RoBERTa batch 1769/2213
# Processed RoBERTa batch 1770/2213
# Processed RoBERTa batch 1771/2213
# Processed RoBERTa batch 1772/2213
# Processed RoBERTa batch 1773/2213
# Processed RoBERTa batch 1774/2213
# Processed RoBERTa batch 1775/2213
# Processed RoBERTa batch 1776/2213
# Processed RoBERTa batch 1777/2213
# Processed RoBERTa batch 1778/2213
# Processed RoBERTa batch 1779/2213
# Processed RoBERTa batch 1780/2213
# Processed RoBERTa batch 1781/2213
# Processed RoBERTa batch 1782/2213
# Processed RoBERTa batch 1783/2213
# Processed RoBERTa batch 1784/2213
# Processed RoBERTa batch 1785/2213
# Processed RoBERTa batch 1786/2213
# Processed RoBERTa batch 1787/2213
# Processed RoBERTa batch 1788/2213
# Processed RoBERTa batch 1789/2213
# Processed RoBERTa batch 1790/2213
# Processed RoBERTa batch 1791/2213
# Processed RoBERTa batch 1792/2213
# Processed RoBERTa batch 1793/2213
# Processed RoBERTa batch 1794/2213
# Processed RoBERTa batch 1795/2213
# Processed RoBERTa batch 1796/2213
# Processed RoBERTa batch 1797/2213
# Processed RoBERTa batch 1798/2213
# Processed RoBERTa batch 1799/2213
# Processed RoBERTa batch 1800/2213
# Processed RoBERTa batch 1801/2213
# Processed RoBERTa batch 1802/2213
# Processed RoBERTa batch 1803/2213
# Processed RoBERTa batch 1804/2213
# Processed RoBERTa batch 1805/2213
# Processed RoBERTa batch 1806/2213
# Processed RoBERTa batch 1807/2213
# Processed RoBERTa batch 1808/2213
# Processed RoBERTa batch 1809/2213
# Processed RoBERTa batch 1810/2213
# Processed RoBERTa batch 1811/2213
# Processed RoBERTa batch 1812/2213
# Processed RoBERTa batch 1813/2213
# Processed RoBERTa batch 1814/2213
# Processed RoBERTa batch 1815/2213
# Processed RoBERTa batch 1816/2213
# Processed RoBERTa batch 1817/2213
# Processed RoBERTa batch 1818/2213
# Processed RoBERTa batch 1819/2213
# Processed RoBERTa batch 1820/2213
# Processed RoBERTa batch 1821/2213
# Processed RoBERTa batch 1822/2213
# Processed RoBERTa batch 1823/2213
# Processed RoBERTa batch 1824/2213
# Processed RoBERTa batch 1825/2213
# Processed RoBERTa batch 1826/2213
# Processed RoBERTa batch 1827/2213
# Processed RoBERTa batch 1828/2213
# Processed RoBERTa batch 1829/2213
# Processed RoBERTa batch 1830/2213
# Processed RoBERTa batch 1831/2213
# Processed RoBERTa batch 1832/2213
# Processed RoBERTa batch 1833/2213
# Processed RoBERTa batch 1834/2213
# Processed RoBERTa batch 1835/2213
# Processed RoBERTa batch 1836/2213
# Processed RoBERTa batch 1837/2213
# Processed RoBERTa batch 1838/2213
# Processed RoBERTa batch 1839/2213
# Processed RoBERTa batch 1840/2213
# Processed RoBERTa batch 1841/2213
# Processed RoBERTa batch 1842/2213
# Processed RoBERTa batch 1843/2213
# Processed RoBERTa batch 1844/2213
# Processed RoBERTa batch 1845/2213
# Processed RoBERTa batch 1846/2213
# Processed RoBERTa batch 1847/2213
# Processed RoBERTa batch 1848/2213
# Processed RoBERTa batch 1849/2213
# Processed RoBERTa batch 1850/2213
# Processed RoBERTa batch 1851/2213
# Processed RoBERTa batch 1852/2213
# Processed RoBERTa batch 1853/2213
# Processed RoBERTa batch 1854/2213
# Processed RoBERTa batch 1855/2213
# Processed RoBERTa batch 1856/2213
# Processed RoBERTa batch 1857/2213
# Processed RoBERTa batch 1858/2213
# Processed RoBERTa batch 1859/2213
# Processed RoBERTa batch 1860/2213
# Processed RoBERTa batch 1861/2213
# Processed RoBERTa batch 1862/2213
# Processed RoBERTa batch 1863/2213
# Processed RoBERTa batch 1864/2213
# Processed RoBERTa batch 1865/2213
# Processed RoBERTa batch 1866/2213
# Processed RoBERTa batch 1867/2213
# Processed RoBERTa batch 1868/2213
# Processed RoBERTa batch 1869/2213
# Processed RoBERTa batch 1870/2213
# Processed RoBERTa batch 1871/2213
# Processed RoBERTa batch 1872/2213
# Processed RoBERTa batch 1873/2213
# Processed RoBERTa batch 1874/2213
# Processed RoBERTa batch 1875/2213
# Processed RoBERTa batch 1876/2213
# Processed RoBERTa batch 1877/2213
# Processed RoBERTa batch 1878/2213
# Processed RoBERTa batch 1879/2213
# Processed RoBERTa batch 1880/2213
# Processed RoBERTa batch 1881/2213
# Processed RoBERTa batch 1882/2213
# Processed RoBERTa batch 1883/2213
# Processed RoBERTa batch 1884/2213
# Processed RoBERTa batch 1885/2213
# Processed RoBERTa batch 1886/2213
# Processed RoBERTa batch 1887/2213
# Processed RoBERTa batch 1888/2213
# Processed RoBERTa batch 1889/2213
# Processed RoBERTa batch 1890/2213
# Processed RoBERTa batch 1891/2213
# Processed RoBERTa batch 1892/2213
# Processed RoBERTa batch 1893/2213
# Processed RoBERTa batch 1894/2213
# Processed RoBERTa batch 1895/2213
# Processed RoBERTa batch 1896/2213
# Processed RoBERTa batch 1897/2213
# Processed RoBERTa batch 1898/2213
# Processed RoBERTa batch 1899/2213
# Processed RoBERTa batch 1900/2213
# Processed RoBERTa batch 1901/2213
# Processed RoBERTa batch 1902/2213
# Processed RoBERTa batch 1903/2213
# Processed RoBERTa batch 1904/2213
# Processed RoBERTa batch 1905/2213
# Processed RoBERTa batch 1906/2213
# Processed RoBERTa batch 1907/2213
# Processed RoBERTa batch 1908/2213
# Processed RoBERTa batch 1909/2213
# Processed RoBERTa batch 1910/2213
# Processed RoBERTa batch 1911/2213
# Processed RoBERTa batch 1912/2213
# Processed RoBERTa batch 1913/2213
# Processed RoBERTa batch 1914/2213
# Processed RoBERTa batch 1915/2213
# Processed RoBERTa batch 1916/2213
# Processed RoBERTa batch 1917/2213
# Processed RoBERTa batch 1918/2213
# Processed RoBERTa batch 1919/2213
# Processed RoBERTa batch 1920/2213
# Processed RoBERTa batch 1921/2213
# Processed RoBERTa batch 1922/2213
# Processed RoBERTa batch 1923/2213
# Processed RoBERTa batch 1924/2213
# Processed RoBERTa batch 1925/2213
# Processed RoBERTa batch 1926/2213
# Processed RoBERTa batch 1927/2213
# Processed RoBERTa batch 1928/2213
# Processed RoBERTa batch 1929/2213
# Processed RoBERTa batch 1930/2213
# Processed RoBERTa batch 1931/2213
# Processed RoBERTa batch 1932/2213
# Processed RoBERTa batch 1933/2213
# Processed RoBERTa batch 1934/2213
# Processed RoBERTa batch 1935/2213
# Processed RoBERTa batch 1936/2213
# Processed RoBERTa batch 1937/2213
# Processed RoBERTa batch 1938/2213
# Processed RoBERTa batch 1939/2213
# Processed RoBERTa batch 1940/2213
# Processed RoBERTa batch 1941/2213
# Processed RoBERTa batch 1942/2213
# Processed RoBERTa batch 1943/2213
# Processed RoBERTa batch 1944/2213
# Processed RoBERTa batch 1945/2213
# Processed RoBERTa batch 1946/2213
# Processed RoBERTa batch 1947/2213
# Processed RoBERTa batch 1948/2213
# Processed RoBERTa batch 1949/2213
# Processed RoBERTa batch 1950/2213
# Processed RoBERTa batch 1951/2213
# Processed RoBERTa batch 1952/2213
# Processed RoBERTa batch 1953/2213
# Processed RoBERTa batch 1954/2213
# Processed RoBERTa batch 1955/2213
# Processed RoBERTa batch 1956/2213
# Processed RoBERTa batch 1957/2213
# Processed RoBERTa batch 1958/2213
# Processed RoBERTa batch 1959/2213
# Processed RoBERTa batch 1960/2213
# Processed RoBERTa batch 1961/2213
# Processed RoBERTa batch 1962/2213
# Processed RoBERTa batch 1963/2213
# Processed RoBERTa batch 1964/2213
# Processed RoBERTa batch 1965/2213
# Processed RoBERTa batch 1966/2213
# Processed RoBERTa batch 1967/2213
# Processed RoBERTa batch 1968/2213
# Processed RoBERTa batch 1969/2213
# Processed RoBERTa batch 1970/2213
# Processed RoBERTa batch 1971/2213
# Processed RoBERTa batch 1972/2213
# Processed RoBERTa batch 1973/2213
# Processed RoBERTa batch 1974/2213
# Processed RoBERTa batch 1975/2213
# Processed RoBERTa batch 1976/2213
# Processed RoBERTa batch 1977/2213
# Processed RoBERTa batch 1978/2213
# Processed RoBERTa batch 1979/2213
# Processed RoBERTa batch 1980/2213
# Processed RoBERTa batch 1981/2213
# Processed RoBERTa batch 1982/2213
# Processed RoBERTa batch 1983/2213
# Processed RoBERTa batch 1984/2213
# Processed RoBERTa batch 1985/2213
# Processed RoBERTa batch 1986/2213
# Processed RoBERTa batch 1987/2213
# Processed RoBERTa batch 1988/2213
# Processed RoBERTa batch 1989/2213
# Processed RoBERTa batch 1990/2213
# Processed RoBERTa batch 1991/2213
# Processed RoBERTa batch 1992/2213
# Processed RoBERTa batch 1993/2213
# Processed RoBERTa batch 1994/2213
# Processed RoBERTa batch 1995/2213
# Processed RoBERTa batch 1996/2213
# Processed RoBERTa batch 1997/2213
# Processed RoBERTa batch 1998/2213
# Processed RoBERTa batch 1999/2213
# Processed RoBERTa batch 2000/2213
# Processed RoBERTa batch 2001/2213
# Processed RoBERTa batch 2002/2213
# Processed RoBERTa batch 2003/2213
# Processed RoBERTa batch 2004/2213
# Processed RoBERTa batch 2005/2213
# Processed RoBERTa batch 2006/2213
# Processed RoBERTa batch 2007/2213
# Processed RoBERTa batch 2008/2213
# Processed RoBERTa batch 2009/2213
# Processed RoBERTa batch 2010/2213
# Processed RoBERTa batch 2011/2213
# Processed RoBERTa batch 2012/2213
# Processed RoBERTa batch 2013/2213
# Processed RoBERTa batch 2014/2213
# Processed RoBERTa batch 2015/2213
# Processed RoBERTa batch 2016/2213
# Processed RoBERTa batch 2017/2213
# Processed RoBERTa batch 2018/2213
# Processed RoBERTa batch 2019/2213
# Processed RoBERTa batch 2020/2213
# Processed RoBERTa batch 2021/2213
# Processed RoBERTa batch 2022/2213
# Processed RoBERTa batch 2023/2213
# Processed RoBERTa batch 2024/2213
# Processed RoBERTa batch 2025/2213
# Processed RoBERTa batch 2026/2213
# Processed RoBERTa batch 2027/2213
# Processed RoBERTa batch 2028/2213
# Processed RoBERTa batch 2029/2213
# Processed RoBERTa batch 2030/2213
# Processed RoBERTa batch 2031/2213
# Processed RoBERTa batch 2032/2213
# Processed RoBERTa batch 2033/2213
# Processed RoBERTa batch 2034/2213
# Processed RoBERTa batch 2035/2213
# Processed RoBERTa batch 2036/2213
# Processed RoBERTa batch 2037/2213
# Processed RoBERTa batch 2038/2213
# Processed RoBERTa batch 2039/2213
# Processed RoBERTa batch 2040/2213
# Processed RoBERTa batch 2041/2213
# Processed RoBERTa batch 2042/2213
# Processed RoBERTa batch 2043/2213
# Processed RoBERTa batch 2044/2213
# Processed RoBERTa batch 2045/2213
# Processed RoBERTa batch 2046/2213
# Processed RoBERTa batch 2047/2213
# Processed RoBERTa batch 2048/2213
# Processed RoBERTa batch 2049/2213
# Processed RoBERTa batch 2050/2213
# Processed RoBERTa batch 2051/2213
# Processed RoBERTa batch 2052/2213
# Processed RoBERTa batch 2053/2213
# Processed RoBERTa batch 2054/2213
# Processed RoBERTa batch 2055/2213
# Processed RoBERTa batch 2056/2213
# Processed RoBERTa batch 2057/2213
# Processed RoBERTa batch 2058/2213
# Processed RoBERTa batch 2059/2213
# Processed RoBERTa batch 2060/2213
# Processed RoBERTa batch 2061/2213
# Processed RoBERTa batch 2062/2213
# Processed RoBERTa batch 2063/2213
# Processed RoBERTa batch 2064/2213
# Processed RoBERTa batch 2065/2213
# Processed RoBERTa batch 2066/2213
# Processed RoBERTa batch 2067/2213
# Processed RoBERTa batch 2068/2213
# Processed RoBERTa batch 2069/2213
# Processed RoBERTa batch 2070/2213
# Processed RoBERTa batch 2071/2213
# Processed RoBERTa batch 2072/2213
# Processed RoBERTa batch 2073/2213
# Processed RoBERTa batch 2074/2213
# Processed RoBERTa batch 2075/2213
# Processed RoBERTa batch 2076/2213
# Processed RoBERTa batch 2077/2213
# Processed RoBERTa batch 2078/2213
# Processed RoBERTa batch 2079/2213
# Processed RoBERTa batch 2080/2213
# Processed RoBERTa batch 2081/2213
# Processed RoBERTa batch 2082/2213
# Processed RoBERTa batch 2083/2213
# Processed RoBERTa batch 2084/2213
# Processed RoBERTa batch 2085/2213
# Processed RoBERTa batch 2086/2213
# Processed RoBERTa batch 2087/2213
# Processed RoBERTa batch 2088/2213
# Processed RoBERTa batch 2089/2213
# Processed RoBERTa batch 2090/2213
# Processed RoBERTa batch 2091/2213
# Processed RoBERTa batch 2092/2213
# Processed RoBERTa batch 2093/2213
# Processed RoBERTa batch 2094/2213
# Processed RoBERTa batch 2095/2213
# Processed RoBERTa batch 2096/2213
# Processed RoBERTa batch 2097/2213
# Processed RoBERTa batch 2098/2213
# Processed RoBERTa batch 2099/2213
# Processed RoBERTa batch 2100/2213
# Processed RoBERTa batch 2101/2213
# Processed RoBERTa batch 2102/2213
# Processed RoBERTa batch 2103/2213
# Processed RoBERTa batch 2104/2213
# Processed RoBERTa batch 2105/2213
# Processed RoBERTa batch 2106/2213
# Processed RoBERTa batch 2107/2213
# Processed RoBERTa batch 2108/2213
# Processed RoBERTa batch 2109/2213
# Processed RoBERTa batch 2110/2213
# Processed RoBERTa batch 2111/2213
# Processed RoBERTa batch 2112/2213
# Processed RoBERTa batch 2113/2213
# Processed RoBERTa batch 2114/2213
# Processed RoBERTa batch 2115/2213
# Processed RoBERTa batch 2116/2213
# Processed RoBERTa batch 2117/2213
# Processed RoBERTa batch 2118/2213
# Processed RoBERTa batch 2119/2213
# Processed RoBERTa batch 2120/2213
# Processed RoBERTa batch 2121/2213
# Processed RoBERTa batch 2122/2213
# Processed RoBERTa batch 2123/2213
# Processed RoBERTa batch 2124/2213
# Processed RoBERTa batch 2125/2213
# Processed RoBERTa batch 2126/2213
# Processed RoBERTa batch 2127/2213
# Processed RoBERTa batch 2128/2213
# Processed RoBERTa batch 2129/2213
# Processed RoBERTa batch 2130/2213
# Processed RoBERTa batch 2131/2213
# Processed RoBERTa batch 2132/2213
# Processed RoBERTa batch 2133/2213
# Processed RoBERTa batch 2134/2213
# Processed RoBERTa batch 2135/2213
# Processed RoBERTa batch 2136/2213
# Processed RoBERTa batch 2137/2213
# Processed RoBERTa batch 2138/2213
# Processed RoBERTa batch 2139/2213
# Processed RoBERTa batch 2140/2213
# Processed RoBERTa batch 2141/2213
# Processed RoBERTa batch 2142/2213
# Processed RoBERTa batch 2143/2213
# Processed RoBERTa batch 2144/2213
# Processed RoBERTa batch 2145/2213
# Processed RoBERTa batch 2146/2213
# Processed RoBERTa batch 2147/2213
# Processed RoBERTa batch 2148/2213
# Processed RoBERTa batch 2149/2213
# Processed RoBERTa batch 2150/2213
# Processed RoBERTa batch 2151/2213
# Processed RoBERTa batch 2152/2213
# Processed RoBERTa batch 2153/2213
# Processed RoBERTa batch 2154/2213
# Processed RoBERTa batch 2155/2213
# Processed RoBERTa batch 2156/2213
# Processed RoBERTa batch 2157/2213
# Processed RoBERTa batch 2158/2213
# Processed RoBERTa batch 2159/2213
# Processed RoBERTa batch 2160/2213
# Processed RoBERTa batch 2161/2213
# Processed RoBERTa batch 2162/2213
# Processed RoBERTa batch 2163/2213
# Processed RoBERTa batch 2164/2213
# Processed RoBERTa batch 2165/2213
# Processed RoBERTa batch 2166/2213
# Processed RoBERTa batch 2167/2213
# Processed RoBERTa batch 2168/2213
# Processed RoBERTa batch 2169/2213
# Processed RoBERTa batch 2170/2213
# Processed RoBERTa batch 2171/2213
# Processed RoBERTa batch 2172/2213
# Processed RoBERTa batch 2173/2213
# Processed RoBERTa batch 2174/2213
# Processed RoBERTa batch 2175/2213
# Processed RoBERTa batch 2176/2213
# Processed RoBERTa batch 2177/2213
# Processed RoBERTa batch 2178/2213
# Processed RoBERTa batch 2179/2213
# Processed RoBERTa batch 2180/2213
# Processed RoBERTa batch 2181/2213
# Processed RoBERTa batch 2182/2213
# Processed RoBERTa batch 2183/2213
# Processed RoBERTa batch 2184/2213
# Processed RoBERTa batch 2185/2213
# Processed RoBERTa batch 2186/2213
# Processed RoBERTa batch 2187/2213
# Processed RoBERTa batch 2188/2213
# Processed RoBERTa batch 2189/2213
# Processed RoBERTa batch 2190/2213
# Processed RoBERTa batch 2191/2213
# Processed RoBERTa batch 2192/2213
# Processed RoBERTa batch 2193/2213
# Processed RoBERTa batch 2194/2213
# Processed RoBERTa batch 2195/2213
# Processed RoBERTa batch 2196/2213
# Processed RoBERTa batch 2197/2213
# Processed RoBERTa batch 2198/2213
# Processed RoBERTa batch 2199/2213
# Processed RoBERTa batch 2200/2213
# Processed RoBERTa batch 2201/2213
# Processed RoBERTa batch 2202/2213
# Processed RoBERTa batch 2203/2213
# Processed RoBERTa batch 2204/2213
# Processed RoBERTa batch 2205/2213
# Processed RoBERTa batch 2206/2213
# Processed RoBERTa batch 2207/2213
# Processed RoBERTa batch 2208/2213
# Processed RoBERTa batch 2209/2213
# Processed RoBERTa batch 2210/2213
# Processed RoBERTa batch 2211/2213
# Processed RoBERTa batch 2212/2213
# Processed RoBERTa batch 2213/2213
# RoBERTa embeddings shape: (70793, 768)

# %%
# Save to parquet (can handle the string-encoded embeddings)
# cleaned_data.to_parquet('cleaned_welfake_with_embeddings.parquet')

# %%
# If you need it To load later:
# def load_data():
#     return pd.read_parquet('cleaned_welfake_with_embeddings.parquet')

# %% [markdown]
# ##### BOW

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
bow_vectorizer = CountVectorizer(max_features=5000, stop_words='english')
bow_embeddings = bow_vectorizer.fit_transform(cleaned_data['text'])

cleaned_data['bow_embedding'] = [sparse_to_string(bow_embeddings[i]) for i in range(bow_embeddings.shape[0])]
print("BOW embeddings shape:", bow_embeddings.shape)
# Out:
# BOW embeddings shape: (70793, 5000)

# %%
display(bow_embeddings)
# Out:
# <70793x5000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 10509868 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ##### BOW TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')
tfidf_embeddings = tfidf_vectorizer.fit_transform(cleaned_data['text'])

cleaned_data['tfidf_embedding'] = [sparse_to_string(tfidf_embeddings[i]) for i in range(tfidf_embeddings.shape[0])]
print("TF-IDF embeddings shape:", tfidf_embeddings.shape)
# Out:
# <70793x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10509868 stored elements in Compressed Sparse Row format>

# %%
# Out:
# TF-IDF embeddings shape: (70793, 5000)

# %% [markdown]
#  ##### CBOW-W2V

# %%
cleaned_data_copy = cleaned_data.copy()
cleaned_data_copy['tokens'] = cleaned_data_copy['text'].apply(lambda x: x.split())
w2v_model = Word2Vec(sentences=cleaned_data_copy['tokens'], vector_size=100, window=5, min_count=5, sg=0, seed=42)
def get_w2v_embedding(tokens, model):
    vectors = [model.wv[token] for token in tokens if token in model.wv]
    return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

w2v_embeddings = np.array([get_w2v_embedding(tokens, w2v_model) for tokens in cleaned_data_copy['tokens']])
cleaned_data['w2v_embedding'] = [array_to_string(arr) for arr in w2v_embeddings]
print("Word2Vec embeddings shape:", w2v_embeddings.shape)
# Out:
# Word2Vec embeddings shape: (70793, 100)

# %% [markdown]
# ##### Push to Hub

# %%
cleaned_data.to_parquet('cleaned_welfake_with_embeddings.parquet_final')

# %%
from datasets import Dataset
import pandas as pd

output_data = Dataset.from_pandas(cleaned_data)
login(token="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")
output_data.push_to_hub("Paulozs/WELFake_embeddings")
# Out:
# Uploading the dataset shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/36 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   0%|          | 0/36 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Paulozs/WELFake_embeddings/commit/87edba4053edab11be0d13067840c37fa7337f1e', commit_message='Upload dataset', commit_description='', oid='87edba4053edab11be0d13067840c37fa7337f1e', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Paulozs/WELFake_embeddings', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Paulozs/WELFake_embeddings'), pr_revision=None, pr_num=None)
