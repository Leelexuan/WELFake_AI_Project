# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader
import torch
import warnings
from transformers import AutoModel, AutoTokenizer
import torch
import joblib
import base64
from huggingface_hub import login, HfApi
from gensim.models import Word2Vec
warnings.filterwarnings('ignore')

# %%
# Define device for torch
use_cuda = True
print("CUDA is available:", torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# CUDA is available: True

# %%
from datasets import load_dataset

dataset = load_dataset("davanstrien/WELFake")
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'text', 'label'],
#         num_rows: 72134
#     })
# })

# %%
from collections import Counter

data = dataset["train"].to_pandas()

print("\nData shape:", data.shape)
print("\nSample of training data:")
display(data.head(3))
# Out:
# Data shape: (72134, 3)
#
# Sample of training data:
#                                                title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1                                               None
# 2  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
#
#                                                 text  label
# 0  No comment is expected from Barack Obama Membe...      1
# 1     Did they post their votes for Hillary already?      1
# 2   Now, most of the demonstrators gathered last ...      1

# %% [markdown]
# ### Remove Empty Text Sections

# %%
cleaned_data = data.dropna(subset=['text', 'title'])
cleaned_data.drop_duplicates(inplace=True)
# rmve all columns where body text is just whitespace
cleaned_data = cleaned_data[cleaned_data['text'].str.strip().str.len() > 0]
# #drop duplicates


# Print before and after to verify
print(f"Original data shape: {data.shape}")
print(f"After removing NaNs and whitespace-only rows: {cleaned_data.shape}")
cleaned_data = cleaned_data.reset_index(drop=True)
# Out:
# Original data shape: (72134, 3)
# After removing NaNs and whitespace-only rows: (62592, 3)

# %% [markdown]
# ### Generate Embeddings

# %%
def array_to_string(arr):
    return base64.b64encode(arr.tobytes()).decode('utf-8')

# %%
def sparse_to_string(sparse_mat):
    csr = sparse_mat.tocsr()
    data = base64.b64encode(csr.data.tobytes()).decode('utf-8')
    indices = base64.b64encode(csr.indices.tobytes()).decode('utf-8')
    indptr = base64.b64encode(csr.indptr.tobytes()).decode('utf-8')
    shape = f"{csr.shape[0]},{csr.shape[1]}"
    return f"{data}|{indices}|{indptr}|{shape}"

# %% [markdown]
# ##### Roberta

# %%
tokenizer = AutoTokenizer.from_pretrained("roberta-base")
model = AutoModel.from_pretrained("roberta-base")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# RobertaModel(
#   (embeddings): RobertaEmbeddings(
#     (word_embeddings): Embedding(50265, 768, padding_idx=1)
#     (position_embeddings): Embedding(514, 768, padding_idx=1)
#     (token_type_embeddings): Embedding(1, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): RobertaEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x RobertaLayer(
#         (attention): RobertaAttention(
#           (self): RobertaSdpaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): RobertaSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): RobertaIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): RobertaOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): RobertaPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def get_roberta_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().cpu().numpy()

# %%
batch_size = 32
roberta_embeddings = []
for i in range(0, len(cleaned_data), batch_size):
    batch_texts = cleaned_data['text'][i:i+batch_size].tolist()
    batch_embeds = [get_roberta_embedding(text) for text in batch_texts]
    roberta_embeddings.extend(batch_embeds)
    print(f"Processed RoBERTa batch {i//batch_size + 1}/{len(cleaned_data)//batch_size + 1}")
# Out:
# Processed RoBERTa batch 1/1957
# Processed RoBERTa batch 2/1957
# Processed RoBERTa batch 3/1957
# Processed RoBERTa batch 4/1957
# Processed RoBERTa batch 5/1957
# Processed RoBERTa batch 6/1957
# Processed RoBERTa batch 7/1957
# Processed RoBERTa batch 8/1957
# Processed RoBERTa batch 9/1957
# Processed RoBERTa batch 10/1957
# Processed RoBERTa batch 11/1957
# Processed RoBERTa batch 12/1957
# Processed RoBERTa batch 13/1957
# Processed RoBERTa batch 14/1957
# Processed RoBERTa batch 15/1957
# Processed RoBERTa batch 16/1957
# Processed RoBERTa batch 17/1957
# Processed RoBERTa batch 18/1957
# Processed RoBERTa batch 19/1957
# Processed RoBERTa batch 20/1957
# Processed RoBERTa batch 21/1957
# Processed RoBERTa batch 22/1957
# Processed RoBERTa batch 23/1957
# Processed RoBERTa batch 24/1957
# Processed RoBERTa batch 25/1957
# Processed RoBERTa batch 26/1957
# Processed RoBERTa batch 27/1957
# Processed RoBERTa batch 28/1957
# Processed RoBERTa batch 29/1957
# Processed RoBERTa batch 30/1957
# Processed RoBERTa batch 31/1957
# Processed RoBERTa batch 32/1957
# Processed RoBERTa batch 33/1957
# Processed RoBERTa batch 34/1957
# Processed RoBERTa batch 35/1957
# Processed RoBERTa batch 36/1957
# Processed RoBERTa batch 37/1957
# Processed RoBERTa batch 38/1957
# Processed RoBERTa batch 39/1957
# Processed RoBERTa batch 40/1957
# Processed RoBERTa batch 41/1957
# Processed RoBERTa batch 42/1957
# Processed RoBERTa batch 43/1957
# Processed RoBERTa batch 44/1957
# Processed RoBERTa batch 45/1957
# Processed RoBERTa batch 46/1957
# Processed RoBERTa batch 47/1957
# Processed RoBERTa batch 48/1957
# Processed RoBERTa batch 49/1957
# Processed RoBERTa batch 50/1957
# Processed RoBERTa batch 51/1957
# Processed RoBERTa batch 52/1957
# Processed RoBERTa batch 53/1957
# Processed RoBERTa batch 54/1957
# Processed RoBERTa batch 55/1957
# Processed RoBERTa batch 56/1957
# Processed RoBERTa batch 57/1957
# Processed RoBERTa batch 58/1957
# Processed RoBERTa batch 59/1957
# Processed RoBERTa batch 60/1957
# Processed RoBERTa batch 61/1957
# Processed RoBERTa batch 62/1957
# Processed RoBERTa batch 63/1957
# Processed RoBERTa batch 64/1957
# Processed RoBERTa batch 65/1957
# Processed RoBERTa batch 66/1957
# Processed RoBERTa batch 67/1957
# Processed RoBERTa batch 68/1957
# Processed RoBERTa batch 69/1957
# Processed RoBERTa batch 70/1957
# Processed RoBERTa batch 71/1957
# Processed RoBERTa batch 72/1957
# Processed RoBERTa batch 73/1957
# Processed RoBERTa batch 74/1957
# Processed RoBERTa batch 75/1957
# Processed RoBERTa batch 76/1957
# Processed RoBERTa batch 77/1957
# Processed RoBERTa batch 78/1957
# Processed RoBERTa batch 79/1957
# Processed RoBERTa batch 80/1957
# Processed RoBERTa batch 81/1957
# Processed RoBERTa batch 82/1957
# Processed RoBERTa batch 83/1957
# Processed RoBERTa batch 84/1957
# Processed RoBERTa batch 85/1957
# Processed RoBERTa batch 86/1957
# Processed RoBERTa batch 87/1957
# Processed RoBERTa batch 88/1957
# Processed RoBERTa batch 89/1957
# Processed RoBERTa batch 90/1957
# Processed RoBERTa batch 91/1957
# Processed RoBERTa batch 92/1957
# Processed RoBERTa batch 93/1957
# Processed RoBERTa batch 94/1957
# Processed RoBERTa batch 95/1957
# Processed RoBERTa batch 96/1957
# Processed RoBERTa batch 97/1957
# Processed RoBERTa batch 98/1957
# Processed RoBERTa batch 99/1957
# Processed RoBERTa batch 100/1957
# Processed RoBERTa batch 101/1957
# Processed RoBERTa batch 102/1957
# Processed RoBERTa batch 103/1957
# Processed RoBERTa batch 104/1957
# Processed RoBERTa batch 105/1957
# Processed RoBERTa batch 106/1957
# Processed RoBERTa batch 107/1957
# Processed RoBERTa batch 108/1957
# Processed RoBERTa batch 109/1957
# Processed RoBERTa batch 110/1957
# Processed RoBERTa batch 111/1957
# Processed RoBERTa batch 112/1957
# Processed RoBERTa batch 113/1957
# Processed RoBERTa batch 114/1957
# Processed RoBERTa batch 115/1957
# Processed RoBERTa batch 116/1957
# Processed RoBERTa batch 117/1957
# Processed RoBERTa batch 118/1957
# Processed RoBERTa batch 119/1957
# Processed RoBERTa batch 120/1957
# Processed RoBERTa batch 121/1957
# Processed RoBERTa batch 122/1957
# Processed RoBERTa batch 123/1957
# Processed RoBERTa batch 124/1957
# Processed RoBERTa batch 125/1957
# Processed RoBERTa batch 126/1957
# Processed RoBERTa batch 127/1957
# Processed RoBERTa batch 128/1957
# Processed RoBERTa batch 129/1957
# Processed RoBERTa batch 130/1957
# Processed RoBERTa batch 131/1957
# Processed RoBERTa batch 132/1957
# Processed RoBERTa batch 133/1957
# Processed RoBERTa batch 134/1957
# Processed RoBERTa batch 135/1957
# Processed RoBERTa batch 136/1957
# Processed RoBERTa batch 137/1957
# Processed RoBERTa batch 138/1957
# Processed RoBERTa batch 139/1957
# Processed RoBERTa batch 140/1957
# Processed RoBERTa batch 141/1957
# Processed RoBERTa batch 142/1957
# Processed RoBERTa batch 143/1957
# Processed RoBERTa batch 144/1957
# Processed RoBERTa batch 145/1957
# Processed RoBERTa batch 146/1957
# Processed RoBERTa batch 147/1957
# Processed RoBERTa batch 148/1957
# Processed RoBERTa batch 149/1957
# Processed RoBERTa batch 150/1957
# Processed RoBERTa batch 151/1957
# Processed RoBERTa batch 152/1957
# Processed RoBERTa batch 153/1957
# Processed RoBERTa batch 154/1957
# Processed RoBERTa batch 155/1957
# Processed RoBERTa batch 156/1957
# Processed RoBERTa batch 157/1957
# Processed RoBERTa batch 158/1957
# Processed RoBERTa batch 159/1957
# Processed RoBERTa batch 160/1957
# Processed RoBERTa batch 161/1957
# Processed RoBERTa batch 162/1957
# Processed RoBERTa batch 163/1957
# Processed RoBERTa batch 164/1957
# Processed RoBERTa batch 165/1957
# Processed RoBERTa batch 166/1957
# Processed RoBERTa batch 167/1957
# Processed RoBERTa batch 168/1957
# Processed RoBERTa batch 169/1957
# Processed RoBERTa batch 170/1957
# Processed RoBERTa batch 171/1957
# Processed RoBERTa batch 172/1957
# Processed RoBERTa batch 173/1957
# Processed RoBERTa batch 174/1957
# Processed RoBERTa batch 175/1957
# Processed RoBERTa batch 176/1957
# Processed RoBERTa batch 177/1957
# Processed RoBERTa batch 178/1957
# Processed RoBERTa batch 179/1957
# Processed RoBERTa batch 180/1957
# Processed RoBERTa batch 181/1957
# Processed RoBERTa batch 182/1957
# Processed RoBERTa batch 183/1957
# Processed RoBERTa batch 184/1957
# Processed RoBERTa batch 185/1957
# Processed RoBERTa batch 186/1957
# Processed RoBERTa batch 187/1957
# Processed RoBERTa batch 188/1957
# Processed RoBERTa batch 189/1957
# Processed RoBERTa batch 190/1957
# Processed RoBERTa batch 191/1957
# Processed RoBERTa batch 192/1957
# Processed RoBERTa batch 193/1957
# Processed RoBERTa batch 194/1957
# Processed RoBERTa batch 195/1957
# Processed RoBERTa batch 196/1957
# Processed RoBERTa batch 197/1957
# Processed RoBERTa batch 198/1957
# Processed RoBERTa batch 199/1957
# Processed RoBERTa batch 200/1957
# Processed RoBERTa batch 201/1957
# Processed RoBERTa batch 202/1957
# Processed RoBERTa batch 203/1957
# Processed RoBERTa batch 204/1957
# Processed RoBERTa batch 205/1957
# Processed RoBERTa batch 206/1957
# Processed RoBERTa batch 207/1957
# Processed RoBERTa batch 208/1957
# Processed RoBERTa batch 209/1957
# Processed RoBERTa batch 210/1957
# Processed RoBERTa batch 211/1957
# Processed RoBERTa batch 212/1957
# Processed RoBERTa batch 213/1957
# Processed RoBERTa batch 214/1957
# Processed RoBERTa batch 215/1957
# Processed RoBERTa batch 216/1957
# Processed RoBERTa batch 217/1957
# Processed RoBERTa batch 218/1957
# Processed RoBERTa batch 219/1957
# Processed RoBERTa batch 220/1957
# Processed RoBERTa batch 221/1957
# Processed RoBERTa batch 222/1957
# Processed RoBERTa batch 223/1957
# Processed RoBERTa batch 224/1957
# Processed RoBERTa batch 225/1957
# Processed RoBERTa batch 226/1957
# Processed RoBERTa batch 227/1957
# Processed RoBERTa batch 228/1957
# Processed RoBERTa batch 229/1957
# Processed RoBERTa batch 230/1957
# Processed RoBERTa batch 231/1957
# Processed RoBERTa batch 232/1957
# Processed RoBERTa batch 233/1957
# Processed RoBERTa batch 234/1957
# Processed RoBERTa batch 235/1957
# Processed RoBERTa batch 236/1957
# Processed RoBERTa batch 237/1957
# Processed RoBERTa batch 238/1957
# Processed RoBERTa batch 239/1957
# Processed RoBERTa batch 240/1957
# Processed RoBERTa batch 241/1957
# Processed RoBERTa batch 242/1957
# Processed RoBERTa batch 243/1957
# Processed RoBERTa batch 244/1957
# Processed RoBERTa batch 245/1957
# Processed RoBERTa batch 246/1957
# Processed RoBERTa batch 247/1957
# Processed RoBERTa batch 248/1957
# Processed RoBERTa batch 249/1957
# Processed RoBERTa batch 250/1957
# Processed RoBERTa batch 251/1957
# Processed RoBERTa batch 252/1957
# Processed RoBERTa batch 253/1957
# Processed RoBERTa batch 254/1957
# Processed RoBERTa batch 255/1957
# Processed RoBERTa batch 256/1957
# Processed RoBERTa batch 257/1957
# Processed RoBERTa batch 258/1957
# Processed RoBERTa batch 259/1957
# Processed RoBERTa batch 260/1957
# Processed RoBERTa batch 261/1957
# Processed RoBERTa batch 262/1957
# Processed RoBERTa batch 263/1957
# Processed RoBERTa batch 264/1957
# Processed RoBERTa batch 265/1957
# Processed RoBERTa batch 266/1957
# Processed RoBERTa batch 267/1957
# Processed RoBERTa batch 268/1957
# Processed RoBERTa batch 269/1957
# Processed RoBERTa batch 270/1957
# Processed RoBERTa batch 271/1957
# Processed RoBERTa batch 272/1957
# Processed RoBERTa batch 273/1957
# Processed RoBERTa batch 274/1957
# Processed RoBERTa batch 275/1957
# Processed RoBERTa batch 276/1957
# Processed RoBERTa batch 277/1957
# Processed RoBERTa batch 278/1957
# Processed RoBERTa batch 279/1957
# Processed RoBERTa batch 280/1957
# Processed RoBERTa batch 281/1957
# Processed RoBERTa batch 282/1957
# Processed RoBERTa batch 283/1957
# Processed RoBERTa batch 284/1957
# Processed RoBERTa batch 285/1957
# Processed RoBERTa batch 286/1957
# Processed RoBERTa batch 287/1957
# Processed RoBERTa batch 288/1957
# Processed RoBERTa batch 289/1957
# Processed RoBERTa batch 290/1957
# Processed RoBERTa batch 291/1957
# Processed RoBERTa batch 292/1957
# Processed RoBERTa batch 293/1957
# Processed RoBERTa batch 294/1957
# Processed RoBERTa batch 295/1957
# Processed RoBERTa batch 296/1957
# Processed RoBERTa batch 297/1957
# Processed RoBERTa batch 298/1957
# Processed RoBERTa batch 299/1957
# Processed RoBERTa batch 300/1957
# Processed RoBERTa batch 301/1957
# Processed RoBERTa batch 302/1957
# Processed RoBERTa batch 303/1957
# Processed RoBERTa batch 304/1957
# Processed RoBERTa batch 305/1957
# Processed RoBERTa batch 306/1957
# Processed RoBERTa batch 307/1957
# Processed RoBERTa batch 308/1957
# Processed RoBERTa batch 309/1957
# Processed RoBERTa batch 310/1957
# Processed RoBERTa batch 311/1957
# Processed RoBERTa batch 312/1957
# Processed RoBERTa batch 313/1957
# Processed RoBERTa batch 314/1957
# Processed RoBERTa batch 315/1957
# Processed RoBERTa batch 316/1957
# Processed RoBERTa batch 317/1957
# Processed RoBERTa batch 318/1957
# Processed RoBERTa batch 319/1957
# Processed RoBERTa batch 320/1957
# Processed RoBERTa batch 321/1957
# Processed RoBERTa batch 322/1957
# Processed RoBERTa batch 323/1957
# Processed RoBERTa batch 324/1957
# Processed RoBERTa batch 325/1957
# Processed RoBERTa batch 326/1957
# Processed RoBERTa batch 327/1957
# Processed RoBERTa batch 328/1957
# Processed RoBERTa batch 329/1957
# Processed RoBERTa batch 330/1957
# Processed RoBERTa batch 331/1957
# Processed RoBERTa batch 332/1957
# Processed RoBERTa batch 333/1957
# Processed RoBERTa batch 334/1957
# Processed RoBERTa batch 335/1957
# Processed RoBERTa batch 336/1957
# Processed RoBERTa batch 337/1957
# Processed RoBERTa batch 338/1957
# Processed RoBERTa batch 339/1957
# Processed RoBERTa batch 340/1957
# Processed RoBERTa batch 341/1957
# Processed RoBERTa batch 342/1957
# Processed RoBERTa batch 343/1957
# Processed RoBERTa batch 344/1957
# Processed RoBERTa batch 345/1957
# Processed RoBERTa batch 346/1957
# Processed RoBERTa batch 347/1957
# Processed RoBERTa batch 348/1957
# Processed RoBERTa batch 349/1957
# Processed RoBERTa batch 350/1957
# Processed RoBERTa batch 351/1957
# Processed RoBERTa batch 352/1957
# Processed RoBERTa batch 353/1957
# Processed RoBERTa batch 354/1957
# Processed RoBERTa batch 355/1957
# Processed RoBERTa batch 356/1957
# Processed RoBERTa batch 357/1957
# Processed RoBERTa batch 358/1957
# Processed RoBERTa batch 359/1957
# Processed RoBERTa batch 360/1957
# Processed RoBERTa batch 361/1957
# Processed RoBERTa batch 362/1957
# Processed RoBERTa batch 363/1957
# Processed RoBERTa batch 364/1957
# Processed RoBERTa batch 365/1957
# Processed RoBERTa batch 366/1957
# Processed RoBERTa batch 367/1957
# Processed RoBERTa batch 368/1957
# Processed RoBERTa batch 369/1957
# Processed RoBERTa batch 370/1957
# Processed RoBERTa batch 371/1957
# Processed RoBERTa batch 372/1957
# Processed RoBERTa batch 373/1957
# Processed RoBERTa batch 374/1957
# Processed RoBERTa batch 375/1957
# Processed RoBERTa batch 376/1957
# Processed RoBERTa batch 377/1957
# Processed RoBERTa batch 378/1957
# Processed RoBERTa batch 379/1957
# Processed RoBERTa batch 380/1957
# Processed RoBERTa batch 381/1957
# Processed RoBERTa batch 382/1957
# Processed RoBERTa batch 383/1957
# Processed RoBERTa batch 384/1957
# Processed RoBERTa batch 385/1957
# Processed RoBERTa batch 386/1957
# Processed RoBERTa batch 387/1957
# Processed RoBERTa batch 388/1957
# Processed RoBERTa batch 389/1957
# Processed RoBERTa batch 390/1957
# Processed RoBERTa batch 391/1957
# Processed RoBERTa batch 392/1957
# Processed RoBERTa batch 393/1957
# Processed RoBERTa batch 394/1957
# Processed RoBERTa batch 395/1957
# Processed RoBERTa batch 396/1957
# Processed RoBERTa batch 397/1957
# Processed RoBERTa batch 398/1957
# Processed RoBERTa batch 399/1957
# Processed RoBERTa batch 400/1957
# Processed RoBERTa batch 401/1957
# Processed RoBERTa batch 402/1957
# Processed RoBERTa batch 403/1957
# Processed RoBERTa batch 404/1957
# Processed RoBERTa batch 405/1957
# Processed RoBERTa batch 406/1957
# Processed RoBERTa batch 407/1957
# Processed RoBERTa batch 408/1957
# Processed RoBERTa batch 409/1957
# Processed RoBERTa batch 410/1957
# Processed RoBERTa batch 411/1957
# Processed RoBERTa batch 412/1957
# Processed RoBERTa batch 413/1957
# Processed RoBERTa batch 414/1957
# Processed RoBERTa batch 415/1957
# Processed RoBERTa batch 416/1957
# Processed RoBERTa batch 417/1957
# Processed RoBERTa batch 418/1957
# Processed RoBERTa batch 419/1957
# Processed RoBERTa batch 420/1957
# Processed RoBERTa batch 421/1957
# Processed RoBERTa batch 422/1957
# Processed RoBERTa batch 423/1957
# Processed RoBERTa batch 424/1957
# Processed RoBERTa batch 425/1957
# Processed RoBERTa batch 426/1957
# Processed RoBERTa batch 427/1957
# Processed RoBERTa batch 428/1957
# Processed RoBERTa batch 429/1957
# Processed RoBERTa batch 430/1957
# Processed RoBERTa batch 431/1957
# Processed RoBERTa batch 432/1957
# Processed RoBERTa batch 433/1957
# Processed RoBERTa batch 434/1957
# Processed RoBERTa batch 435/1957
# Processed RoBERTa batch 436/1957
# Processed RoBERTa batch 437/1957
# Processed RoBERTa batch 438/1957
# Processed RoBERTa batch 439/1957
# Processed RoBERTa batch 440/1957
# Processed RoBERTa batch 441/1957
# Processed RoBERTa batch 442/1957
# Processed RoBERTa batch 443/1957
# Processed RoBERTa batch 444/1957
# Processed RoBERTa batch 445/1957
# Processed RoBERTa batch 446/1957
# Processed RoBERTa batch 447/1957
# Processed RoBERTa batch 448/1957
# Processed RoBERTa batch 449/1957
# Processed RoBERTa batch 450/1957
# Processed RoBERTa batch 451/1957
# Processed RoBERTa batch 452/1957
# Processed RoBERTa batch 453/1957
# Processed RoBERTa batch 454/1957
# Processed RoBERTa batch 455/1957
# Processed RoBERTa batch 456/1957
# Processed RoBERTa batch 457/1957
# Processed RoBERTa batch 458/1957
# Processed RoBERTa batch 459/1957
# Processed RoBERTa batch 460/1957
# Processed RoBERTa batch 461/1957
# Processed RoBERTa batch 462/1957
# Processed RoBERTa batch 463/1957
# Processed RoBERTa batch 464/1957
# Processed RoBERTa batch 465/1957
# Processed RoBERTa batch 466/1957
# Processed RoBERTa batch 467/1957
# Processed RoBERTa batch 468/1957
# Processed RoBERTa batch 469/1957
# Processed RoBERTa batch 470/1957
# Processed RoBERTa batch 471/1957
# Processed RoBERTa batch 472/1957
# Processed RoBERTa batch 473/1957
# Processed RoBERTa batch 474/1957
# Processed RoBERTa batch 475/1957
# Processed RoBERTa batch 476/1957
# Processed RoBERTa batch 477/1957
# Processed RoBERTa batch 478/1957
# Processed RoBERTa batch 479/1957
# Processed RoBERTa batch 480/1957
# Processed RoBERTa batch 481/1957
# Processed RoBERTa batch 482/1957
# Processed RoBERTa batch 483/1957
# Processed RoBERTa batch 484/1957
# Processed RoBERTa batch 485/1957
# Processed RoBERTa batch 486/1957
# Processed RoBERTa batch 487/1957
# Processed RoBERTa batch 488/1957
# Processed RoBERTa batch 489/1957
# Processed RoBERTa batch 490/1957
# Processed RoBERTa batch 491/1957
# Processed RoBERTa batch 492/1957
# Processed RoBERTa batch 493/1957
# Processed RoBERTa batch 494/1957
# Processed RoBERTa batch 495/1957
# Processed RoBERTa batch 496/1957
# Processed RoBERTa batch 497/1957
# Processed RoBERTa batch 498/1957
# Processed RoBERTa batch 499/1957
# Processed RoBERTa batch 500/1957
# Processed RoBERTa batch 501/1957
# Processed RoBERTa batch 502/1957
# Processed RoBERTa batch 503/1957
# Processed RoBERTa batch 504/1957
# Processed RoBERTa batch 505/1957
# Processed RoBERTa batch 506/1957
# Processed RoBERTa batch 507/1957
# Processed RoBERTa batch 508/1957
# Processed RoBERTa batch 509/1957
# Processed RoBERTa batch 510/1957
# Processed RoBERTa batch 511/1957
# Processed RoBERTa batch 512/1957
# Processed RoBERTa batch 513/1957
# Processed RoBERTa batch 514/1957
# Processed RoBERTa batch 515/1957
# Processed RoBERTa batch 516/1957
# Processed RoBERTa batch 517/1957
# Processed RoBERTa batch 518/1957
# Processed RoBERTa batch 519/1957
# Processed RoBERTa batch 520/1957
# Processed RoBERTa batch 521/1957
# Processed RoBERTa batch 522/1957
# Processed RoBERTa batch 523/1957
# Processed RoBERTa batch 524/1957
# Processed RoBERTa batch 525/1957
# Processed RoBERTa batch 526/1957
# Processed RoBERTa batch 527/1957
# Processed RoBERTa batch 528/1957
# Processed RoBERTa batch 529/1957
# Processed RoBERTa batch 530/1957
# Processed RoBERTa batch 531/1957
# Processed RoBERTa batch 532/1957
# Processed RoBERTa batch 533/1957
# Processed RoBERTa batch 534/1957
# Processed RoBERTa batch 535/1957
# Processed RoBERTa batch 536/1957
# Processed RoBERTa batch 537/1957
# Processed RoBERTa batch 538/1957
# Processed RoBERTa batch 539/1957
# Processed RoBERTa batch 540/1957
# Processed RoBERTa batch 541/1957
# Processed RoBERTa batch 542/1957
# Processed RoBERTa batch 543/1957
# Processed RoBERTa batch 544/1957
# Processed RoBERTa batch 545/1957
# Processed RoBERTa batch 546/1957
# Processed RoBERTa batch 547/1957
# Processed RoBERTa batch 548/1957
# Processed RoBERTa batch 549/1957
# Processed RoBERTa batch 550/1957
# Processed RoBERTa batch 551/1957
# Processed RoBERTa batch 552/1957
# Processed RoBERTa batch 553/1957
# Processed RoBERTa batch 554/1957
# Processed RoBERTa batch 555/1957
# Processed RoBERTa batch 556/1957
# Processed RoBERTa batch 557/1957
# Processed RoBERTa batch 558/1957
# Processed RoBERTa batch 559/1957
# Processed RoBERTa batch 560/1957
# Processed RoBERTa batch 561/1957
# Processed RoBERTa batch 562/1957
# Processed RoBERTa batch 563/1957
# Processed RoBERTa batch 564/1957
# Processed RoBERTa batch 565/1957
# Processed RoBERTa batch 566/1957
# Processed RoBERTa batch 567/1957
# Processed RoBERTa batch 568/1957
# Processed RoBERTa batch 569/1957
# Processed RoBERTa batch 570/1957
# Processed RoBERTa batch 571/1957
# Processed RoBERTa batch 572/1957
# Processed RoBERTa batch 573/1957
# Processed RoBERTa batch 574/1957
# Processed RoBERTa batch 575/1957
# Processed RoBERTa batch 576/1957
# Processed RoBERTa batch 577/1957
# Processed RoBERTa batch 578/1957
# Processed RoBERTa batch 579/1957
# Processed RoBERTa batch 580/1957
# Processed RoBERTa batch 581/1957
# Processed RoBERTa batch 582/1957
# Processed RoBERTa batch 583/1957
# Processed RoBERTa batch 584/1957
# Processed RoBERTa batch 585/1957
# Processed RoBERTa batch 586/1957
# Processed RoBERTa batch 587/1957
# Processed RoBERTa batch 588/1957
# Processed RoBERTa batch 589/1957
# Processed RoBERTa batch 590/1957
# Processed RoBERTa batch 591/1957
# Processed RoBERTa batch 592/1957
# Processed RoBERTa batch 593/1957
# Processed RoBERTa batch 594/1957
# Processed RoBERTa batch 595/1957
# Processed RoBERTa batch 596/1957
# Processed RoBERTa batch 597/1957
# Processed RoBERTa batch 598/1957
# Processed RoBERTa batch 599/1957
# Processed RoBERTa batch 600/1957
# Processed RoBERTa batch 601/1957
# Processed RoBERTa batch 602/1957
# Processed RoBERTa batch 603/1957
# Processed RoBERTa batch 604/1957
# Processed RoBERTa batch 605/1957
# Processed RoBERTa batch 606/1957
# Processed RoBERTa batch 607/1957
# Processed RoBERTa batch 608/1957
# Processed RoBERTa batch 609/1957
# Processed RoBERTa batch 610/1957
# Processed RoBERTa batch 611/1957
# Processed RoBERTa batch 612/1957
# Processed RoBERTa batch 613/1957
# Processed RoBERTa batch 614/1957
# Processed RoBERTa batch 615/1957
# Processed RoBERTa batch 616/1957
# Processed RoBERTa batch 617/1957
# Processed RoBERTa batch 618/1957
# Processed RoBERTa batch 619/1957
# Processed RoBERTa batch 620/1957
# Processed RoBERTa batch 621/1957
# Processed RoBERTa batch 622/1957
# Processed RoBERTa batch 623/1957
# Processed RoBERTa batch 624/1957
# Processed RoBERTa batch 625/1957
# Processed RoBERTa batch 626/1957
# Processed RoBERTa batch 627/1957
# Processed RoBERTa batch 628/1957
# Processed RoBERTa batch 629/1957
# Processed RoBERTa batch 630/1957
# Processed RoBERTa batch 631/1957
# Processed RoBERTa batch 632/1957
# Processed RoBERTa batch 633/1957
# Processed RoBERTa batch 634/1957
# Processed RoBERTa batch 635/1957
# Processed RoBERTa batch 636/1957
# Processed RoBERTa batch 637/1957
# Processed RoBERTa batch 638/1957
# Processed RoBERTa batch 639/1957
# Processed RoBERTa batch 640/1957
# Processed RoBERTa batch 641/1957
# Processed RoBERTa batch 642/1957
# Processed RoBERTa batch 643/1957
# Processed RoBERTa batch 644/1957
# Processed RoBERTa batch 645/1957
# Processed RoBERTa batch 646/1957
# Processed RoBERTa batch 647/1957
# Processed RoBERTa batch 648/1957
# Processed RoBERTa batch 649/1957
# Processed RoBERTa batch 650/1957
# Processed RoBERTa batch 651/1957
# Processed RoBERTa batch 652/1957
# Processed RoBERTa batch 653/1957
# Processed RoBERTa batch 654/1957
# Processed RoBERTa batch 655/1957
# Processed RoBERTa batch 656/1957
# Processed RoBERTa batch 657/1957
# Processed RoBERTa batch 658/1957
# Processed RoBERTa batch 659/1957
# Processed RoBERTa batch 660/1957
# Processed RoBERTa batch 661/1957
# Processed RoBERTa batch 662/1957
# Processed RoBERTa batch 663/1957
# Processed RoBERTa batch 664/1957
# Processed RoBERTa batch 665/1957
# Processed RoBERTa batch 666/1957
# Processed RoBERTa batch 667/1957
# Processed RoBERTa batch 668/1957
# Processed RoBERTa batch 669/1957
# Processed RoBERTa batch 670/1957
# Processed RoBERTa batch 671/1957
# Processed RoBERTa batch 672/1957
# Processed RoBERTa batch 673/1957
# Processed RoBERTa batch 674/1957
# Processed RoBERTa batch 675/1957
# Processed RoBERTa batch 676/1957
# Processed RoBERTa batch 677/1957
# Processed RoBERTa batch 678/1957
# Processed RoBERTa batch 679/1957
# Processed RoBERTa batch 680/1957
# Processed RoBERTa batch 681/1957
# Processed RoBERTa batch 682/1957
# Processed RoBERTa batch 683/1957
# Processed RoBERTa batch 684/1957
# Processed RoBERTa batch 685/1957
# Processed RoBERTa batch 686/1957
# Processed RoBERTa batch 687/1957
# Processed RoBERTa batch 688/1957
# Processed RoBERTa batch 689/1957
# Processed RoBERTa batch 690/1957
# Processed RoBERTa batch 691/1957
# Processed RoBERTa batch 692/1957
# Processed RoBERTa batch 693/1957
# Processed RoBERTa batch 694/1957
# Processed RoBERTa batch 695/1957
# Processed RoBERTa batch 696/1957
# Processed RoBERTa batch 697/1957
# Processed RoBERTa batch 698/1957
# Processed RoBERTa batch 699/1957
# Processed RoBERTa batch 700/1957
# Processed RoBERTa batch 701/1957
# Processed RoBERTa batch 702/1957
# Processed RoBERTa batch 703/1957
# Processed RoBERTa batch 704/1957
# Processed RoBERTa batch 705/1957
# Processed RoBERTa batch 706/1957
# Processed RoBERTa batch 707/1957
# Processed RoBERTa batch 708/1957
# Processed RoBERTa batch 709/1957
# Processed RoBERTa batch 710/1957
# Processed RoBERTa batch 711/1957
# Processed RoBERTa batch 712/1957
# Processed RoBERTa batch 713/1957
# Processed RoBERTa batch 714/1957
# Processed RoBERTa batch 715/1957
# Processed RoBERTa batch 716/1957
# Processed RoBERTa batch 717/1957
# Processed RoBERTa batch 718/1957
# Processed RoBERTa batch 719/1957
# Processed RoBERTa batch 720/1957
# Processed RoBERTa batch 721/1957
# Processed RoBERTa batch 722/1957
# Processed RoBERTa batch 723/1957
# Processed RoBERTa batch 724/1957
# Processed RoBERTa batch 725/1957
# Processed RoBERTa batch 726/1957
# Processed RoBERTa batch 727/1957
# Processed RoBERTa batch 728/1957
# Processed RoBERTa batch 729/1957
# Processed RoBERTa batch 730/1957
# Processed RoBERTa batch 731/1957
# Processed RoBERTa batch 732/1957
# Processed RoBERTa batch 733/1957
# Processed RoBERTa batch 734/1957
# Processed RoBERTa batch 735/1957
# Processed RoBERTa batch 736/1957
# Processed RoBERTa batch 737/1957
# Processed RoBERTa batch 738/1957
# Processed RoBERTa batch 739/1957
# Processed RoBERTa batch 740/1957
# Processed RoBERTa batch 741/1957
# Processed RoBERTa batch 742/1957
# Processed RoBERTa batch 743/1957
# Processed RoBERTa batch 744/1957
# Processed RoBERTa batch 745/1957
# Processed RoBERTa batch 746/1957
# Processed RoBERTa batch 747/1957
# Processed RoBERTa batch 748/1957
# Processed RoBERTa batch 749/1957
# Processed RoBERTa batch 750/1957
# Processed RoBERTa batch 751/1957
# Processed RoBERTa batch 752/1957
# Processed RoBERTa batch 753/1957
# Processed RoBERTa batch 754/1957
# Processed RoBERTa batch 755/1957
# Processed RoBERTa batch 756/1957
# Processed RoBERTa batch 757/1957
# Processed RoBERTa batch 758/1957
# Processed RoBERTa batch 759/1957
# Processed RoBERTa batch 760/1957
# Processed RoBERTa batch 761/1957
# Processed RoBERTa batch 762/1957
# Processed RoBERTa batch 763/1957
# Processed RoBERTa batch 764/1957
# Processed RoBERTa batch 765/1957
# Processed RoBERTa batch 766/1957
# Processed RoBERTa batch 767/1957
# Processed RoBERTa batch 768/1957
# Processed RoBERTa batch 769/1957
# Processed RoBERTa batch 770/1957
# Processed RoBERTa batch 771/1957
# Processed RoBERTa batch 772/1957
# Processed RoBERTa batch 773/1957
# Processed RoBERTa batch 774/1957
# Processed RoBERTa batch 775/1957
# Processed RoBERTa batch 776/1957
# Processed RoBERTa batch 777/1957
# Processed RoBERTa batch 778/1957
# Processed RoBERTa batch 779/1957
# Processed RoBERTa batch 780/1957
# Processed RoBERTa batch 781/1957
# Processed RoBERTa batch 782/1957
# Processed RoBERTa batch 783/1957
# Processed RoBERTa batch 784/1957
# Processed RoBERTa batch 785/1957
# Processed RoBERTa batch 786/1957
# Processed RoBERTa batch 787/1957
# Processed RoBERTa batch 788/1957
# Processed RoBERTa batch 789/1957
# Processed RoBERTa batch 790/1957
# Processed RoBERTa batch 791/1957
# Processed RoBERTa batch 792/1957
# Processed RoBERTa batch 793/1957
# Processed RoBERTa batch 794/1957
# Processed RoBERTa batch 795/1957
# Processed RoBERTa batch 796/1957
# Processed RoBERTa batch 797/1957
# Processed RoBERTa batch 798/1957
# Processed RoBERTa batch 799/1957
# Processed RoBERTa batch 800/1957
# Processed RoBERTa batch 801/1957
# Processed RoBERTa batch 802/1957
# Processed RoBERTa batch 803/1957
# Processed RoBERTa batch 804/1957
# Processed RoBERTa batch 805/1957
# Processed RoBERTa batch 806/1957
# Processed RoBERTa batch 807/1957
# Processed RoBERTa batch 808/1957
# Processed RoBERTa batch 809/1957
# Processed RoBERTa batch 810/1957
# Processed RoBERTa batch 811/1957
# Processed RoBERTa batch 812/1957
# Processed RoBERTa batch 813/1957
# Processed RoBERTa batch 814/1957
# Processed RoBERTa batch 815/1957
# Processed RoBERTa batch 816/1957
# Processed RoBERTa batch 817/1957
# Processed RoBERTa batch 818/1957
# Processed RoBERTa batch 819/1957
# Processed RoBERTa batch 820/1957
# Processed RoBERTa batch 821/1957
# Processed RoBERTa batch 822/1957
# Processed RoBERTa batch 823/1957
# Processed RoBERTa batch 824/1957
# Processed RoBERTa batch 825/1957
# Processed RoBERTa batch 826/1957
# Processed RoBERTa batch 827/1957
# Processed RoBERTa batch 828/1957
# Processed RoBERTa batch 829/1957
# Processed RoBERTa batch 830/1957
# Processed RoBERTa batch 831/1957
# Processed RoBERTa batch 832/1957
# Processed RoBERTa batch 833/1957
# Processed RoBERTa batch 834/1957
# Processed RoBERTa batch 835/1957
# Processed RoBERTa batch 836/1957
# Processed RoBERTa batch 837/1957
# Processed RoBERTa batch 838/1957
# Processed RoBERTa batch 839/1957
# Processed RoBERTa batch 840/1957
# Processed RoBERTa batch 841/1957
# Processed RoBERTa batch 842/1957
# Processed RoBERTa batch 843/1957
# Processed RoBERTa batch 844/1957
# Processed RoBERTa batch 845/1957
# Processed RoBERTa batch 846/1957
# Processed RoBERTa batch 847/1957
# Processed RoBERTa batch 848/1957
# Processed RoBERTa batch 849/1957
# Processed RoBERTa batch 850/1957
# Processed RoBERTa batch 851/1957
# Processed RoBERTa batch 852/1957
# Processed RoBERTa batch 853/1957
# Processed RoBERTa batch 854/1957
# Processed RoBERTa batch 855/1957
# Processed RoBERTa batch 856/1957
# Processed RoBERTa batch 857/1957
# Processed RoBERTa batch 858/1957
# Processed RoBERTa batch 859/1957
# Processed RoBERTa batch 860/1957
# Processed RoBERTa batch 861/1957
# Processed RoBERTa batch 862/1957
# Processed RoBERTa batch 863/1957
# Processed RoBERTa batch 864/1957
# Processed RoBERTa batch 865/1957
# Processed RoBERTa batch 866/1957
# Processed RoBERTa batch 867/1957
# Processed RoBERTa batch 868/1957
# Processed RoBERTa batch 869/1957
# Processed RoBERTa batch 870/1957
# Processed RoBERTa batch 871/1957
# Processed RoBERTa batch 872/1957
# Processed RoBERTa batch 873/1957
# Processed RoBERTa batch 874/1957
# Processed RoBERTa batch 875/1957
# Processed RoBERTa batch 876/1957
# Processed RoBERTa batch 877/1957
# Processed RoBERTa batch 878/1957
# Processed RoBERTa batch 879/1957
# Processed RoBERTa batch 880/1957
# Processed RoBERTa batch 881/1957
# Processed RoBERTa batch 882/1957
# Processed RoBERTa batch 883/1957
# Processed RoBERTa batch 884/1957
# Processed RoBERTa batch 885/1957
# Processed RoBERTa batch 886/1957
# Processed RoBERTa batch 887/1957
# Processed RoBERTa batch 888/1957
# Processed RoBERTa batch 889/1957
# Processed RoBERTa batch 890/1957
# Processed RoBERTa batch 891/1957
# Processed RoBERTa batch 892/1957
# Processed RoBERTa batch 893/1957
# Processed RoBERTa batch 894/1957
# Processed RoBERTa batch 895/1957
# Processed RoBERTa batch 896/1957
# Processed RoBERTa batch 897/1957
# Processed RoBERTa batch 898/1957
# Processed RoBERTa batch 899/1957
# Processed RoBERTa batch 900/1957
# Processed RoBERTa batch 901/1957
# Processed RoBERTa batch 902/1957
# Processed RoBERTa batch 903/1957
# Processed RoBERTa batch 904/1957
# Processed RoBERTa batch 905/1957
# Processed RoBERTa batch 906/1957
# Processed RoBERTa batch 907/1957
# Processed RoBERTa batch 908/1957
# Processed RoBERTa batch 909/1957
# Processed RoBERTa batch 910/1957
# Processed RoBERTa batch 911/1957
# Processed RoBERTa batch 912/1957
# Processed RoBERTa batch 913/1957
# Processed RoBERTa batch 914/1957
# Processed RoBERTa batch 915/1957
# Processed RoBERTa batch 916/1957
# Processed RoBERTa batch 917/1957
# Processed RoBERTa batch 918/1957
# Processed RoBERTa batch 919/1957
# Processed RoBERTa batch 920/1957
# Processed RoBERTa batch 921/1957
# Processed RoBERTa batch 922/1957
# Processed RoBERTa batch 923/1957
# Processed RoBERTa batch 924/1957
# Processed RoBERTa batch 925/1957
# Processed RoBERTa batch 926/1957
# Processed RoBERTa batch 927/1957
# Processed RoBERTa batch 928/1957
# Processed RoBERTa batch 929/1957
# Processed RoBERTa batch 930/1957
# Processed RoBERTa batch 931/1957
# Processed RoBERTa batch 932/1957
# Processed RoBERTa batch 933/1957
# Processed RoBERTa batch 934/1957
# Processed RoBERTa batch 935/1957
# Processed RoBERTa batch 936/1957
# Processed RoBERTa batch 937/1957
# Processed RoBERTa batch 938/1957
# Processed RoBERTa batch 939/1957
# Processed RoBERTa batch 940/1957
# Processed RoBERTa batch 941/1957
# Processed RoBERTa batch 942/1957
# Processed RoBERTa batch 943/1957
# Processed RoBERTa batch 944/1957
# Processed RoBERTa batch 945/1957
# Processed RoBERTa batch 946/1957
# Processed RoBERTa batch 947/1957
# Processed RoBERTa batch 948/1957
# Processed RoBERTa batch 949/1957
# Processed RoBERTa batch 950/1957
# Processed RoBERTa batch 951/1957
# Processed RoBERTa batch 952/1957
# Processed RoBERTa batch 953/1957
# Processed RoBERTa batch 954/1957
# Processed RoBERTa batch 955/1957
# Processed RoBERTa batch 956/1957
# Processed RoBERTa batch 957/1957
# Processed RoBERTa batch 958/1957
# Processed RoBERTa batch 959/1957
# Processed RoBERTa batch 960/1957
# Processed RoBERTa batch 961/1957
# Processed RoBERTa batch 962/1957
# Processed RoBERTa batch 963/1957
# Processed RoBERTa batch 964/1957
# Processed RoBERTa batch 965/1957
# Processed RoBERTa batch 966/1957
# Processed RoBERTa batch 967/1957
# Processed RoBERTa batch 968/1957
# Processed RoBERTa batch 969/1957
# Processed RoBERTa batch 970/1957
# Processed RoBERTa batch 971/1957
# Processed RoBERTa batch 972/1957
# Processed RoBERTa batch 973/1957
# Processed RoBERTa batch 974/1957
# Processed RoBERTa batch 975/1957
# Processed RoBERTa batch 976/1957
# Processed RoBERTa batch 977/1957
# Processed RoBERTa batch 978/1957
# Processed RoBERTa batch 979/1957
# Processed RoBERTa batch 980/1957
# Processed RoBERTa batch 981/1957
# Processed RoBERTa batch 982/1957
# Processed RoBERTa batch 983/1957
# Processed RoBERTa batch 984/1957
# Processed RoBERTa batch 985/1957
# Processed RoBERTa batch 986/1957
# Processed RoBERTa batch 987/1957
# Processed RoBERTa batch 988/1957
# Processed RoBERTa batch 989/1957
# Processed RoBERTa batch 990/1957
# Processed RoBERTa batch 991/1957
# Processed RoBERTa batch 992/1957
# Processed RoBERTa batch 993/1957
# Processed RoBERTa batch 994/1957
# Processed RoBERTa batch 995/1957
# Processed RoBERTa batch 996/1957
# Processed RoBERTa batch 997/1957
# Processed RoBERTa batch 998/1957
# Processed RoBERTa batch 999/1957
# Processed RoBERTa batch 1000/1957
# Processed RoBERTa batch 1001/1957
# Processed RoBERTa batch 1002/1957
# Processed RoBERTa batch 1003/1957
# Processed RoBERTa batch 1004/1957
# Processed RoBERTa batch 1005/1957
# Processed RoBERTa batch 1006/1957
# Processed RoBERTa batch 1007/1957
# Processed RoBERTa batch 1008/1957
# Processed RoBERTa batch 1009/1957
# Processed RoBERTa batch 1010/1957
# Processed RoBERTa batch 1011/1957
# Processed RoBERTa batch 1012/1957
# Processed RoBERTa batch 1013/1957
# Processed RoBERTa batch 1014/1957
# Processed RoBERTa batch 1015/1957
# Processed RoBERTa batch 1016/1957
# Processed RoBERTa batch 1017/1957
# Processed RoBERTa batch 1018/1957
# Processed RoBERTa batch 1019/1957
# Processed RoBERTa batch 1020/1957
# Processed RoBERTa batch 1021/1957
# Processed RoBERTa batch 1022/1957
# Processed RoBERTa batch 1023/1957
# Processed RoBERTa batch 1024/1957
# Processed RoBERTa batch 1025/1957
# Processed RoBERTa batch 1026/1957
# Processed RoBERTa batch 1027/1957
# Processed RoBERTa batch 1028/1957
# Processed RoBERTa batch 1029/1957
# Processed RoBERTa batch 1030/1957
# Processed RoBERTa batch 1031/1957
# Processed RoBERTa batch 1032/1957
# Processed RoBERTa batch 1033/1957
# Processed RoBERTa batch 1034/1957
# Processed RoBERTa batch 1035/1957
# Processed RoBERTa batch 1036/1957
# Processed RoBERTa batch 1037/1957
# Processed RoBERTa batch 1038/1957
# Processed RoBERTa batch 1039/1957
# Processed RoBERTa batch 1040/1957
# Processed RoBERTa batch 1041/1957
# Processed RoBERTa batch 1042/1957
# Processed RoBERTa batch 1043/1957
# Processed RoBERTa batch 1044/1957
# Processed RoBERTa batch 1045/1957
# Processed RoBERTa batch 1046/1957
# Processed RoBERTa batch 1047/1957
# Processed RoBERTa batch 1048/1957
# Processed RoBERTa batch 1049/1957
# Processed RoBERTa batch 1050/1957
# Processed RoBERTa batch 1051/1957
# Processed RoBERTa batch 1052/1957
# Processed RoBERTa batch 1053/1957
# Processed RoBERTa batch 1054/1957
# Processed RoBERTa batch 1055/1957
# Processed RoBERTa batch 1056/1957
# Processed RoBERTa batch 1057/1957
# Processed RoBERTa batch 1058/1957
# Processed RoBERTa batch 1059/1957
# Processed RoBERTa batch 1060/1957
# Processed RoBERTa batch 1061/1957
# Processed RoBERTa batch 1062/1957
# Processed RoBERTa batch 1063/1957
# Processed RoBERTa batch 1064/1957
# Processed RoBERTa batch 1065/1957
# Processed RoBERTa batch 1066/1957
# Processed RoBERTa batch 1067/1957
# Processed RoBERTa batch 1068/1957
# Processed RoBERTa batch 1069/1957
# Processed RoBERTa batch 1070/1957
# Processed RoBERTa batch 1071/1957
# Processed RoBERTa batch 1072/1957
# Processed RoBERTa batch 1073/1957
# Processed RoBERTa batch 1074/1957
# Processed RoBERTa batch 1075/1957
# Processed RoBERTa batch 1076/1957
# Processed RoBERTa batch 1077/1957
# Processed RoBERTa batch 1078/1957
# Processed RoBERTa batch 1079/1957
# Processed RoBERTa batch 1080/1957
# Processed RoBERTa batch 1081/1957
# Processed RoBERTa batch 1082/1957
# Processed RoBERTa batch 1083/1957
# Processed RoBERTa batch 1084/1957
# Processed RoBERTa batch 1085/1957
# Processed RoBERTa batch 1086/1957
# Processed RoBERTa batch 1087/1957
# Processed RoBERTa batch 1088/1957
# Processed RoBERTa batch 1089/1957
# Processed RoBERTa batch 1090/1957
# Processed RoBERTa batch 1091/1957
# Processed RoBERTa batch 1092/1957
# Processed RoBERTa batch 1093/1957
# Processed RoBERTa batch 1094/1957
# Processed RoBERTa batch 1095/1957
# Processed RoBERTa batch 1096/1957
# Processed RoBERTa batch 1097/1957
# Processed RoBERTa batch 1098/1957
# Processed RoBERTa batch 1099/1957
# Processed RoBERTa batch 1100/1957
# Processed RoBERTa batch 1101/1957
# Processed RoBERTa batch 1102/1957
# Processed RoBERTa batch 1103/1957
# Processed RoBERTa batch 1104/1957
# Processed RoBERTa batch 1105/1957
# Processed RoBERTa batch 1106/1957
# Processed RoBERTa batch 1107/1957
# Processed RoBERTa batch 1108/1957
# Processed RoBERTa batch 1109/1957
# Processed RoBERTa batch 1110/1957
# Processed RoBERTa batch 1111/1957
# Processed RoBERTa batch 1112/1957
# Processed RoBERTa batch 1113/1957
# Processed RoBERTa batch 1114/1957
# Processed RoBERTa batch 1115/1957
# Processed RoBERTa batch 1116/1957
# Processed RoBERTa batch 1117/1957
# Processed RoBERTa batch 1118/1957
# Processed RoBERTa batch 1119/1957
# Processed RoBERTa batch 1120/1957
# Processed RoBERTa batch 1121/1957
# Processed RoBERTa batch 1122/1957
# Processed RoBERTa batch 1123/1957
# Processed RoBERTa batch 1124/1957
# Processed RoBERTa batch 1125/1957
# Processed RoBERTa batch 1126/1957
# Processed RoBERTa batch 1127/1957
# Processed RoBERTa batch 1128/1957
# Processed RoBERTa batch 1129/1957
# Processed RoBERTa batch 1130/1957
# Processed RoBERTa batch 1131/1957
# Processed RoBERTa batch 1132/1957
# Processed RoBERTa batch 1133/1957
# Processed RoBERTa batch 1134/1957
# Processed RoBERTa batch 1135/1957
# Processed RoBERTa batch 1136/1957
# Processed RoBERTa batch 1137/1957
# Processed RoBERTa batch 1138/1957
# Processed RoBERTa batch 1139/1957
# Processed RoBERTa batch 1140/1957
# Processed RoBERTa batch 1141/1957
# Processed RoBERTa batch 1142/1957
# Processed RoBERTa batch 1143/1957
# Processed RoBERTa batch 1144/1957
# Processed RoBERTa batch 1145/1957
# Processed RoBERTa batch 1146/1957
# Processed RoBERTa batch 1147/1957
# Processed RoBERTa batch 1148/1957
# Processed RoBERTa batch 1149/1957
# Processed RoBERTa batch 1150/1957
# Processed RoBERTa batch 1151/1957
# Processed RoBERTa batch 1152/1957
# Processed RoBERTa batch 1153/1957
# Processed RoBERTa batch 1154/1957
# Processed RoBERTa batch 1155/1957
# Processed RoBERTa batch 1156/1957
# Processed RoBERTa batch 1157/1957
# Processed RoBERTa batch 1158/1957
# Processed RoBERTa batch 1159/1957
# Processed RoBERTa batch 1160/1957
# Processed RoBERTa batch 1161/1957
# Processed RoBERTa batch 1162/1957
# Processed RoBERTa batch 1163/1957
# Processed RoBERTa batch 1164/1957
# Processed RoBERTa batch 1165/1957
# Processed RoBERTa batch 1166/1957
# Processed RoBERTa batch 1167/1957
# Processed RoBERTa batch 1168/1957
# Processed RoBERTa batch 1169/1957
# Processed RoBERTa batch 1170/1957
# Processed RoBERTa batch 1171/1957
# Processed RoBERTa batch 1172/1957
# Processed RoBERTa batch 1173/1957
# Processed RoBERTa batch 1174/1957
# Processed RoBERTa batch 1175/1957
# Processed RoBERTa batch 1176/1957
# Processed RoBERTa batch 1177/1957
# Processed RoBERTa batch 1178/1957
# Processed RoBERTa batch 1179/1957
# Processed RoBERTa batch 1180/1957
# Processed RoBERTa batch 1181/1957
# Processed RoBERTa batch 1182/1957
# Processed RoBERTa batch 1183/1957
# Processed RoBERTa batch 1184/1957
# Processed RoBERTa batch 1185/1957
# Processed RoBERTa batch 1186/1957
# Processed RoBERTa batch 1187/1957
# Processed RoBERTa batch 1188/1957
# Processed RoBERTa batch 1189/1957
# Processed RoBERTa batch 1190/1957
# Processed RoBERTa batch 1191/1957
# Processed RoBERTa batch 1192/1957
# Processed RoBERTa batch 1193/1957
# Processed RoBERTa batch 1194/1957
# Processed RoBERTa batch 1195/1957
# Processed RoBERTa batch 1196/1957
# Processed RoBERTa batch 1197/1957
# Processed RoBERTa batch 1198/1957
# Processed RoBERTa batch 1199/1957
# Processed RoBERTa batch 1200/1957
# Processed RoBERTa batch 1201/1957
# Processed RoBERTa batch 1202/1957
# Processed RoBERTa batch 1203/1957
# Processed RoBERTa batch 1204/1957
# Processed RoBERTa batch 1205/1957
# Processed RoBERTa batch 1206/1957
# Processed RoBERTa batch 1207/1957
# Processed RoBERTa batch 1208/1957
# Processed RoBERTa batch 1209/1957
# Processed RoBERTa batch 1210/1957
# Processed RoBERTa batch 1211/1957
# Processed RoBERTa batch 1212/1957
# Processed RoBERTa batch 1213/1957
# Processed RoBERTa batch 1214/1957
# Processed RoBERTa batch 1215/1957
# Processed RoBERTa batch 1216/1957
# Processed RoBERTa batch 1217/1957
# Processed RoBERTa batch 1218/1957
# Processed RoBERTa batch 1219/1957
# Processed RoBERTa batch 1220/1957
# Processed RoBERTa batch 1221/1957
# Processed RoBERTa batch 1222/1957
# Processed RoBERTa batch 1223/1957
# Processed RoBERTa batch 1224/1957
# Processed RoBERTa batch 1225/1957
# Processed RoBERTa batch 1226/1957
# Processed RoBERTa batch 1227/1957
# Processed RoBERTa batch 1228/1957
# Processed RoBERTa batch 1229/1957
# Processed RoBERTa batch 1230/1957
# Processed RoBERTa batch 1231/1957
# Processed RoBERTa batch 1232/1957
# Processed RoBERTa batch 1233/1957
# Processed RoBERTa batch 1234/1957
# Processed RoBERTa batch 1235/1957
# Processed RoBERTa batch 1236/1957
# Processed RoBERTa batch 1237/1957
# Processed RoBERTa batch 1238/1957
# Processed RoBERTa batch 1239/1957
# Processed RoBERTa batch 1240/1957
# Processed RoBERTa batch 1241/1957
# Processed RoBERTa batch 1242/1957
# Processed RoBERTa batch 1243/1957
# Processed RoBERTa batch 1244/1957
# Processed RoBERTa batch 1245/1957
# Processed RoBERTa batch 1246/1957
# Processed RoBERTa batch 1247/1957
# Processed RoBERTa batch 1248/1957
# Processed RoBERTa batch 1249/1957
# Processed RoBERTa batch 1250/1957
# Processed RoBERTa batch 1251/1957
# Processed RoBERTa batch 1252/1957
# Processed RoBERTa batch 1253/1957
# Processed RoBERTa batch 1254/1957
# Processed RoBERTa batch 1255/1957
# Processed RoBERTa batch 1256/1957
# Processed RoBERTa batch 1257/1957
# Processed RoBERTa batch 1258/1957
# Processed RoBERTa batch 1259/1957
# Processed RoBERTa batch 1260/1957
# Processed RoBERTa batch 1261/1957
# Processed RoBERTa batch 1262/1957
# Processed RoBERTa batch 1263/1957
# Processed RoBERTa batch 1264/1957
# Processed RoBERTa batch 1265/1957
# Processed RoBERTa batch 1266/1957
# Processed RoBERTa batch 1267/1957
# Processed RoBERTa batch 1268/1957
# Processed RoBERTa batch 1269/1957
# Processed RoBERTa batch 1270/1957
# Processed RoBERTa batch 1271/1957
# Processed RoBERTa batch 1272/1957
# Processed RoBERTa batch 1273/1957
# Processed RoBERTa batch 1274/1957
# Processed RoBERTa batch 1275/1957
# Processed RoBERTa batch 1276/1957
# Processed RoBERTa batch 1277/1957
# Processed RoBERTa batch 1278/1957
# Processed RoBERTa batch 1279/1957
# Processed RoBERTa batch 1280/1957
# Processed RoBERTa batch 1281/1957
# Processed RoBERTa batch 1282/1957
# Processed RoBERTa batch 1283/1957
# Processed RoBERTa batch 1284/1957
# Processed RoBERTa batch 1285/1957
# Processed RoBERTa batch 1286/1957
# Processed RoBERTa batch 1287/1957
# Processed RoBERTa batch 1288/1957
# Processed RoBERTa batch 1289/1957
# Processed RoBERTa batch 1290/1957
# Processed RoBERTa batch 1291/1957
# Processed RoBERTa batch 1292/1957
# Processed RoBERTa batch 1293/1957
# Processed RoBERTa batch 1294/1957
# Processed RoBERTa batch 1295/1957
# Processed RoBERTa batch 1296/1957
# Processed RoBERTa batch 1297/1957
# Processed RoBERTa batch 1298/1957
# Processed RoBERTa batch 1299/1957
# Processed RoBERTa batch 1300/1957
# Processed RoBERTa batch 1301/1957
# Processed RoBERTa batch 1302/1957
# Processed RoBERTa batch 1303/1957
# Processed RoBERTa batch 1304/1957
# Processed RoBERTa batch 1305/1957
# Processed RoBERTa batch 1306/1957
# Processed RoBERTa batch 1307/1957
# Processed RoBERTa batch 1308/1957
# Processed RoBERTa batch 1309/1957
# Processed RoBERTa batch 1310/1957
# Processed RoBERTa batch 1311/1957
# Processed RoBERTa batch 1312/1957
# Processed RoBERTa batch 1313/1957
# Processed RoBERTa batch 1314/1957
# Processed RoBERTa batch 1315/1957
# Processed RoBERTa batch 1316/1957
# Processed RoBERTa batch 1317/1957
# Processed RoBERTa batch 1318/1957
# Processed RoBERTa batch 1319/1957
# Processed RoBERTa batch 1320/1957
# Processed RoBERTa batch 1321/1957
# Processed RoBERTa batch 1322/1957
# Processed RoBERTa batch 1323/1957
# Processed RoBERTa batch 1324/1957
# Processed RoBERTa batch 1325/1957
# Processed RoBERTa batch 1326/1957
# Processed RoBERTa batch 1327/1957
# Processed RoBERTa batch 1328/1957
# Processed RoBERTa batch 1329/1957
# Processed RoBERTa batch 1330/1957
# Processed RoBERTa batch 1331/1957
# Processed RoBERTa batch 1332/1957
# Processed RoBERTa batch 1333/1957
# Processed RoBERTa batch 1334/1957
# Processed RoBERTa batch 1335/1957
# Processed RoBERTa batch 1336/1957
# Processed RoBERTa batch 1337/1957
# Processed RoBERTa batch 1338/1957
# Processed RoBERTa batch 1339/1957
# Processed RoBERTa batch 1340/1957
# Processed RoBERTa batch 1341/1957
# Processed RoBERTa batch 1342/1957
# Processed RoBERTa batch 1343/1957
# Processed RoBERTa batch 1344/1957
# Processed RoBERTa batch 1345/1957
# Processed RoBERTa batch 1346/1957
# Processed RoBERTa batch 1347/1957
# Processed RoBERTa batch 1348/1957
# Processed RoBERTa batch 1349/1957
# Processed RoBERTa batch 1350/1957
# Processed RoBERTa batch 1351/1957
# Processed RoBERTa batch 1352/1957
# Processed RoBERTa batch 1353/1957
# Processed RoBERTa batch 1354/1957
# Processed RoBERTa batch 1355/1957
# Processed RoBERTa batch 1356/1957
# Processed RoBERTa batch 1357/1957
# Processed RoBERTa batch 1358/1957
# Processed RoBERTa batch 1359/1957
# Processed RoBERTa batch 1360/1957
# Processed RoBERTa batch 1361/1957
# Processed RoBERTa batch 1362/1957
# Processed RoBERTa batch 1363/1957
# Processed RoBERTa batch 1364/1957
# Processed RoBERTa batch 1365/1957
# Processed RoBERTa batch 1366/1957
# Processed RoBERTa batch 1367/1957
# Processed RoBERTa batch 1368/1957
# Processed RoBERTa batch 1369/1957
# Processed RoBERTa batch 1370/1957
# Processed RoBERTa batch 1371/1957
# Processed RoBERTa batch 1372/1957
# Processed RoBERTa batch 1373/1957
# Processed RoBERTa batch 1374/1957
# Processed RoBERTa batch 1375/1957
# Processed RoBERTa batch 1376/1957
# Processed RoBERTa batch 1377/1957
# Processed RoBERTa batch 1378/1957
# Processed RoBERTa batch 1379/1957
# Processed RoBERTa batch 1380/1957
# Processed RoBERTa batch 1381/1957
# Processed RoBERTa batch 1382/1957
# Processed RoBERTa batch 1383/1957
# Processed RoBERTa batch 1384/1957
# Processed RoBERTa batch 1385/1957
# Processed RoBERTa batch 1386/1957
# Processed RoBERTa batch 1387/1957
# Processed RoBERTa batch 1388/1957
# Processed RoBERTa batch 1389/1957
# Processed RoBERTa batch 1390/1957
# Processed RoBERTa batch 1391/1957
# Processed RoBERTa batch 1392/1957
# Processed RoBERTa batch 1393/1957
# Processed RoBERTa batch 1394/1957
# Processed RoBERTa batch 1395/1957
# Processed RoBERTa batch 1396/1957
# Processed RoBERTa batch 1397/1957
# Processed RoBERTa batch 1398/1957
# Processed RoBERTa batch 1399/1957
# Processed RoBERTa batch 1400/1957
# Processed RoBERTa batch 1401/1957
# Processed RoBERTa batch 1402/1957
# Processed RoBERTa batch 1403/1957
# Processed RoBERTa batch 1404/1957
# Processed RoBERTa batch 1405/1957
# Processed RoBERTa batch 1406/1957
# Processed RoBERTa batch 1407/1957
# Processed RoBERTa batch 1408/1957
# Processed RoBERTa batch 1409/1957
# Processed RoBERTa batch 1410/1957
# Processed RoBERTa batch 1411/1957
# Processed RoBERTa batch 1412/1957
# Processed RoBERTa batch 1413/1957
# Processed RoBERTa batch 1414/1957
# Processed RoBERTa batch 1415/1957
# Processed RoBERTa batch 1416/1957
# Processed RoBERTa batch 1417/1957
# Processed RoBERTa batch 1418/1957
# Processed RoBERTa batch 1419/1957
# Processed RoBERTa batch 1420/1957
# Processed RoBERTa batch 1421/1957
# Processed RoBERTa batch 1422/1957
# Processed RoBERTa batch 1423/1957
# Processed RoBERTa batch 1424/1957
# Processed RoBERTa batch 1425/1957
# Processed RoBERTa batch 1426/1957
# Processed RoBERTa batch 1427/1957
# Processed RoBERTa batch 1428/1957
# Processed RoBERTa batch 1429/1957
# Processed RoBERTa batch 1430/1957
# Processed RoBERTa batch 1431/1957
# Processed RoBERTa batch 1432/1957
# Processed RoBERTa batch 1433/1957
# Processed RoBERTa batch 1434/1957
# Processed RoBERTa batch 1435/1957
# Processed RoBERTa batch 1436/1957
# Processed RoBERTa batch 1437/1957
# Processed RoBERTa batch 1438/1957
# Processed RoBERTa batch 1439/1957
# Processed RoBERTa batch 1440/1957
# Processed RoBERTa batch 1441/1957
# Processed RoBERTa batch 1442/1957
# Processed RoBERTa batch 1443/1957
# Processed RoBERTa batch 1444/1957
# ...
# Processed RoBERTa batch 1487/1957
# Processed RoBERTa batch 1488/1957
# Processed RoBERTa batch 1489/1957
# Processed RoBERTa batch 1490/1957
# Processed RoBERTa batch 1491/1957
# Processed RoBERTa batch 1492/1957
# Processed RoBERTa batch 1493/1957
# Processed RoBERTa batch 1494/1957
# Processed RoBERTa batch 1495/1957
# Processed RoBERTa batch 1496/1957
# Processed RoBERTa batch 1497/1957
# Processed RoBERTa batch 1498/1957
# Processed RoBERTa batch 1499/1957
# Processed RoBERTa batch 1500/1957
# Processed RoBERTa batch 1501/1957
# Processed RoBERTa batch 1502/1957
# Processed RoBERTa batch 1503/1957
# Processed RoBERTa batch 1504/1957
# Processed RoBERTa batch 1505/1957
# Processed RoBERTa batch 1506/1957
# Processed RoBERTa batch 1507/1957
# Processed RoBERTa batch 1508/1957
# Processed RoBERTa batch 1509/1957
# Processed RoBERTa batch 1510/1957
# Processed RoBERTa batch 1511/1957
# Processed RoBERTa batch 1512/1957
# Processed RoBERTa batch 1513/1957
# Processed RoBERTa batch 1514/1957
# Processed RoBERTa batch 1515/1957
# Processed RoBERTa batch 1516/1957
# Processed RoBERTa batch 1517/1957
# Processed RoBERTa batch 1518/1957
# Processed RoBERTa batch 1519/1957
# Processed RoBERTa batch 1520/1957
# Processed RoBERTa batch 1521/1957
# Processed RoBERTa batch 1522/1957
# Processed RoBERTa batch 1523/1957
# Processed RoBERTa batch 1524/1957
# Processed RoBERTa batch 1525/1957
# Processed RoBERTa batch 1526/1957
# Processed RoBERTa batch 1527/1957
# Processed RoBERTa batch 1528/1957
# Processed RoBERTa batch 1529/1957
# Processed RoBERTa batch 1530/1957
# Processed RoBERTa batch 1531/1957
# Processed RoBERTa batch 1532/1957
# Processed RoBERTa batch 1533/1957
# Processed RoBERTa batch 1534/1957
# Processed RoBERTa batch 1535/1957
# Processed RoBERTa batch 1536/1957
# Processed RoBERTa batch 1537/1957
# Processed RoBERTa batch 1538/1957
# Processed RoBERTa batch 1539/1957
# Processed RoBERTa batch 1540/1957
# Processed RoBERTa batch 1541/1957
# Processed RoBERTa batch 1542/1957
# Processed RoBERTa batch 1543/1957
# Processed RoBERTa batch 1544/1957
# Processed RoBERTa batch 1545/1957
# Processed RoBERTa batch 1546/1957
# Processed RoBERTa batch 1547/1957
# Processed RoBERTa batch 1548/1957
# Processed RoBERTa batch 1549/1957
# Processed RoBERTa batch 1550/1957
# Processed RoBERTa batch 1551/1957
# Processed RoBERTa batch 1552/1957
# Processed RoBERTa batch 1553/1957
# Processed RoBERTa batch 1554/1957
# Processed RoBERTa batch 1555/1957
# Processed RoBERTa batch 1556/1957
# Processed RoBERTa batch 1557/1957
# Processed RoBERTa batch 1558/1957
# Processed RoBERTa batch 1559/1957
# Processed RoBERTa batch 1560/1957
# Processed RoBERTa batch 1561/1957
# Processed RoBERTa batch 1562/1957
# Processed RoBERTa batch 1563/1957
# Processed RoBERTa batch 1564/1957
# Processed RoBERTa batch 1565/1957
# Processed RoBERTa batch 1566/1957
# Processed RoBERTa batch 1567/1957
# Processed RoBERTa batch 1568/1957
# Processed RoBERTa batch 1569/1957
# Processed RoBERTa batch 1570/1957
# Processed RoBERTa batch 1571/1957
# Processed RoBERTa batch 1572/1957
# Processed RoBERTa batch 1573/1957
# Processed RoBERTa batch 1574/1957
# Processed RoBERTa batch 1575/1957
# Processed RoBERTa batch 1576/1957
# Processed RoBERTa batch 1577/1957
# Processed RoBERTa batch 1578/1957
# Processed RoBERTa batch 1579/1957
# Processed RoBERTa batch 1580/1957
# Processed RoBERTa batch 1581/1957
# Processed RoBERTa batch 1582/1957
# Processed RoBERTa batch 1583/1957
# Processed RoBERTa batch 1584/1957
# Processed RoBERTa batch 1585/1957
# Processed RoBERTa batch 1586/1957
# Processed RoBERTa batch 1587/1957
# Processed RoBERTa batch 1588/1957
# Processed RoBERTa batch 1589/1957
# Processed RoBERTa batch 1590/1957
# Processed RoBERTa batch 1591/1957
# Processed RoBERTa batch 1592/1957
# Processed RoBERTa batch 1593/1957
# Processed RoBERTa batch 1594/1957
# Processed RoBERTa batch 1595/1957
# Processed RoBERTa batch 1596/1957
# Processed RoBERTa batch 1597/1957
# Processed RoBERTa batch 1598/1957
# Processed RoBERTa batch 1599/1957
# Processed RoBERTa batch 1600/1957
# Processed RoBERTa batch 1601/1957
# Processed RoBERTa batch 1602/1957
# Processed RoBERTa batch 1603/1957
# Processed RoBERTa batch 1604/1957
# Processed RoBERTa batch 1605/1957
# Processed RoBERTa batch 1606/1957
# Processed RoBERTa batch 1607/1957
# Processed RoBERTa batch 1608/1957
# Processed RoBERTa batch 1609/1957
# Processed RoBERTa batch 1610/1957
# Processed RoBERTa batch 1611/1957
# Processed RoBERTa batch 1612/1957
# Processed RoBERTa batch 1613/1957
# Processed RoBERTa batch 1614/1957
# Processed RoBERTa batch 1615/1957
# Processed RoBERTa batch 1616/1957
# Processed RoBERTa batch 1617/1957
# Processed RoBERTa batch 1618/1957
# Processed RoBERTa batch 1619/1957
# Processed RoBERTa batch 1620/1957
# Processed RoBERTa batch 1621/1957
# Processed RoBERTa batch 1622/1957
# Processed RoBERTa batch 1623/1957
# Processed RoBERTa batch 1624/1957
# Processed RoBERTa batch 1625/1957
# Processed RoBERTa batch 1626/1957
# Processed RoBERTa batch 1627/1957
# Processed RoBERTa batch 1628/1957
# Processed RoBERTa batch 1629/1957
# Processed RoBERTa batch 1630/1957
# Processed RoBERTa batch 1631/1957
# Processed RoBERTa batch 1632/1957
# Processed RoBERTa batch 1633/1957
# Processed RoBERTa batch 1634/1957
# Processed RoBERTa batch 1635/1957
# Processed RoBERTa batch 1636/1957
# Processed RoBERTa batch 1637/1957
# Processed RoBERTa batch 1638/1957
# Processed RoBERTa batch 1639/1957
# Processed RoBERTa batch 1640/1957
# Processed RoBERTa batch 1641/1957
# Processed RoBERTa batch 1642/1957
# Processed RoBERTa batch 1643/1957
# Processed RoBERTa batch 1644/1957
# Processed RoBERTa batch 1645/1957
# Processed RoBERTa batch 1646/1957
# Processed RoBERTa batch 1647/1957
# Processed RoBERTa batch 1648/1957
# Processed RoBERTa batch 1649/1957
# Processed RoBERTa batch 1650/1957
# Processed RoBERTa batch 1651/1957
# Processed RoBERTa batch 1652/1957
# Processed RoBERTa batch 1653/1957
# Processed RoBERTa batch 1654/1957
# Processed RoBERTa batch 1655/1957
# Processed RoBERTa batch 1656/1957
# Processed RoBERTa batch 1657/1957
# Processed RoBERTa batch 1658/1957
# Processed RoBERTa batch 1659/1957
# Processed RoBERTa batch 1660/1957
# Processed RoBERTa batch 1661/1957
# Processed RoBERTa batch 1662/1957
# Processed RoBERTa batch 1663/1957
# Processed RoBERTa batch 1664/1957
# Processed RoBERTa batch 1665/1957
# Processed RoBERTa batch 1666/1957
# Processed RoBERTa batch 1667/1957
# Processed RoBERTa batch 1668/1957
# Processed RoBERTa batch 1669/1957
# Processed RoBERTa batch 1670/1957
# Processed RoBERTa batch 1671/1957
# Processed RoBERTa batch 1672/1957
# Processed RoBERTa batch 1673/1957
# Processed RoBERTa batch 1674/1957
# Processed RoBERTa batch 1675/1957
# Processed RoBERTa batch 1676/1957
# Processed RoBERTa batch 1677/1957
# Processed RoBERTa batch 1678/1957
# Processed RoBERTa batch 1679/1957
# Processed RoBERTa batch 1680/1957
# Processed RoBERTa batch 1681/1957
# Processed RoBERTa batch 1682/1957
# Processed RoBERTa batch 1683/1957
# Processed RoBERTa batch 1684/1957
# Processed RoBERTa batch 1685/1957
# Processed RoBERTa batch 1686/1957
# Processed RoBERTa batch 1687/1957
# Processed RoBERTa batch 1688/1957
# Processed RoBERTa batch 1689/1957
# Processed RoBERTa batch 1690/1957
# Processed RoBERTa batch 1691/1957
# Processed RoBERTa batch 1692/1957
# Processed RoBERTa batch 1693/1957
# Processed RoBERTa batch 1694/1957
# Processed RoBERTa batch 1695/1957
# Processed RoBERTa batch 1696/1957
# Processed RoBERTa batch 1697/1957
# Processed RoBERTa batch 1698/1957
# Processed RoBERTa batch 1699/1957
# Processed RoBERTa batch 1700/1957
# Processed RoBERTa batch 1701/1957
# Processed RoBERTa batch 1702/1957
# Processed RoBERTa batch 1703/1957
# Processed RoBERTa batch 1704/1957
# Processed RoBERTa batch 1705/1957
# Processed RoBERTa batch 1706/1957
# Processed RoBERTa batch 1707/1957
# Processed RoBERTa batch 1708/1957
# Processed RoBERTa batch 1709/1957
# Processed RoBERTa batch 1710/1957
# Processed RoBERTa batch 1711/1957
# Processed RoBERTa batch 1712/1957
# Processed RoBERTa batch 1713/1957
# Processed RoBERTa batch 1714/1957
# Processed RoBERTa batch 1715/1957
# Processed RoBERTa batch 1716/1957
# Processed RoBERTa batch 1717/1957
# Processed RoBERTa batch 1718/1957
# Processed RoBERTa batch 1719/1957
# Processed RoBERTa batch 1720/1957
# Processed RoBERTa batch 1721/1957
# Processed RoBERTa batch 1722/1957
# Processed RoBERTa batch 1723/1957
# Processed RoBERTa batch 1724/1957
# Processed RoBERTa batch 1725/1957
# Processed RoBERTa batch 1726/1957
# Processed RoBERTa batch 1727/1957
# Processed RoBERTa batch 1728/1957
# Processed RoBERTa batch 1729/1957
# Processed RoBERTa batch 1730/1957
# Processed RoBERTa batch 1731/1957
# Processed RoBERTa batch 1732/1957
# Processed RoBERTa batch 1733/1957
# Processed RoBERTa batch 1734/1957
# Processed RoBERTa batch 1735/1957
# Processed RoBERTa batch 1736/1957
# Processed RoBERTa batch 1737/1957
# Processed RoBERTa batch 1738/1957
# Processed RoBERTa batch 1739/1957
# Processed RoBERTa batch 1740/1957
# Processed RoBERTa batch 1741/1957
# Processed RoBERTa batch 1742/1957
# Processed RoBERTa batch 1743/1957
# Processed RoBERTa batch 1744/1957
# Processed RoBERTa batch 1745/1957
# Processed RoBERTa batch 1746/1957
# Processed RoBERTa batch 1747/1957
# Processed RoBERTa batch 1748/1957
# Processed RoBERTa batch 1749/1957
# Processed RoBERTa batch 1750/1957
# Processed RoBERTa batch 1751/1957
# Processed RoBERTa batch 1752/1957
# Processed RoBERTa batch 1753/1957
# Processed RoBERTa batch 1754/1957
# Processed RoBERTa batch 1755/1957
# Processed RoBERTa batch 1756/1957
# Processed RoBERTa batch 1757/1957
# Processed RoBERTa batch 1758/1957
# Processed RoBERTa batch 1759/1957
# Processed RoBERTa batch 1760/1957
# Processed RoBERTa batch 1761/1957
# Processed RoBERTa batch 1762/1957
# Processed RoBERTa batch 1763/1957
# Processed RoBERTa batch 1764/1957
# Processed RoBERTa batch 1765/1957
# Processed RoBERTa batch 1766/1957
# Processed RoBERTa batch 1767/1957
# Processed RoBERTa batch 1768/1957
# Processed RoBERTa batch 1769/1957
# Processed RoBERTa batch 1770/1957
# Processed RoBERTa batch 1771/1957
# Processed RoBERTa batch 1772/1957
# Processed RoBERTa batch 1773/1957
# Processed RoBERTa batch 1774/1957
# Processed RoBERTa batch 1775/1957
# Processed RoBERTa batch 1776/1957
# Processed RoBERTa batch 1777/1957
# Processed RoBERTa batch 1778/1957
# Processed RoBERTa batch 1779/1957
# Processed RoBERTa batch 1780/1957
# Processed RoBERTa batch 1781/1957
# Processed RoBERTa batch 1782/1957
# Processed RoBERTa batch 1783/1957
# Processed RoBERTa batch 1784/1957
# Processed RoBERTa batch 1785/1957
# Processed RoBERTa batch 1786/1957
# Processed RoBERTa batch 1787/1957
# Processed RoBERTa batch 1788/1957
# Processed RoBERTa batch 1789/1957
# Processed RoBERTa batch 1790/1957
# Processed RoBERTa batch 1791/1957
# Processed RoBERTa batch 1792/1957
# Processed RoBERTa batch 1793/1957
# Processed RoBERTa batch 1794/1957
# Processed RoBERTa batch 1795/1957
# Processed RoBERTa batch 1796/1957
# Processed RoBERTa batch 1797/1957
# Processed RoBERTa batch 1798/1957
# Processed RoBERTa batch 1799/1957
# Processed RoBERTa batch 1800/1957
# Processed RoBERTa batch 1801/1957
# Processed RoBERTa batch 1802/1957
# Processed RoBERTa batch 1803/1957
# Processed RoBERTa batch 1804/1957
# Processed RoBERTa batch 1805/1957
# Processed RoBERTa batch 1806/1957
# Processed RoBERTa batch 1807/1957
# Processed RoBERTa batch 1808/1957
# Processed RoBERTa batch 1809/1957
# Processed RoBERTa batch 1810/1957
# Processed RoBERTa batch 1811/1957
# Processed RoBERTa batch 1812/1957
# Processed RoBERTa batch 1813/1957
# Processed RoBERTa batch 1814/1957
# Processed RoBERTa batch 1815/1957
# Processed RoBERTa batch 1816/1957
# Processed RoBERTa batch 1817/1957
# Processed RoBERTa batch 1818/1957
# Processed RoBERTa batch 1819/1957
# Processed RoBERTa batch 1820/1957
# Processed RoBERTa batch 1821/1957
# Processed RoBERTa batch 1822/1957
# Processed RoBERTa batch 1823/1957
# Processed RoBERTa batch 1824/1957
# Processed RoBERTa batch 1825/1957
# Processed RoBERTa batch 1826/1957
# Processed RoBERTa batch 1827/1957
# Processed RoBERTa batch 1828/1957
# Processed RoBERTa batch 1829/1957
# Processed RoBERTa batch 1830/1957
# Processed RoBERTa batch 1831/1957
# Processed RoBERTa batch 1832/1957
# Processed RoBERTa batch 1833/1957
# Processed RoBERTa batch 1834/1957
# Processed RoBERTa batch 1835/1957
# Processed RoBERTa batch 1836/1957
# Processed RoBERTa batch 1837/1957
# Processed RoBERTa batch 1838/1957
# Processed RoBERTa batch 1839/1957
# Processed RoBERTa batch 1840/1957
# Processed RoBERTa batch 1841/1957
# Processed RoBERTa batch 1842/1957
# Processed RoBERTa batch 1843/1957
# Processed RoBERTa batch 1844/1957
# Processed RoBERTa batch 1845/1957
# Processed RoBERTa batch 1846/1957
# Processed RoBERTa batch 1847/1957
# Processed RoBERTa batch 1848/1957
# Processed RoBERTa batch 1849/1957
# Processed RoBERTa batch 1850/1957
# Processed RoBERTa batch 1851/1957
# Processed RoBERTa batch 1852/1957
# Processed RoBERTa batch 1853/1957
# Processed RoBERTa batch 1854/1957
# Processed RoBERTa batch 1855/1957
# Processed RoBERTa batch 1856/1957
# Processed RoBERTa batch 1857/1957
# Processed RoBERTa batch 1858/1957
# Processed RoBERTa batch 1859/1957
# Processed RoBERTa batch 1860/1957
# Processed RoBERTa batch 1861/1957
# Processed RoBERTa batch 1862/1957
# Processed RoBERTa batch 1863/1957
# Processed RoBERTa batch 1864/1957
# Processed RoBERTa batch 1865/1957
# Processed RoBERTa batch 1866/1957
# Processed RoBERTa batch 1867/1957
# Processed RoBERTa batch 1868/1957
# Processed RoBERTa batch 1869/1957
# Processed RoBERTa batch 1870/1957
# Processed RoBERTa batch 1871/1957
# Processed RoBERTa batch 1872/1957
# Processed RoBERTa batch 1873/1957
# Processed RoBERTa batch 1874/1957
# Processed RoBERTa batch 1875/1957
# Processed RoBERTa batch 1876/1957
# Processed RoBERTa batch 1877/1957
# Processed RoBERTa batch 1878/1957
# Processed RoBERTa batch 1879/1957
# Processed RoBERTa batch 1880/1957
# Processed RoBERTa batch 1881/1957
# Processed RoBERTa batch 1882/1957
# Processed RoBERTa batch 1883/1957
# Processed RoBERTa batch 1884/1957
# Processed RoBERTa batch 1885/1957
# Processed RoBERTa batch 1886/1957
# Processed RoBERTa batch 1887/1957
# Processed RoBERTa batch 1888/1957
# Processed RoBERTa batch 1889/1957
# Processed RoBERTa batch 1890/1957
# Processed RoBERTa batch 1891/1957
# Processed RoBERTa batch 1892/1957
# Processed RoBERTa batch 1893/1957
# Processed RoBERTa batch 1894/1957
# Processed RoBERTa batch 1895/1957
# Processed RoBERTa batch 1896/1957
# Processed RoBERTa batch 1897/1957
# Processed RoBERTa batch 1898/1957
# Processed RoBERTa batch 1899/1957
# Processed RoBERTa batch 1900/1957
# Processed RoBERTa batch 1901/1957
# Processed RoBERTa batch 1902/1957
# Processed RoBERTa batch 1903/1957
# Processed RoBERTa batch 1904/1957
# Processed RoBERTa batch 1905/1957
# Processed RoBERTa batch 1906/1957
# Processed RoBERTa batch 1907/1957
# Processed RoBERTa batch 1908/1957
# Processed RoBERTa batch 1909/1957
# Processed RoBERTa batch 1910/1957
# Processed RoBERTa batch 1911/1957
# Processed RoBERTa batch 1912/1957
# Processed RoBERTa batch 1913/1957
# Processed RoBERTa batch 1914/1957
# Processed RoBERTa batch 1915/1957
# Processed RoBERTa batch 1916/1957
# Processed RoBERTa batch 1917/1957
# Processed RoBERTa batch 1918/1957
# Processed RoBERTa batch 1919/1957
# Processed RoBERTa batch 1920/1957
# Processed RoBERTa batch 1921/1957
# Processed RoBERTa batch 1922/1957
# Processed RoBERTa batch 1923/1957
# Processed RoBERTa batch 1924/1957
# Processed RoBERTa batch 1925/1957
# Processed RoBERTa batch 1926/1957
# Processed RoBERTa batch 1927/1957
# Processed RoBERTa batch 1928/1957
# Processed RoBERTa batch 1929/1957
# Processed RoBERTa batch 1930/1957
# Processed RoBERTa batch 1931/1957
# Processed RoBERTa batch 1932/1957
# Processed RoBERTa batch 1933/1957
# Processed RoBERTa batch 1934/1957
# Processed RoBERTa batch 1935/1957
# Processed RoBERTa batch 1936/1957
# Processed RoBERTa batch 1937/1957
# Processed RoBERTa batch 1938/1957
# Processed RoBERTa batch 1939/1957
# Processed RoBERTa batch 1940/1957
# Processed RoBERTa batch 1941/1957
# Processed RoBERTa batch 1942/1957
# Processed RoBERTa batch 1943/1957
# Processed RoBERTa batch 1944/1957
# Processed RoBERTa batch 1945/1957
# Processed RoBERTa batch 1946/1957
# Processed RoBERTa batch 1947/1957
# Processed RoBERTa batch 1948/1957
# Processed RoBERTa batch 1949/1957
# Processed RoBERTa batch 1950/1957
# Processed RoBERTa batch 1951/1957
# Processed RoBERTa batch 1952/1957
# Processed RoBERTa batch 1953/1957
# Processed RoBERTa batch 1954/1957
# Processed RoBERTa batch 1955/1957
# Processed RoBERTa batch 1956/1957

# %%
roberta_embeddings = np.array(roberta_embeddings)
print(roberta_embeddings.shape)
cleaned_data['roberta_embedding'] = [array_to_string(arr) for arr in roberta_embeddings]
print("RoBERTa embeddings shape:", roberta_embeddings.shape)
# Out:
# (62592, 768)
# RoBERTa embeddings shape: (62592, 768)

# %%
#reduce dimensionality with PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=300, random_state=45)  
roberta_reduced = pca.fit_transform(roberta_embeddings)
print(roberta_reduced.shape)
# Out:
# (62592, 300)

# %%
cleaned_data['roberta_embedding'] = list(roberta_reduced)
display(cleaned_data)
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 62587  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 62588  Russians steal research on Trump in hack of U....
# 62589   WATCH: Giuliani Demands That Democrats Apolog...
# 62590  Migrants Refuse To Leave Train At Refugee Camp...
# 62591  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 62587  An email released by WikiLeaks on Sunday appea...      1
# 62588  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 62589  You know, because in fantasyland Republicans n...      1
# 62590  Migrants Refuse To Leave Train At Refugee Camp...      0
# 62591  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
#
#                                        roberta_embedding
# 0      [0.77837825, -1.3829339, 0.21932077, -0.037815...
# 1      [-3.4394891, -1.1532453, -0.57524085, -0.29689...
# 2      [0.61816597, 0.10020125, -0.627897, -0.1652965...
# 3      [0.6582862, 0.40051103, -0.35593724, 0.6198630...
# 4      [0.51393855, 0.6349008, 1.0849333, 0.33767414,...
# ...                                                  ...
# 62587  [-0.74468505, 0.1229167, 1.3666742, 0.07904005...
# 62588  [0.5316571, 0.9854491, -0.6684599, -0.01448869...
# 62589  [0.6461022, -1.1085404, 0.13549614, -0.3637871...
# 62590  [0.5340885, -0.03433156, -0.3962021, 0.1179680...
# 62591  [0.63186765, 0.23515463, -0.49998522, 0.108960...
#
# [62592 rows x 4 columns]

# %%
# Save to parquet (can handle the string-encoded embeddings)
# cleaned_data.to_parquet('cleaned_welfake_with_embeddings.parquet')

# %%
# If you need it To load later:
# def load_data():
#     return pd.read_parquet('cleaned_welfake_with_embeddings.parquet')

# %% [markdown]
# ##### BOW

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
bow_vectorizer = CountVectorizer(min_df=0.05, max_df=0.95, stop_words='english', ngram_range=(1,3))
bow_embeddings = bow_vectorizer.fit_transform(cleaned_data['text'])
print("BOW embeddings shape:", bow_embeddings.shape)
print(bow_embeddings)
# Out:
# BOW embeddings shape: (62592, 759)
#   (0, 129)	1
#   (0, 219)	1
#   (0, 68)	1
#   (0, 453)	1
#   (0, 409)	1
#   (0, 87)	3
#   (0, 736)	9
#   (0, 474)	10
#   (0, 690)	1
#   (0, 444)	1
#   (0, 691)	5
#   (0, 411)	1
#   (0, 78)	10
#   (0, 43)	1
#   (0, 664)	6
#   (0, 694)	3
#   (0, 608)	1
#   (0, 647)	3
#   (0, 145)	1
#   (0, 1)	1
#   (0, 673)	1
#   (0, 120)	1
#   (0, 287)	2
#   (0, 374)	6
#   (0, 540)	1
#   :	:
#   (62591, 373)	1
#   (62591, 208)	1
#   (62591, 234)	1
#   (62591, 12)	1
#   (62591, 704)	1
#   (62591, 230)	1
#   (62591, 247)	1
#   (62591, 170)	1
#   (62591, 76)	1
#   (62591, 716)	3
#   (62591, 458)	1
#   (62591, 724)	2
#   (62591, 336)	1
#   (62591, 405)	2
#   (62591, 63)	1
#   (62591, 132)	1
#   (62591, 224)	1
#   (62591, 482)	1
#   (62591, 338)	1
#   (62591, 250)	1
#   (62591, 237)	1
#   (62591, 470)	1
#   (62591, 688)	1
#   (62591, 352)	1
#   (62591, 82)	1

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=300, random_state=45)
bow_reduced = svd.fit_transform(bow_embeddings)
print(bow_reduced.shape)
print(bow_reduced)
# Out:
# (62592, 300)
# [[ 1.27512282e+01 -8.76048498e+00 -2.46459563e+00 ... -2.40341146e-01
#   -5.38164033e-01  9.53867908e-02]
#  [ 1.54090634e-01 -6.48069395e-02 -1.32581682e-01 ... -2.61103861e-03
#    7.50409455e-02 -1.80323212e-02]
#  [ 1.11447250e+01 -6.60614566e+00 -7.93055526e-01 ...  3.73877185e-01
#    5.65029930e-01 -1.15148480e+00]
#  ...
#  [ 1.64992115e+01  1.31108905e+01 -1.99710545e+00 ... -1.45536429e-01
#   -3.82781577e-01  1.45375327e-01]
#  [ 5.26452653e+00 -3.88533425e+00 -8.70070293e-01 ... -3.13548525e-01
#    6.88490359e-01 -9.97100491e-02]
#  [ 1.01114713e+01  3.59138092e+00 -4.21846264e-01 ... -1.04478263e+00
#   -2.67524534e-01 -7.14664660e-01]]

# %%
cleaned_data['bow_embedding'] = list(bow_reduced)
display(cleaned_data)
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 62587  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 62588  Russians steal research on Trump in hack of U....
# 62589   WATCH: Giuliani Demands That Democrats Apolog...
# 62590  Migrants Refuse To Leave Train At Refugee Camp...
# 62591  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 62587  An email released by WikiLeaks on Sunday appea...      1
# 62588  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 62589  You know, because in fantasyland Republicans n...      1
# 62590  Migrants Refuse To Leave Train At Refugee Camp...      0
# 62591  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
#
#                                        roberta_embedding  \
# 0      [0.77837825, -1.3829339, 0.21932077, -0.037815...
# 1      [-3.4394891, -1.1532453, -0.57524085, -0.29689...
# 2      [0.61816597, 0.10020125, -0.627897, -0.1652965...
# 3      [0.6582862, 0.40051103, -0.35593724, 0.6198630...
# 4      [0.51393855, 0.6349008, 1.0849333, 0.33767414,...
# ...                                                  ...
# 62587  [-0.74468505, 0.1229167, 1.3666742, 0.07904005...
# 62588  [0.5316571, 0.9854491, -0.6684599, -0.01448869...
# 62589  [0.6461022, -1.1085404, 0.13549614, -0.3637871...
# 62590  [0.5340885, -0.03433156, -0.3962021, 0.1179680...
# 62591  [0.63186765, 0.23515463, -0.49998522, 0.108960...
#
#                                            bow_embedding
# 0      [12.751228183014527, -8.760484977091297, -2.46...
# 1      [0.1540906344076637, -0.06480693954115654, -0....
# 2      [11.144724982986332, -6.606145662614691, -0.79...
# 3      [2.6159286882160537, -1.72675977752399, -0.519...
# 4      [1.9346475297557924, -1.1505992523835311, -0.7...
# ...                                                  ...
# 62587  [3.622973638522903, -0.54198912841281, -1.4584...
# 62588  [17.799926846744107, 1.1087862440581235, 1.350...
# 62589  [16.499211522306364, 13.110890533481918, -1.99...
# 62590  [5.264526534165657, -3.8853342501017916, -0.87...
# 62591  [10.11147131974668, 3.5913809223715325, -0.421...
#
# [62592 rows x 5 columns]

# %% [markdown]
# ##### BOW TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=0.05, max_df=0.95, stop_words='english', ngram_range=(1,3))
tfidf_embeddings = tfidf_vectorizer.fit_transform(cleaned_data['text'])
print(tfidf_embeddings)
print("TF-IDF embeddings shape:", tfidf_embeddings.shape)
# Out:
#   (0, 129)	0.043776892997407064
#   (0, 219)	0.04355821109782633
#   (0, 68)	0.04264258887658645
#   (0, 453)	0.03279594325845806
#   (0, 409)	0.038586898362493266
#   (0, 87)	0.09441925332228658
#   (0, 736)	0.2845383624214601
#   (0, 474)	0.227589084485444
#   (0, 690)	0.03690762869472127
#   (0, 444)	0.041771788008004074
#   (0, 691)	0.2346406766570602
#   (0, 411)	0.04742089416427213
#   (0, 78)	0.4472010844429815
#   (0, 43)	0.03506439473743557
#   (0, 664)	0.30615377652594616
#   (0, 694)	0.10636320635940007
#   (0, 608)	0.04809402251574631
#   (0, 647)	0.1320968997702561
#   (0, 145)	0.04220381021203303
#   (0, 1)	0.03876578583431527
#   (0, 673)	0.025868632274383907
#   (0, 120)	0.049907229419462296
#   (0, 287)	0.10050605184265582
#   (0, 374)	0.1570416554970401
#   (0, 540)	0.04721988149094425
#   :	:
#   (62591, 373)	0.06722572182360022
#   (62591, 208)	0.06071248241715993
#   (62591, 234)	0.07861192097670323
#   (62591, 12)	0.07555794846128877
#   (62591, 704)	0.06355231491962349
#   (62591, 230)	0.08430353674689829
#   (62591, 247)	0.06290711238039597
#   (62591, 170)	0.07769290928615934
#   (62591, 76)	0.08160004058268908
#   (62591, 716)	0.235342357607589
#   (62591, 458)	0.05976224000913626
#   (62591, 724)	0.1639420874090766
#   (62591, 336)	0.07873964984520587
#   (62591, 405)	0.11388531877662471
#   (62591, 63)	0.08629647104492795
#   (62591, 132)	0.08496885170498068
#   (62591, 224)	0.07849900904604334
#   (62591, 482)	0.08498780117441608
#   (62591, 338)	0.08169220115126709
#   (62591, 250)	0.08026752433159266
#   (62591, 237)	0.08164878293783691
#   (62591, 470)	0.06554361793889381
#   (62591, 688)	0.07606401500238563
#   (62591, 352)	0.07390805364527206
#   (62591, 82)	0.08519096036814194
# TF-IDF embeddings shape: (62592, 759)

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=300, random_state=45)
tfidf_reduced = svd.fit_transform(tfidf_embeddings)
print(tfidf_reduced.shape)
print(tfidf_reduced)
# Out:
# (62592, 300)
# [[ 0.31860298 -0.10941072  0.10317675 ...  0.00278509 -0.00708589
#   -0.00929653]
#  [ 0.07578831 -0.01524089  0.02820455 ...  0.04122813 -0.00059605
#    0.02045247]
#  [ 0.39807791 -0.15109853  0.057081   ...  0.01464588  0.00635184
#    0.03690883]
#  ...
#  [ 0.45380863  0.33718147 -0.04324545 ...  0.00891854  0.0281111
#    0.00085979]
#  [ 0.29040425 -0.21906294 -0.02015833 ... -0.05417055 -0.03030166
#   -0.00403572]
#  [ 0.46950877  0.07418171 -0.13248021 ...  0.00967072  0.01256809
#    0.04918511]]

# %%
cleaned_data['tfidf_embedding'] = list(tfidf_reduced)
display(cleaned_data)
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 62587  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 62588  Russians steal research on Trump in hack of U....
# 62589   WATCH: Giuliani Demands That Democrats Apolog...
# 62590  Migrants Refuse To Leave Train At Refugee Camp...
# 62591  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 62587  An email released by WikiLeaks on Sunday appea...      1
# 62588  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 62589  You know, because in fantasyland Republicans n...      1
# 62590  Migrants Refuse To Leave Train At Refugee Camp...      0
# 62591  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
#
#                                        roberta_embedding  \
# 0      [0.77837825, -1.3829339, 0.21932077, -0.037815...
# 1      [-3.4394891, -1.1532453, -0.57524085, -0.29689...
# 2      [0.61816597, 0.10020125, -0.627897, -0.1652965...
# 3      [0.6582862, 0.40051103, -0.35593724, 0.6198630...
# 4      [0.51393855, 0.6349008, 1.0849333, 0.33767414,...
# ...                                                  ...
# 62587  [-0.74468505, 0.1229167, 1.3666742, 0.07904005...
# 62588  [0.5316571, 0.9854491, -0.6684599, -0.01448869...
# 62589  [0.6461022, -1.1085404, 0.13549614, -0.3637871...
# 62590  [0.5340885, -0.03433156, -0.3962021, 0.1179680...
# 62591  [0.63186765, 0.23515463, -0.49998522, 0.108960...
#
#                                            bow_embedding  \
# 0      [12.751228183014527, -8.760484977091297, -2.46...
# 1      [0.1540906344076637, -0.06480693954115654, -0....
# 2      [11.144724982986332, -6.606145662614691, -0.79...
# 3      [2.6159286882160537, -1.72675977752399, -0.519...
# 4      [1.9346475297557924, -1.1505992523835311, -0.7...
# ...                                                  ...
# 62587  [3.622973638522903, -0.54198912841281, -1.4584...
# 62588  [17.799926846744107, 1.1087862440581235, 1.350...
# 62589  [16.499211522306364, 13.110890533481918, -1.99...
# 62590  [5.264526534165657, -3.8853342501017916, -0.87...
# 62591  [10.11147131974668, 3.5913809223715325, -0.421...
#
#                                          tfidf_embedding
# 0      [0.3186029772902578, -0.1094107173745029, 0.10...
# 1      [0.07578831287738759, -0.015240886953002832, 0...
# 2      [0.3980779078413261, -0.15109853445516602, 0.0...
# 3      [0.21115011222058097, -0.14267633316979805, -0...
# 4      [0.1945931561404842, -0.1142489399938969, 0.00...
# ...                                                  ...
# 62587  [0.23084806769137872, 0.09422806198766091, 0.3...
# 62588  [0.4787758131172253, 0.003986352099122974, -0....
# 62589  [0.45380863043849157, 0.3371814687589905, -0.0...
# 62590  [0.290404249417728, -0.21906293500944446, -0.0...
# 62591  [0.46950877235370597, 0.07418171272835605, -0....
#
# [62592 rows x 6 columns]

# %% [markdown]
#  ##### CBOW-W2V

# %%
import nltk
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package english_wordnet to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package english_wordnet is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\paulo\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
texts = cleaned_data["text"].astype(str).tolist()

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in ENGLISH_STOP_WORDS]
    return tokens

tokenized_texts = [preprocess(t) for t in texts]

# %%
from gensim.models import KeyedVectors
import gensim.downloader

#load pretrained model
w2v_vectors = gensim.downloader.load('word2vec-google-news-300')

# %%
embedding_dim = w2v_vectors.vector_size
num_docs = len(tokenized_texts)

w2v_embeddings = np.zeros((num_docs, embedding_dim), dtype=np.float32)

#include batch processing
batch_size = 32
for start_idx in range(0, num_docs, batch_size):
    end_idx = min(start_idx + batch_size, num_docs)
    batch = tokenized_texts[start_idx:end_idx]
    
    # Compute embeddings for the batch
    for i, doc in enumerate(batch):
        vectors = [w2v_vectors[word] for word in doc if word in w2v_vectors]
        if vectors:
            w2v_embeddings[start_idx + i] = np.mean(vectors, axis=0)
        else:
            w2v_embeddings[start_idx + i] = np.zeros(embedding_dim)

# %%
print(w2v_embeddings.shape)
cleaned_data['w2v_embedding'] = list(w2v_embeddings)
display(cleaned_data)
# Out:
# (62592, 300)
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 62587  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 62588  Russians steal research on Trump in hack of U....
# 62589   WATCH: Giuliani Demands That Democrats Apolog...
# 62590  Migrants Refuse To Leave Train At Refugee Camp...
# 62591  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 62587  An email released by WikiLeaks on Sunday appea...      1
# 62588  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 62589  You know, because in fantasyland Republicans n...      1
# 62590  Migrants Refuse To Leave Train At Refugee Camp...      0
# 62591  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
#
#                                        roberta_embedding  \
# 0      [0.77837825, -1.3829339, 0.21932077, -0.037815...
# 1      [-3.4394891, -1.1532453, -0.57524085, -0.29689...
# 2      [0.61816597, 0.10020125, -0.627897, -0.1652965...
# 3      [0.6582862, 0.40051103, -0.35593724, 0.6198630...
# 4      [0.51393855, 0.6349008, 1.0849333, 0.33767414,...
# ...                                                  ...
# 62587  [-0.74468505, 0.1229167, 1.3666742, 0.07904005...
# 62588  [0.5316571, 0.9854491, -0.6684599, -0.01448869...
# 62589  [0.6461022, -1.1085404, 0.13549614, -0.3637871...
# 62590  [0.5340885, -0.03433156, -0.3962021, 0.1179680...
# 62591  [0.63186765, 0.23515463, -0.49998522, 0.108960...
#
#                                            bow_embedding  \
# 0      [12.751228183014527, -8.760484977091297, -2.46...
# 1      [0.1540906344076637, -0.06480693954115654, -0....
# 2      [11.144724982986332, -6.606145662614691, -0.79...
# 3      [2.6159286882160537, -1.72675977752399, -0.519...
# 4      [1.9346475297557924, -1.1505992523835311, -0.7...
# ...                                                  ...
# 62587  [3.622973638522903, -0.54198912841281, -1.4584...
# 62588  [17.799926846744107, 1.1087862440581235, 1.350...
# 62589  [16.499211522306364, 13.110890533481918, -1.99...
# 62590  [5.264526534165657, -3.8853342501017916, -0.87...
# 62591  [10.11147131974668, 3.5913809223715325, -0.421...
#
#                                          tfidf_embedding  \
# 0      [0.3186029772902578, -0.1094107173745029, 0.10...
# 1      [0.07578831287738759, -0.015240886953002832, 0...
# 2      [0.3980779078413261, -0.15109853445516602, 0.0...
# 3      [0.21115011222058097, -0.14267633316979805, -0...
# 4      [0.1945931561404842, -0.1142489399938969, 0.00...
# ...                                                  ...
# 62587  [0.23084806769137872, 0.09422806198766091, 0.3...
# 62588  [0.4787758131172253, 0.003986352099122974, -0....
# 62589  [0.45380863043849157, 0.3371814687589905, -0.0...
# 62590  [0.290404249417728, -0.21906293500944446, -0.0...
# 62591  [0.46950877235370597, 0.07418171272835605, -0....
#
#                                            w2v_embedding
# 0      [0.005737772, 0.051631283, 0.039275542, 0.0679...
# 1      [0.014999917, 0.057231702, 0.05448833, 0.10918...
# 2      [0.04940245, 0.03809506, 0.030635785, 0.096523...
# 3      [-0.022517398, 0.08829837, 0.06998471, 0.05531...
# 4      [0.031655375, 0.018008867, 0.039424133, 0.0783...
# ...                                                  ...
# 62587  [-0.00035927512, 0.04827896, -0.027950248, 0.0...
# 62588  [-0.020597927, 0.025891328, 0.0079015875, 0.06...
# 62589  [0.026168875, 0.059571818, 0.025066013, 0.0854...
# 62590  [0.009088822, 0.061462272, 0.026323821, 0.0745...
# 62591  [-0.02042316, 0.06397203, 0.021204822, 0.06751...
#
# [62592 rows x 7 columns]

# %% [markdown]
# #### OLD version

# %%
# cleaned_data_copy = cleaned_data.copy()
# cleaned_data_copy['tokens'] = cleaned_data_copy['text'].apply(lambda x: x.split())
# w2v_model = Word2Vec(sentences=cleaned_data_copy['tokens'], vector_size=100, window=5, min_count=5, sg=0, seed=42)
# def get_w2v_embedding(tokens, model):
#     vectors = [model.wv[token] for token in tokens if token in model.wv]
#     return np.mean(vectors, axis=0) if vectors else np.zeros(model.vector_size)

# w2v_embeddings = np.array([get_w2v_embedding(tokens, w2v_model) for tokens in cleaned_data_copy['tokens']])
# cleaned_data['w2v_embedding'] = [array_to_string(arr) for arr in w2v_embeddings]
# print("Word2Vec embeddings shape:", w2v_embeddings.shape)

# %% [markdown]
# ##### Push to Hub

# %%
cleaned_data.to_parquet('cleaned_welfake_with_embeddings.parquet')

# %%
from datasets import Dataset
import pandas as pd
import json

display(cleaned_data)

output_data = Dataset.from_pandas(cleaned_data)

# with open("config.json", "r") as f:
#     config=json.load(f)
# hf_token = config.get("hf_token")
# if(hf_token):
#     login(token=hf_token)
# else:
#     print("can't find token")
# Out:
#                                                    title  \
# 0      LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1      UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2      Bobby Jindal, raised Hindu, uses story of Chri...
# 3      SATAN 2: Russia unvelis an image of its terrif...
# 4      About Time! Christian Group Sues Amazon and SP...
# ...                                                  ...
# 62587  WIKILEAKS EMAIL SHOWS CLINTON FOUNDATION FUNDS...
# 62588  Russians steal research on Trump in hack of U....
# 62589   WATCH: Giuliani Demands That Democrats Apolog...
# 62590  Migrants Refuse To Leave Train At Refugee Camp...
# 62591  Trump tussle gives unpopular Mexican leader mu...
#
#                                                     text  label  \
# 0      No comment is expected from Barack Obama Membe...      1
# 1       Now, most of the demonstrators gathered last ...      1
# 2      A dozen politically active pastors came here f...      0
# 3      The RS-28 Sarmat missile, dubbed Satan 2, will...      1
# 4      All we can say on this one is it s about time ...      1
# ...                                                  ...    ...
# 62587  An email released by WikiLeaks on Sunday appea...      1
# 62588  WASHINGTON (Reuters) - Hackers believed to be ...      0
# 62589  You know, because in fantasyland Republicans n...      1
# 62590  Migrants Refuse To Leave Train At Refugee Camp...      0
# 62591  MEXICO CITY (Reuters) - Donald Trump’s combati...      0
#
#                                        roberta_embedding  \
# 0      [0.77837825, -1.3829339, 0.21932077, -0.037815...
# 1      [-3.4394891, -1.1532453, -0.57524085, -0.29689...
# 2      [0.61816597, 0.10020125, -0.627897, -0.1652965...
# 3      [0.6582862, 0.40051103, -0.35593724, 0.6198630...
# 4      [0.51393855, 0.6349008, 1.0849333, 0.33767414,...
# ...                                                  ...
# 62587  [-0.74468505, 0.1229167, 1.3666742, 0.07904005...
# 62588  [0.5316571, 0.9854491, -0.6684599, -0.01448869...
# 62589  [0.6461022, -1.1085404, 0.13549614, -0.3637871...
# 62590  [0.5340885, -0.03433156, -0.3962021, 0.1179680...
# 62591  [0.63186765, 0.23515463, -0.49998522, 0.108960...
#
#                                            bow_embedding  \
# 0      [12.751228183014527, -8.760484977091297, -2.46...
# 1      [0.1540906344076637, -0.06480693954115654, -0....
# 2      [11.144724982986332, -6.606145662614691, -0.79...
# 3      [2.6159286882160537, -1.72675977752399, -0.519...
# 4      [1.9346475297557924, -1.1505992523835311, -0.7...
# ...                                                  ...
# 62587  [3.622973638522903, -0.54198912841281, -1.4584...
# 62588  [17.799926846744107, 1.1087862440581235, 1.350...
# 62589  [16.499211522306364, 13.110890533481918, -1.99...
# 62590  [5.264526534165657, -3.8853342501017916, -0.87...
# 62591  [10.11147131974668, 3.5913809223715325, -0.421...
#
#                                          tfidf_embedding  \
# 0      [0.3186029772902578, -0.1094107173745029, 0.10...
# 1      [0.07578831287738759, -0.015240886953002832, 0...
# 2      [0.3980779078413261, -0.15109853445516602, 0.0...
# 3      [0.21115011222058097, -0.14267633316979805, -0...
# 4      [0.1945931561404842, -0.1142489399938969, 0.00...
# ...                                                  ...
# 62587  [0.23084806769137872, 0.09422806198766091, 0.3...
# 62588  [0.4787758131172253, 0.003986352099122974, -0....
# 62589  [0.45380863043849157, 0.3371814687589905, -0.0...
# 62590  [0.290404249417728, -0.21906293500944446, -0.0...
# 62591  [0.46950877235370597, 0.07418171272835605, -0....
#
#                                            w2v_embedding
# 0      [0.005737772, 0.051631283, 0.039275542, 0.0679...
# 1      [0.014999917, 0.057231702, 0.05448833, 0.10918...
# 2      [0.04940245, 0.03809506, 0.030635785, 0.096523...
# 3      [-0.022517398, 0.08829837, 0.06998471, 0.05531...
# 4      [0.031655375, 0.018008867, 0.039424133, 0.0783...
# ...                                                  ...
# 62587  [-0.00035927512, 0.04827896, -0.027950248, 0.0...
# 62588  [-0.020597927, 0.025891328, 0.0079015875, 0.06...
# 62589  [0.026168875, 0.059571818, 0.025066013, 0.0854...
# 62590  [0.009088822, 0.061462272, 0.026323821, 0.0745...
# 62591  [-0.02042316, 0.06397203, 0.021204822, 0.06751...
#
# [62592 rows x 7 columns]

# %%
output_data.push_to_hub("Paulozs/WELFake_embeddings")
# Out:
# Uploading the dataset shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/32 [00:00<?, ?ba/s]
# Creating parquet from Arrow format:   0%|          | 0/32 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/442 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Paulozs/WELFake_embeddings/commit/b50ce239b7e8fd68bf3f6910bbf6a85084a09ffd', commit_message='Upload dataset', commit_description='', oid='b50ce239b7e8fd68bf3f6910bbf6a85084a09ffd', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Paulozs/WELFake_embeddings', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Paulozs/WELFake_embeddings'), pr_revision=None, pr_num=None)
